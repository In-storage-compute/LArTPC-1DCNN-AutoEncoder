# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
#!{sys.executable} -m pip install tensorflow-gpu==2.4
#!export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/bhawks/.conda/envs/dune-1dcnn/lib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
wireplane = "Z"
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]

# %%
filenames
# Out:
# ['processed_data/x_test_Z.npy',
#  'processed_data/x_train_Z.npy',
#  'processed_data/y_test_flat_noise_target_Z.npy',
#  'processed_data/y_test_Z.npy',
#  'processed_data/y_train_flat_noise_target_Z.npy',
#  'processed_data/y_train_Z.npy']

# %%
for i in range(6):
    print(filenames[i])
# Out:
# processed_data/x_test_Z.npy
# processed_data/x_train_Z.npy
# processed_data/y_test_flat_noise_target_Z.npy
# processed_data/y_test_Z.npy
# processed_data/y_train_flat_noise_target_Z.npy
# processed_data/y_train_Z.npy

# %%
x_test = np.load(filenames[0])
x_train = np.load(filenames[1])
y_test_flat_noise_target = np.load(filenames[2])

y_test = np.load(filenames[3])
y_train_flat_noise_target = np.load(filenames[4])
y_train = np.load(filenames[5])

# %%
num = 0
for idx in range(num,num+3):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 2))
    fig.suptitle('Waveforms')
    ax1.plot(x_train[idx],color='blue', label='clean')
    ax1.plot(y_train[idx],color='m',alpha=0.7, label='data')

    ax2.plot(y_train_flat_noise_target[idx],color='m',alpha=0.7, label='data')
    ax2.set_title("y_train_flat_noise_target")
    plt.show()

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_test_scaled = (x_test-mean)/std
y_train_flat_noise_target_scaled = (y_train_flat_noise_target-mean)/std

y_train_scaled = (y_train-mean)/std
y_test_scaled = (y_test-mean)/std
y_test_flat_noise_target_scaled = (y_test_flat_noise_target-mean)/std

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Dense,Flatten, AveragePooling1D
from tensorflow.keras.layers import Input,  UpSampling1D
from tensorflow.keras.models import Model
#from keras import backend as K

# %% [markdown]
# # Autoencoder

# %%
from tensorflow.keras.models import load_model
model = load_model("learn_models/" + wireplane + "plane_nu.h5")

# %%
for i,layer in enumerate(model.layers):
  print(i,layer.name)
# Out:
# 0 conv1d
# 1 max_pooling1d
# 2 conv1d_1
# 3 max_pooling1d_1
# 4 dropout
# 5 conv1d_2
# 6 global_max_pooling1d
# 7 dropout_1
# 8 flatten
# 9 wavrec_out

# %%
time_periods = 200

# %%
input_wave = Input(shape=(x_train_scaled.shape[1], 1)) 
x = Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", weights=model.layers[0].get_weights() , input_shape=(time_periods,1))(input_wave)
x = MaxPooling1D(pool_size=2)(x)
 
#second convolutional block
x = Conv1D(filters=32, kernel_size=5, strides=2, weights=model.layers[2].get_weights(), activation = "relu", )(x)
x = MaxPooling1D(pool_size=2)(x)

encoded = Conv1D(filters=64, kernel_size=9, weights=model.layers[5].get_weights(), activation = "relu")(x)


x = Conv1D(filters=64, kernel_size=9, padding = "same", activation = "relu")(encoded)
x = UpSampling1D(4)(x)

x = Conv1D(filters=32, kernel_size=5, padding = "same", activation = "relu")(x)
x = UpSampling1D(3)(x)

x = Conv1D(filters=16, kernel_size=3,  activation = "relu")(x)
x = UpSampling1D(6)(x)

decoded = Conv1D(filters=1, kernel_size=5,  activation = "linear")(x)



autoencoder = Model(input_wave, decoded)

# %%
for i,layer in enumerate(autoencoder.layers):                                      
  print(i,layer.name)
# Out:
# 0 input_2
# 1 conv1d_7
# 2 max_pooling1d_2
# 3 conv1d_8
# 4 max_pooling1d_3
# 5 conv1d_9
# 6 conv1d_10
# 7 up_sampling1d_3
# 8 conv1d_11
# 9 up_sampling1d_4
# 10 conv1d_12
# 11 up_sampling1d_5
# 12 conv1d_13

# %%
for layer in autoencoder.layers[:6]:                                               
    layer.trainable=False                                                          
for layer in autoencoder.layers[6:]:                                               
    layer.trainable=True                                                           
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 1)]          0
#
#  conv1d_7 (Conv1D)           (None, 99, 16)            64
#
#  max_pooling1d_2 (MaxPooling  (None, 49, 16)           0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_3 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 3, 64)             18496
#
#  conv1d_10 (Conv1D)          (None, 3, 64)             36928
#
#  up_sampling1d_3 (UpSampling  (None, 12, 64)           0
#  1D)
#
#  conv1d_11 (Conv1D)          (None, 12, 32)            10272
#
#  up_sampling1d_4 (UpSampling  (None, 36, 32)           0
#  1D)
#
#  conv1d_12 (Conv1D)          (None, 34, 16)            1552
#
#  up_sampling1d_5 (UpSampling  (None, 204, 16)          0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 200, 1)            81
#
# =================================================================
# Total params: 69,985
# Trainable params: 48,833
# Non-trainable params: 21,152
# _________________________________________________________________

# %% [markdown]
# ### IMPORTANT: define the target for training
# 1) x_train_scale: train against itself (for wavefroms with signal + noise, target is that wavefrom), (for pure noise, the target will be that pure waveform as well)
# 2) y_train_flat_noise_target: same as (1), but when the wavefrom is JUST noise, target get will be ZERO
# 2) y_train_scale: train using clean signals as target

# %%
#target = x_train_scaled
#target = y_train_flat_noise_target_scaled
target = y_train_scaled

tarID = 3

# %%
# %%time
history = autoencoder.fit(x_train_scaled,                                                              
                    target,                                                            
                    batch_size=512,                                              
                    epochs=100,                                                      
                    callbacks=None, # callbacks=callbacks_list,                         
                    validation_split=0.2, shuffle=False,                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.1487 - val_loss: 0.0213
# Epoch 2/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 3/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 4/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 5/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 6/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 7/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 8/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 9/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 10/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 11/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 12/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 13/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 14/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 15/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 16/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 17/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 18/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 19/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 20/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 21/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 22/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 23/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 24/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 25/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 26/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 27/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 28/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 29/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 30/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 31/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 32/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 33/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 34/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 35/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 36/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 37/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 38/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 39/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 40/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 41/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 42/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 43/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 44/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 45/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 46/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 47/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 48/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 49/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 50/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 51/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 52/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 53/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 54/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 55/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 56/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 57/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 58/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 59/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 60/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 61/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 62/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 63/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 64/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 65/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 66/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 67/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 68/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 69/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 70/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 71/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 72/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 73/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 74/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 75/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 76/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 77/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 78/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 79/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 80/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 81/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 82/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 83/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 84/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 85/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 86/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 87/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 88/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 89/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 90/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 91/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 92/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 93/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 94/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 95/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 96/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 97/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 98/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 99/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 100/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0206 - val_loss: 0.0213
# Wall time: 39.8 s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Loss',fontsize=15)                                            
plt.ylabel('Loss (MSE)', fontsize=12)                                                 
plt.xlabel('Training Epoch', fontsize=12)                                                                                                                       
plt.legend(fontsize=12)                                                                    
plt.show()

# %%
# %%time
y = autoencoder.predict(x_test, batch_size=1024)
# Out:
# 63/63 [==============================] - 0s 4ms/step
# Wall time: 455 ms

# %%
y = y.reshape(y.shape[0], y.shape[1])

# %%
y
# Out:
# array([[-0.00099063, -0.00099063, -0.00099063, ..., -0.00099063,
#         -0.00099063, -0.00099063],
#        [-0.00099063, -0.00099063, -0.00099063, ..., -0.00099063,
#         -0.00099063, -0.00099063],
#        [-0.00099063, -0.00099063, -0.00099063, ..., -0.00099063,
#         -0.00099063, -0.00099063],
#        ...,
#        [-0.00099063, -0.00099063, -0.00099063, ..., -0.00099063,
#         -0.00099063, -0.00099063],
#        [-0.00099063, -0.00099063, -0.00099063, ..., -0.00099063,
#         -0.00099063, -0.00099063],
#        [-0.00099063, -0.00099063, -0.00099063, ..., -0.00099063,
#         -0.00099063, -0.00099063]], dtype=float32)

# %%
for idx in range(10):
    fig, (ax1) = plt.subplots(figsize=(12, 4))
    ax1.plot(y_test[idx],color='blue', label='target')
    ax1.plot(y[idx],color='m',alpha=0.7, label='model prediction')
    ax1.plot(x_test[idx], color='orange',alpha=0.7, label = 'original input')
    ax1.set_title("trained using (unclean signal) + (noise) as target", fontsize=15)
    ax1.legend()


    plt.show()

# %%
#model.save("results/" + wireplane + "plane_nu_" + str(tarID) + ".h5")

# %%
#np.save('results/train_target_sig_' + wireplane + "_" + str(tarID), y)
