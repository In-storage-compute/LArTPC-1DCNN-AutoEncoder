# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 2023-04-29 19:12:53.547836: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
np.random.seed(33)

# %%
wireplane = "V"
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/x_test_V.npy',
#  'processed_data/y_train_ROI_V.npy',
#  'processed_data/x_train_V.npy',
#  'processed_data/y_train_AE_V.npy',
#  'processed_data/y_test_ROI_V.npy',
#  'processed_data/y_test_AE_V.npy']

# %%
x_train = np.load(path+'x_train_' + wireplane + '.npy')
x_test = np.load(path+'x_test_' + wireplane + '.npy')
y_train = np.load(path+'y_train_ROI_' + wireplane + '.npy')
y_test = np.load(path+'y_test_ROI_'+wireplane+'.npy')

# %%
print(x_test.shape, y_train.shape, y_test.shape, y_train.shape)
# Out:
# (100000, 200) (100000,) (100000,) (100000,)

# %%
#split train and valid sets
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (80000, 200) (80000,)
# (100000, 200) (100000,)
# (20000, 200) (20000,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
np.save("ROI_models/mean_"+wireplane+"_nu_ROI", mean)
np.save("ROI_models/scale_"+wireplane+"_nu_ROI", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
    model = Sequential()  
    #first convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
    model.add(MaxPooling1D(pool_size=2))

    #second convolutional block
    model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.1))

    #forth convolutional block                                      
    model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2)) 

    model.add(Flatten())



    model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
    return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-29 19:13:01.148919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.153697: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.154018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.155006: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-29 19:13:01.160148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.160461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.160734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.647360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.647914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.648359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:13:01.648639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7927 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 1g.10gb, pci bus id: 0000:04:00.0, compute capability: 8.0

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#%%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 2023-04-29 19:13:10.373494: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2023-04-29 19:13:11.432516: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Running ptxas --version returned 32512
# 2023-04-29 19:13:11.563510: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: ptxas exited with non-zero error code 32512, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-04-29 19:13:11.709730: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 40/40 [==============================] - 4s 24ms/step - loss: 0.5355 - accuracy: 0.7117 - val_loss: 0.4156 - val_accuracy: 0.8174
# Epoch 2/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3971 - accuracy: 0.8226 - val_loss: 0.3746 - val_accuracy: 0.8354
# Epoch 3/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3764 - accuracy: 0.8329 - val_loss: 0.3711 - val_accuracy: 0.8361
# Epoch 4/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3692 - accuracy: 0.8364 - val_loss: 0.3635 - val_accuracy: 0.8395
# Epoch 5/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3649 - accuracy: 0.8384 - val_loss: 0.3622 - val_accuracy: 0.8378
# Epoch 6/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3625 - accuracy: 0.8406 - val_loss: 0.3584 - val_accuracy: 0.8414
# Epoch 7/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3601 - accuracy: 0.8418 - val_loss: 0.3582 - val_accuracy: 0.8436
# Epoch 8/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3580 - accuracy: 0.8426 - val_loss: 0.3602 - val_accuracy: 0.8375
# Epoch 9/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3580 - accuracy: 0.8424 - val_loss: 0.3554 - val_accuracy: 0.8427
# Epoch 10/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.3574 - accuracy: 0.8433 - val_loss: 0.3549 - val_accuracy: 0.8436
# Epoch 11/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3560 - accuracy: 0.8437 - val_loss: 0.3561 - val_accuracy: 0.8450
# Epoch 12/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3547 - accuracy: 0.8445 - val_loss: 0.3545 - val_accuracy: 0.8421
# Epoch 13/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3544 - accuracy: 0.8456 - val_loss: 0.3543 - val_accuracy: 0.8423
# Epoch 14/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3544 - accuracy: 0.8450 - val_loss: 0.3534 - val_accuracy: 0.8450
# Epoch 15/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3531 - accuracy: 0.8455 - val_loss: 0.3534 - val_accuracy: 0.8456
# Epoch 16/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3526 - accuracy: 0.8457 - val_loss: 0.3529 - val_accuracy: 0.8441
# Epoch 17/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3524 - accuracy: 0.8458 - val_loss: 0.3528 - val_accuracy: 0.8449
# Epoch 18/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3530 - accuracy: 0.8458 - val_loss: 0.3526 - val_accuracy: 0.8454
# Epoch 19/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3524 - accuracy: 0.8456 - val_loss: 0.3523 - val_accuracy: 0.8451
# Epoch 20/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.3515 - accuracy: 0.8468 - val_loss: 0.3523 - val_accuracy: 0.8453
# Epoch 21/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3509 - accuracy: 0.8465 - val_loss: 0.3523 - val_accuracy: 0.8451
# Epoch 22/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3511 - accuracy: 0.8465 - val_loss: 0.3521 - val_accuracy: 0.8453
# Epoch 23/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3506 - accuracy: 0.8459 - val_loss: 0.3520 - val_accuracy: 0.8453
# Epoch 24/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3503 - accuracy: 0.8470 - val_loss: 0.3522 - val_accuracy: 0.8461
# Epoch 25/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3498 - accuracy: 0.8475 - val_loss: 0.3521 - val_accuracy: 0.8447
# Epoch 26/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3493 - accuracy: 0.8479 - val_loss: 0.3523 - val_accuracy: 0.8461
# Epoch 27/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3489 - accuracy: 0.8477 - val_loss: 0.3518 - val_accuracy: 0.8457
# Epoch 28/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3493 - accuracy: 0.8477 - val_loss: 0.3527 - val_accuracy: 0.8464
# Epoch 29/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3499 - accuracy: 0.8473 - val_loss: 0.3517 - val_accuracy: 0.8461
# Epoch 30/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3480 - accuracy: 0.8481 - val_loss: 0.3517 - val_accuracy: 0.8459
# Epoch 31/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3483 - accuracy: 0.8480 - val_loss: 0.3577 - val_accuracy: 0.8418
# Epoch 32/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3490 - accuracy: 0.8479 - val_loss: 0.3515 - val_accuracy: 0.8459
# Epoch 33/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3472 - accuracy: 0.8486 - val_loss: 0.3521 - val_accuracy: 0.8451
# Epoch 34/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3472 - accuracy: 0.8485 - val_loss: 0.3525 - val_accuracy: 0.8455
# Epoch 35/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.3465 - accuracy: 0.8485 - val_loss: 0.3517 - val_accuracy: 0.8459
# Epoch 36/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3460 - accuracy: 0.8491 - val_loss: 0.3523 - val_accuracy: 0.8467
# Epoch 37/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.3471 - accuracy: 0.8484 - val_loss: 0.3521 - val_accuracy: 0.8470

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 4104

# %%
model.save("ROI_models/model_" + wireplane + "plane_nu_ROI.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 10ms/step - loss: 8.1962 - accuracy: 0.5026
# [8.19615364074707, 0.5026400089263916]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 2ms/step
# CPU times: user 511 ms, sys: 231 ms, total: 742 ms
# Wall time: 603 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <Axes: >

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10,6))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.8940828126010527

# %%
np.save("ROI_results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 41ms/step
# CPU times: user 232 ms, sys: 58.9 ms, total: 290 ms
# Wall time: 250 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <Axes: >

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10,6))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)
# Out:
# 0.884114628848487

# %%
np.save("ROI_results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 3ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# CPU times: user 312 ms, sys: 140 ms, total: 452 ms
# Wall time: 334 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([    0.,     0.,   712., 24383., 12836.,  4840.,  2375.,  1450.,
#           949.,   623.,   473.,   337.,   233.,   203.,   174.,   148.,
#            94.,    83.,    57.,    30.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([    0.,     0.,   123.,  5026.,  3667.,  1646.,  1144.,   821.,
#           607.,   504.,   460.,   376.,   411.,   401.,   408.,   426.,
#           433.,   526.,   763., 32258.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)
