# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import helper_functions as f
# Out:
# 2023-07-17 11:36:24.901548: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-17 11:36:29.474013: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load SIGNALS

# %%
wireplane = "U"
np.random.seed(77)
path = ('/home/vlian/Workspace/ar39_samples/processed/' +wireplane+'/')

# %%
dataset_adc_5_13 = np.load(path+'adc_5_13.npz', allow_pickle=True)

# %%
dataset_adc_14_16 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_14_16_U.npz', allow_pickle=True)

# %%
dataset_adc_gt_eq_17 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_gt_eq_17_U_ar39.npz', allow_pickle=True)

# %%
list(dataset_adc_14_16.keys())
# Out:
# ['adc_14', 'adc_15', 'adc_16']

# %%
list(dataset_adc_gt_eq_17.keys())
# Out:
# ['adc_17', 'adc_18', 'adc_19', 'adc_20', 'adc_21', 'adc_22', 'adc_gt_22']

# %%
adc_5_7 = dataset_adc_5_13['adc_5_7']
adc_8_10 = dataset_adc_5_13['adc_8_10']
#adc_11_13 = dataset_adc_5_13['adc_11_13']

# %%
adc_14 = dataset_adc_14_16['adc_14']
adc_15 = dataset_adc_14_16['adc_15']
adc_16 = dataset_adc_14_16['adc_16']

# %%
adc_17 = dataset_adc_gt_eq_17['adc_17']
adc_18 = dataset_adc_gt_eq_17['adc_18']
adc_19 = dataset_adc_gt_eq_17['adc_19']
adc_20 = dataset_adc_gt_eq_17['adc_20']
adc_21 = dataset_adc_gt_eq_17['adc_21']
adc_22 = dataset_adc_gt_eq_17['adc_22']
adc_gt_22 = dataset_adc_gt_eq_17['adc_gt_22']

# %%
#HERE
adc_5_7[0][0:10].shape
# Out:
# (10, 200)

# %%
def cut_data(adc_group, type_):
    if type_:
        num_samples = 54000
    else:
        num_samples = 18000
    
    x = adc_group[0][0:num_samples]
    y = adc_group[1][0:num_samples]
    
    print(x.shape, y.shape)
    
    return x, y

# %%
# for training with adc_5_10
print(adc_5_7.shape)
x_train = np.concatenate((adc_5_7[0], adc_8_10[0]))
y_train = np.concatenate((adc_5_7[1], adc_8_10[1]))
# Out:
# (2, 300000, 200)

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,2))
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
adc_5_7_x, adc_5_7_y = cut_data(adc_5_7, True)
adc_8_10_x, adc_8_10_y = cut_data(adc_8_10, True)
adc_11_13_x, adc_11_13_y = cut_data(adc_11_13, True)

adc_14_x, adc_14_y = cut_data(adc_14, False)
adc_15_x, adc_15_y = cut_data(adc_15, False)
adc_16_x, adc_16_y = cut_data(adc_16, False)
adc_17_x, adc_17_y = cut_data(adc_17, False)
adc_18_x, adc_18_y = cut_data(adc_18, False)
adc_19_x, adc_19_y = cut_data(adc_19, False)
adc_20_x, adc_20_y = cut_data(adc_20, False)
adc_21_x, adc_21_y = cut_data(adc_21, False)
adc_22_x, adc_22_y = cut_data(adc_22, False)
adc_gt_22_x, adc_gt_22_y = cut_data(adc_gt_22, True)

del adc_5_7, adc_8_10, adc_11_13, adc_14, adc_15, adc_16, adc_17, adc_18, adc_19, adc_20, adc_21, adc_22, adc_gt_22
# Out:
# (54000, 200) (54000, 200)
# (54000, 200) (54000, 200)
# (54000, 200) (54000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (54000, 200) (54000, 200)

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.plot(adc_8_10_x[i])
    plt.plot(adc_8_10_y[i])
    plt.show()

# %%
print(adc_5_7[0].shape, adc_5_7[1].shape)
print(adc_8_10[0].shape, adc_8_10[1].shape)
print(adc_11_13[0].shape, adc_11_13[1].shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(adc_5_7[0].shape, adc_5_7[1].shape)
#       2 print(adc_8_10[0].shape, adc_8_10[1].shape)
#       3 print(adc_11_13[0].shape, adc_11_13[1].shape)
#
# NameError: name 'adc_5_7' is not defined

# %%
print(adc_14.shape, adc_15.shape, adc_16.shape, adc_17.shape)
print(adc_18.shape, adc_19.shape, adc_20.shape, adc_21.shape)
print(adc_22.shape, adc_gt_22.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(adc_14.shape, adc_15.shape, adc_16.shape, adc_17.shape)
#       2 print(adc_18.shape, adc_19.shape, adc_20.shape, adc_21.shape)
#       3 print(adc_22.shape, adc_gt_22.shape)
#
# NameError: name 'adc_14' is not defined

# %%
print(adc_17[0].shape, adc_17[1].shape)
# Out:
# (100000, 200) (100000, 200)

# %%
x_train = np.empty((0,200))
x_train = np.concatenate((x_train, adc_5_7_x))
x_train = np.concatenate((x_train, adc_8_10_x))
x_train = np.concatenate((x_train, adc_11_13_x))
x_train = np.concatenate((x_train, adc_14_x))
x_train = np.concatenate((x_train, adc_15_x))
x_train = np.concatenate((x_train, adc_16_x))
x_train = np.concatenate((x_train, adc_17_x))
x_train = np.concatenate((x_train, adc_18_x))
x_train = np.concatenate((x_train, adc_19_x))
x_train = np.concatenate((x_train, adc_20_x))
x_train = np.concatenate((x_train, adc_21_x))
x_train = np.concatenate((x_train, adc_22_x))
x_train = np.concatenate((x_train, adc_gt_22_x))

y_train = np.empty((0,200))
y_train = np.concatenate((y_train, adc_5_7_y))
y_train = np.concatenate((y_train, adc_8_10_y))
y_train = np.concatenate((y_train, adc_11_13_y))
y_train = np.concatenate((y_train, adc_14_y))
y_train = np.concatenate((y_train, adc_15_y))
y_train = np.concatenate((y_train, adc_16_y))
y_train = np.concatenate((y_train, adc_17_y))
y_train = np.concatenate((y_train, adc_18_y))
y_train = np.concatenate((y_train, adc_19_y))
y_train = np.concatenate((y_train, adc_20_y))
y_train = np.concatenate((y_train, adc_21_y))
y_train = np.concatenate((y_train, adc_22_y))
y_train = np.concatenate((y_train, adc_gt_22_y))

# %%
x_train = np.empty((0,200))
x_train = np.concatenate((x_train, adc_5_7[0]))
x_train = np.concatenate((x_train, adc_8_10[0]))
x_train = np.concatenate((x_train, adc_11_13[0]))
x_train = np.concatenate((x_train, adc_14[0]))
x_train = np.concatenate((x_train, adc_15[0]))
x_train = np.concatenate((x_train, adc_16[0]))
x_train = np.concatenate((x_train, adc_17[0]))
x_train = np.concatenate((x_train, adc_18[0]))
x_train = np.concatenate((x_train, adc_19[0]))
x_train = np.concatenate((x_train, adc_20[0]))
x_train = np.concatenate((x_train, adc_21[0]))
x_train = np.concatenate((x_train, adc_22[0]))
x_train = np.concatenate((x_train, adc_gt_22[0]))

y_train = np.empty((0,200))
y_train = np.concatenate((y_train, adc_5_7[1]))
y_train = np.concatenate((y_train, adc_8_10[1]))
y_train = np.concatenate((y_train, adc_11_13[1]))
y_train = np.concatenate((y_train, adc_14[1]))
y_train = np.concatenate((y_train, adc_15[1]))
y_train = np.concatenate((y_train, adc_16[1]))
y_train = np.concatenate((y_train, adc_17[1]))
y_train = np.concatenate((y_train, adc_18[1]))
y_train = np.concatenate((y_train, adc_19[1]))
y_train = np.concatenate((y_train, adc_20[1]))
y_train = np.concatenate((y_train, adc_21[1]))
y_train = np.concatenate((y_train, adc_22[1]))
y_train = np.concatenate((y_train, adc_gt_22[1]))

# %%
print(x_train.shape, y_train.shape)
# Out:
# (378000, 200) (378000, 200)

# %%
for i in range(300000,300000+10):
    fig = plt.figure(figsize=(8,1))
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
54*3 + 18*10
# Out:
# 342

# %%
for i in range(100):
    x_train, y_train = shuffle(x_train, y_train)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (600000, 200) (600000, 200)

# %%
x_train = x_train[0:1400000]
y_train = y_train[0:1400000]
print(x_train.shape, y_train.shape)
# Out:
# (1400000, 200) (1400000, 200)

# %%
roi_truth_signals = np.ones(y_train.shape[0])

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.title(str(max(y_train[i])) + ' -- ' + str(roi_truth_signals[i]) )
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
check_grouping = f.adc_grouping(x_train, y_train)
del check_grouping
# Out:
#  0: adc_5_7             1: adc_8_10             2: adc_11_13             3: adc_14_16             4: adc_17_19             5: adc_20_22             6: adc_gt_22
#
# adc_5_7
# count       300000
#
# adc_8_10
# count       300000
#
# adc_11_13
# count       0
#
# adc_14_16
# count       0
#
# adc_17_19
# count       0
#
# adc_20_22
# count       0
#
# adc_gt_22
# count       0
#
#      Total:    600000

# %% [markdown]
# ## Load NOISE

# %%
noise_path = '/home/vlian/Workspace/more-noise/U/'
noise_filenames = sorted([f for f in listdir(noise_path) if (isfile(join(noise_path, f)) and wireplane in f)])
combined_noise = np.concatenate([np.load(noise_path+fname, mmap_mode='r') for fname in noise_filenames])

noise_waveforms = f.get_std_waveforms(combined_noise, 200)
roi_truth_noise = np.zeros(noise_waveforms.shape[0]) # for autoencoder
print(noise_waveforms.shape, roi_truth_noise.shape)
# Out:
# (1400000, 200) (1400000,)

# %%
for i in range(10):
    noise_waveforms = shuffle(noise_waveforms)

# %%
noise_waveforms = noise_waveforms[:y_train.shape[0]]
roi_truth_noise = roi_truth_noise[:y_train.shape[0]]

# %%
print(noise_waveforms.shape, roi_truth_noise.shape)
# Out:
# (600000, 200) (600000,)

# %% [markdown]
# ## Train/Test Split - Signals

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, roi_truth_signals, test_size=0.4, shuffle=True)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (360000, 200) (240000, 200) (360000,) (240000,)

# %% [markdown]
# #### Train/Val Split - Signals

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, shuffle=True)
print(x_train.shape, x_valid.shape, y_train.shape, y_valid.shape)
# Out:
# (288000, 200) (72000, 200) (288000,) (72000,)

# %% [markdown]
# ## Train/Test Split - Noise

# %%
x_noise_train, x_noise_test, y_noise_train, y_noise_test = train_test_split(noise_waveforms, roi_truth_noise, test_size=0.3, shuffle=True)
print(x_noise_train.shape, x_noise_test.shape, y_noise_train.shape, y_noise_test.shape)
# Out:
# (420000, 200) (180000, 200) (420000,) (180000,)

# %% [markdown]
# #### Train/Val Split - Noise

# %%
x_noise_train, x_noise_valid, y_noise_train, y_noise_valid = train_test_split(x_noise_train, y_noise_train, test_size=0.2, shuffle=True)
print(x_noise_train.shape, x_noise_valid.shape, y_noise_train.shape, y_noise_valid.shape)
# Out:
# (336000, 200) (84000, 200) (336000,) (84000,)

# %% [markdown]
# ## Combine Signal + Noise

# %%
x_train = np.concatenate((x_train, x_noise_train))
y_train = np.concatenate((y_train, y_noise_train))

x_valid = np.concatenate((x_valid, x_noise_valid))
y_valid = np.concatenate((y_valid, y_noise_valid))

x_test = np.concatenate((x_test, x_noise_test))
y_test = np.concatenate((y_test, y_noise_test))

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (624000, 200) (624000,)
# (156000, 200) (156000,)
# (420000, 200) (420000,)

# %%
for i in range(100):
    x_train, y_train = shuffle(x_train, y_train)
    x_valid, y_valid = shuffle(x_valid, y_valid)
    x_test, y_test = shuffle(x_test, y_test)

# %%
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (624000, 200) (624000,)
# (156000, 200) (156000,)
# (420000, 200) (420000,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
print(mean, std)
# Out:
# 0.006147932692307692 4.5177438961562215

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
np.save("ROI_ar39_models/mean_adc_5_10"+wireplane+"_nu_ROI", mean)
np.save("ROI_ar39_models/scale_adc_5_10"+wireplane+"_nu_ROI", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
    model = Sequential()  
    #first convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
    model.add(MaxPooling1D(pool_size=2))

    #second convolutional block
    model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.1))

    #forth convolutional block                                      
    model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2)) 

    model.add(Flatten())



    model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
    return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________
# 2023-07-17 11:47:03.507402: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:04.345710: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:04.346059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:04.351642: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:04.351926: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:04.352176: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:05.671065: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:05.671473: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:05.671803: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-17 11:47:05.672094: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18083 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 2g.20gb, pci bus id: 0000:04:00.0, compute capability: 8.0

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (624000, 200, 1) (156000, 200, 1) (420000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
20480/4
# Out:
# 5120.0

# %%
#%%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=5120,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 2023-07-17 11:47:10.459986: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-17 11:47:13.679439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 122/122 [==============================] - 10s 19ms/step - loss: 0.6161 - accuracy: 0.6568 - val_loss: 0.5471 - val_accuracy: 0.7234
# Epoch 2/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5438 - accuracy: 0.7264 - val_loss: 0.5284 - val_accuracy: 0.7373
# Epoch 3/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5317 - accuracy: 0.7357 - val_loss: 0.5225 - val_accuracy: 0.7415
# Epoch 4/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5267 - accuracy: 0.7387 - val_loss: 0.5192 - val_accuracy: 0.7439
# Epoch 5/100
# 122/122 [==============================] - 2s 14ms/step - loss: 0.5235 - accuracy: 0.7412 - val_loss: 0.5167 - val_accuracy: 0.7455
# Epoch 6/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5218 - accuracy: 0.7424 - val_loss: 0.5157 - val_accuracy: 0.7461
# Epoch 7/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5204 - accuracy: 0.7433 - val_loss: 0.5146 - val_accuracy: 0.7469
# Epoch 8/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5193 - accuracy: 0.7435 - val_loss: 0.5149 - val_accuracy: 0.7471
# Epoch 9/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5183 - accuracy: 0.7444 - val_loss: 0.5133 - val_accuracy: 0.7468
# Epoch 10/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5175 - accuracy: 0.7447 - val_loss: 0.5132 - val_accuracy: 0.7469
# Epoch 11/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5169 - accuracy: 0.7452 - val_loss: 0.5123 - val_accuracy: 0.7479
# Epoch 12/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5162 - accuracy: 0.7459 - val_loss: 0.5123 - val_accuracy: 0.7483
# Epoch 13/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5159 - accuracy: 0.7462 - val_loss: 0.5121 - val_accuracy: 0.7484
# Epoch 14/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5153 - accuracy: 0.7463 - val_loss: 0.5114 - val_accuracy: 0.7483
# Epoch 15/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5146 - accuracy: 0.7466 - val_loss: 0.5116 - val_accuracy: 0.7485
# Epoch 16/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5145 - accuracy: 0.7467 - val_loss: 0.5111 - val_accuracy: 0.7483
# Epoch 17/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5141 - accuracy: 0.7472 - val_loss: 0.5111 - val_accuracy: 0.7486
# Epoch 18/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5136 - accuracy: 0.7473 - val_loss: 0.5108 - val_accuracy: 0.7490
# Epoch 19/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5135 - accuracy: 0.7475 - val_loss: 0.5116 - val_accuracy: 0.7484
# Epoch 20/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5134 - accuracy: 0.7478 - val_loss: 0.5109 - val_accuracy: 0.7481
# Epoch 21/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5131 - accuracy: 0.7479 - val_loss: 0.5108 - val_accuracy: 0.7488
# Epoch 22/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5128 - accuracy: 0.7477 - val_loss: 0.5107 - val_accuracy: 0.7487
# Epoch 23/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5126 - accuracy: 0.7483 - val_loss: 0.5105 - val_accuracy: 0.7489
# Epoch 24/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5124 - accuracy: 0.7483 - val_loss: 0.5108 - val_accuracy: 0.7484
# Epoch 25/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5119 - accuracy: 0.7484 - val_loss: 0.5105 - val_accuracy: 0.7483
# Epoch 26/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5118 - accuracy: 0.7483 - val_loss: 0.5111 - val_accuracy: 0.7484
# Epoch 27/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5116 - accuracy: 0.7487 - val_loss: 0.5107 - val_accuracy: 0.7479
# Epoch 28/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5114 - accuracy: 0.7487 - val_loss: 0.5111 - val_accuracy: 0.7481
# Epoch 29/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5113 - accuracy: 0.7486 - val_loss: 0.5106 - val_accuracy: 0.7488
# Epoch 30/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5115 - accuracy: 0.7487 - val_loss: 0.5105 - val_accuracy: 0.7486
# Epoch 31/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5111 - accuracy: 0.7490 - val_loss: 0.5103 - val_accuracy: 0.7488
# Epoch 32/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5114 - accuracy: 0.7490 - val_loss: 0.5108 - val_accuracy: 0.7484
# Epoch 33/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5112 - accuracy: 0.7490 - val_loss: 0.5105 - val_accuracy: 0.7489
# Epoch 34/100
# 122/122 [==============================] - 2s 13ms/step - loss: 0.5107 - accuracy: 0.7491 - val_loss: 0.5106 - val_accuracy: 0.7486
# Epoch 35/100
# 122/122 [==============================] - 1s 12ms/step - loss: 0.5106 - accuracy: 0.7492 - val_loss: 0.5111 - val_accuracy: 0.7486
# Epoch 36/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5102 - accuracy: 0.7496 - val_loss: 0.5108 - val_accuracy: 0.7478
# Epoch 37/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5106 - accuracy: 0.7490 - val_loss: 0.5111 - val_accuracy: 0.7478
# Epoch 38/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5104 - accuracy: 0.7492 - val_loss: 0.5108 - val_accuracy: 0.7483
# Epoch 39/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5100 - accuracy: 0.7494 - val_loss: 0.5107 - val_accuracy: 0.7486
# Epoch 40/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5100 - accuracy: 0.7499 - val_loss: 0.5107 - val_accuracy: 0.7490
# Epoch 41/100
# 122/122 [==============================] - 2s 12ms/step - loss: 0.5100 - accuracy: 0.7498 - val_loss: 0.5107 - val_accuracy: 0.7485

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#HERE

import gc
gc.collect()
# Out:
# 5982

# %%
model.save("ROI_ar39_models/model_adc_5_10" + wireplane + "plane_nu_ROI.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 103/103 [==============================] - 1s 4ms/step - loss: 0.5262 - accuracy: 0.7227
# [0.5261521339416504, 0.7226928472518921]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 103/103 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 59/59 [==============================] - 0s 3ms/step
# 44/44 [==============================] - 0s 3ms/step
# CPU times: user 795 ms, sys: 506 ms, total: 1.3 s
# Wall time: 1.1 s

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([0.0000e+00, 1.2000e+01, 1.1068e+04, 3.6795e+04, 3.2736e+04,
#         2.4232e+04, 1.7967e+04, 1.3409e+04, 1.0178e+04, 7.6130e+03,
#         5.9150e+03, 4.6090e+03, 3.7680e+03, 3.0030e+03, 2.3910e+03,
#         1.9650e+03, 1.5510e+03, 1.2160e+03, 9.9700e+02, 5.7500e+02]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([    0.,     0.,  2345., 11141., 14366., 13906., 13664., 12521.,
#         11710., 10826., 10149.,  9813.,  9398.,  9426.,  9528., 10163.,
#         11248., 13167., 17977., 48652.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
a = [out for out in all_infer if out >= 0.94]

# %%
len(a)/len(all_infer)
# Out:
# 0.12771428571428572

# %%
all_infer
# Out:
# array([[0.55080163],
#        [0.3115658 ],
#        [0.23582049],
#        ...,
#        [0.4553365 ],
#        [0.13283767],
#        [0.99757665]], dtype=float32)

# %%
sigs_truth = []
sigs_pred = []

noise_truth = []
noise_pred = []

for i, truth in enumerate(all_y_test):
    if truth == 1:
        sigs_truth.append(truth)
        sigs_pred.append(all_infer[i])
    else:
        noise_truth.append(truth)
        noise_pred.append(all_infer[i])

# %%
print(len(sigs_truth), len(sigs_pred))
print(len(noise_truth), len(noise_pred))
# Out:
# 240000 240000
# 180000 180000

# %%
a = [out for out in sigs_pred if out >= 0.94]

# %%
len(a)/len(sigs_truth)
# Out:
# 0.22034583333333332

# %%
a = [out for out in noise_pred if out < 0.94]

# %%
len(a)/len(noise_truth)
# Out:
# 0.9957944444444444
