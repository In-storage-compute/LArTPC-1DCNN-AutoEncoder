# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
#!{sys.executable} -m pip install tensorflow-gpu==2.4
#!export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/bhawks/.conda/envs/dune-1dcnn/lib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
wireplane = "Z"
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/mean_Z.npy',
#  'processed_data/std_Z.npy',
#  'processed_data/x_test_Z.npy',
#  'processed_data/x_train_Z.npy',
#  'processed_data/y_test_AE_Z.npy',
#  'processed_data/y_test_ROI_Z.npy',
#  'processed_data/y_train_AE_Z.npy',
#  'processed_data/y_train_ROI_Z.npy']

# %%
x_test = np.load(filenames[2])
x_train = np.load(filenames[3])
y_test = np.load(filenames[5])
y_train = np.load(filenames[7])

# %%
#split train and valid sets (40k train 10k valid) 
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200) (20000, 200) (100000, 200)

# %%
np.save("latest_models/mean_"+wireplane+"_nu", mean)
np.save("latest_models/scale_"+wireplane+"_nu", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
  model = Sequential()  
  #first convolutional block
  model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
  model.add(MaxPooling1D(pool_size=2))

  #second convolutional block
  model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(0.1))
  
  #forth convolutional block                                      
  model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
  model.add(GlobalMaxPooling1D())
  model.add(Dropout(0.2)) 
    
  model.add(Flatten())

  
 
  model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
  return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
# %%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 9s 20ms/step - loss: 0.4931 - accuracy: 0.7565 - val_loss: 0.4107 - val_accuracy: 0.8101
# Epoch 2/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3887 - accuracy: 0.8239 - val_loss: 0.3684 - val_accuracy: 0.8361
# Epoch 3/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3639 - accuracy: 0.8392 - val_loss: 0.3541 - val_accuracy: 0.8443
# Epoch 4/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3551 - accuracy: 0.8454 - val_loss: 0.3526 - val_accuracy: 0.8478
# Epoch 5/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3518 - accuracy: 0.8480 - val_loss: 0.3462 - val_accuracy: 0.8497
# Epoch 6/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3492 - accuracy: 0.8494 - val_loss: 0.3454 - val_accuracy: 0.8511
# Epoch 7/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3474 - accuracy: 0.8504 - val_loss: 0.3435 - val_accuracy: 0.8507
# Epoch 8/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3470 - accuracy: 0.8515 - val_loss: 0.3471 - val_accuracy: 0.8493
# Epoch 9/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3460 - accuracy: 0.8512 - val_loss: 0.3430 - val_accuracy: 0.8499
# Epoch 10/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3433 - accuracy: 0.8524 - val_loss: 0.3412 - val_accuracy: 0.8511
# Epoch 11/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3425 - accuracy: 0.8529 - val_loss: 0.3394 - val_accuracy: 0.8522
# Epoch 12/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3415 - accuracy: 0.8527 - val_loss: 0.3383 - val_accuracy: 0.8525
# Epoch 13/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3399 - accuracy: 0.8541 - val_loss: 0.3373 - val_accuracy: 0.8514
# Epoch 14/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3391 - accuracy: 0.8538 - val_loss: 0.3364 - val_accuracy: 0.8526
# Epoch 15/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3377 - accuracy: 0.8549 - val_loss: 0.3362 - val_accuracy: 0.8529
# Epoch 16/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3365 - accuracy: 0.8550 - val_loss: 0.3345 - val_accuracy: 0.8540
# Epoch 17/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3357 - accuracy: 0.8561 - val_loss: 0.3343 - val_accuracy: 0.8540
# Epoch 18/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3348 - accuracy: 0.8562 - val_loss: 0.3346 - val_accuracy: 0.8541
# Epoch 19/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3338 - accuracy: 0.8568 - val_loss: 0.3331 - val_accuracy: 0.8547
# Epoch 20/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3341 - accuracy: 0.8562 - val_loss: 0.3328 - val_accuracy: 0.8558
# Epoch 21/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3333 - accuracy: 0.8566 - val_loss: 0.3321 - val_accuracy: 0.8554
# Epoch 22/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3317 - accuracy: 0.8573 - val_loss: 0.3318 - val_accuracy: 0.8551
# Epoch 23/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3321 - accuracy: 0.8579 - val_loss: 0.3316 - val_accuracy: 0.8561
# Epoch 24/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3311 - accuracy: 0.8577 - val_loss: 0.3304 - val_accuracy: 0.8566
# Epoch 25/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3296 - accuracy: 0.8580 - val_loss: 0.3323 - val_accuracy: 0.8562
# Epoch 26/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3308 - accuracy: 0.8575 - val_loss: 0.3311 - val_accuracy: 0.8556
# Epoch 27/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3290 - accuracy: 0.8580 - val_loss: 0.3338 - val_accuracy: 0.8555
# Epoch 28/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3312 - accuracy: 0.8576 - val_loss: 0.3299 - val_accuracy: 0.8573
# Epoch 29/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3288 - accuracy: 0.8591 - val_loss: 0.3292 - val_accuracy: 0.8563
# Epoch 30/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3279 - accuracy: 0.8589 - val_loss: 0.3297 - val_accuracy: 0.8576
# Epoch 31/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3275 - accuracy: 0.8592 - val_loss: 0.3290 - val_accuracy: 0.8568
# Epoch 32/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3271 - accuracy: 0.8601 - val_loss: 0.3289 - val_accuracy: 0.8571
# Epoch 33/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3269 - accuracy: 0.8593 - val_loss: 0.3303 - val_accuracy: 0.8562
# Epoch 34/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3259 - accuracy: 0.8603 - val_loss: 0.3300 - val_accuracy: 0.8566
# Epoch 35/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3254 - accuracy: 0.8606 - val_loss: 0.3305 - val_accuracy: 0.8569
# Epoch 36/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3266 - accuracy: 0.8597 - val_loss: 0.3283 - val_accuracy: 0.8576
# Epoch 37/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3265 - accuracy: 0.8596 - val_loss: 0.3289 - val_accuracy: 0.8579
# Epoch 38/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3258 - accuracy: 0.8599 - val_loss: 0.3284 - val_accuracy: 0.8573
# Epoch 39/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3252 - accuracy: 0.8602 - val_loss: 0.3285 - val_accuracy: 0.8581
# Epoch 40/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3251 - accuracy: 0.8605 - val_loss: 0.3288 - val_accuracy: 0.8571
# Epoch 41/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3242 - accuracy: 0.8613 - val_loss: 0.3280 - val_accuracy: 0.8582
# Epoch 42/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3240 - accuracy: 0.8610 - val_loss: 0.3281 - val_accuracy: 0.8573
# Epoch 43/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3241 - accuracy: 0.8612 - val_loss: 0.3276 - val_accuracy: 0.8575
# Epoch 44/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3236 - accuracy: 0.8614 - val_loss: 0.3281 - val_accuracy: 0.8572
# Epoch 45/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3234 - accuracy: 0.8614 - val_loss: 0.3292 - val_accuracy: 0.8575
# Epoch 46/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3227 - accuracy: 0.8624 - val_loss: 0.3289 - val_accuracy: 0.8579
# Epoch 47/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3227 - accuracy: 0.8619 - val_loss: 0.3278 - val_accuracy: 0.8574
# Epoch 48/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3224 - accuracy: 0.8620 - val_loss: 0.3275 - val_accuracy: 0.8575
# Epoch 49/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3220 - accuracy: 0.8620 - val_loss: 0.3286 - val_accuracy: 0.8567
# Epoch 50/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3214 - accuracy: 0.8622 - val_loss: 0.3276 - val_accuracy: 0.8576
# Epoch 51/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3213 - accuracy: 0.8625 - val_loss: 0.3282 - val_accuracy: 0.8574
# Epoch 52/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3206 - accuracy: 0.8628 - val_loss: 0.3297 - val_accuracy: 0.8576
# Epoch 53/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3220 - accuracy: 0.8623 - val_loss: 0.3275 - val_accuracy: 0.8579
# Epoch 54/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3193 - accuracy: 0.8637 - val_loss: 0.3274 - val_accuracy: 0.8577
# Epoch 55/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3194 - accuracy: 0.8639 - val_loss: 0.3275 - val_accuracy: 0.8579
# Epoch 56/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3200 - accuracy: 0.8628 - val_loss: 0.3274 - val_accuracy: 0.8580
# Epoch 57/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3188 - accuracy: 0.8629 - val_loss: 0.3288 - val_accuracy: 0.8578
# Epoch 58/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3194 - accuracy: 0.8630 - val_loss: 0.3274 - val_accuracy: 0.8582
# Epoch 59/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3186 - accuracy: 0.8633 - val_loss: 0.3277 - val_accuracy: 0.8576
# Epoch 60/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3185 - accuracy: 0.8636 - val_loss: 0.3277 - val_accuracy: 0.8569
# Epoch 61/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3178 - accuracy: 0.8636 - val_loss: 0.3283 - val_accuracy: 0.8563
# Epoch 62/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3179 - accuracy: 0.8637 - val_loss: 0.3277 - val_accuracy: 0.8579
# Epoch 63/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3180 - accuracy: 0.8644 - val_loss: 0.3283 - val_accuracy: 0.8576
# Wall time: 23.8 s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 5308

# %%
model.save("latest_models/model_" + wireplane + "plane_nu.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3238 - accuracy: 0.8609
# [0.32382798194885254, 0.8608899712562561]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 1ms/step
# Wall time: 513 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10, 8))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.9194468820485341

# %%
np.save("latest_results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("latest_results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("latest_results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 27ms/step
# Wall time: 188 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)
# Out:
# 0.9077615455232307

# %%
np.save("latest_results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("latest_results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("latest_results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 8ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# Wall time: 269 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([    0.,   539., 18797., 13855.,  6476.,  3584.,  1988.,  1225.,
#           888.,   649.,   467.,   333.,   291.,   239.,   184.,   136.,
#           106.,   105.,    76.,    62.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([    0.,    36.,  2547.,  2945.,  1881.,  1325.,  1072.,   811.,
#           682.,   613.,   515.,   552.,   464.,   419.,   462.,   483.,
#           522.,   634.,   870., 33167.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)
