# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
#!{sys.executable} -m pip install tensorflow-gpu==2.4
#!export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/bhawks/.conda/envs/dune-1dcnn/lib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
wireplane = "Z"
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/mean_Z.npy',
#  'processed_data/std_Z.npy',
#  'processed_data/x_test_Z.npy',
#  'processed_data/x_train_Z.npy',
#  'processed_data/y_test_AE_Z.npy',
#  'processed_data/y_test_ROI_Z.npy',
#  'processed_data/y_train_AE_Z.npy',
#  'processed_data/y_train_ROI_Z.npy']

# %%
x_test = np.load(filenames[2])
x_train = np.load(filenames[3])
y_test = np.load(filenames[5])
y_train = np.load(filenames[7])

# %%
#split train and valid sets (40k train 10k valid) 
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
np.save("latest_models/mean_"+wireplane+"_nu", mean)
np.save("latest_models/scale_"+wireplane+"_nu", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
  model = Sequential()  
  #first convolutional block
  model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
  model.add(MaxPooling1D(pool_size=2))

  #second convolutional block
  model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(0.1))
  
  #forth convolutional block                                      
  model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
  model.add(GlobalMaxPooling1D())
  model.add(Dropout(0.2)) 
    
  model.add(Flatten())

  
 
  model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
  return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
# %%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 9s 14ms/step - loss: 0.4635 - accuracy: 0.7983 - val_loss: 0.3449 - val_accuracy: 0.8544
# Epoch 2/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3116 - accuracy: 0.8713 - val_loss: 0.2764 - val_accuracy: 0.8892
# Epoch 3/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2703 - accuracy: 0.8938 - val_loss: 0.2552 - val_accuracy: 0.9013
# Epoch 4/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2578 - accuracy: 0.9004 - val_loss: 0.2488 - val_accuracy: 0.9038
# Epoch 5/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2514 - accuracy: 0.9040 - val_loss: 0.2440 - val_accuracy: 0.9064
# Epoch 6/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2491 - accuracy: 0.9054 - val_loss: 0.2425 - val_accuracy: 0.9069
# Epoch 7/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2474 - accuracy: 0.9057 - val_loss: 0.2403 - val_accuracy: 0.9081
# Epoch 8/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2449 - accuracy: 0.9075 - val_loss: 0.2389 - val_accuracy: 0.9087
# Epoch 9/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2441 - accuracy: 0.9075 - val_loss: 0.2387 - val_accuracy: 0.9091
# Epoch 10/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2436 - accuracy: 0.9079 - val_loss: 0.2378 - val_accuracy: 0.9108
# Epoch 11/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2421 - accuracy: 0.9082 - val_loss: 0.2393 - val_accuracy: 0.9105
# Epoch 12/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2421 - accuracy: 0.9083 - val_loss: 0.2363 - val_accuracy: 0.9104
# Epoch 13/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2413 - accuracy: 0.9087 - val_loss: 0.2352 - val_accuracy: 0.9115
# Epoch 14/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2399 - accuracy: 0.9092 - val_loss: 0.2351 - val_accuracy: 0.9112
# Epoch 15/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2396 - accuracy: 0.9097 - val_loss: 0.2351 - val_accuracy: 0.9110
# Epoch 16/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2395 - accuracy: 0.9094 - val_loss: 0.2363 - val_accuracy: 0.9110
# Epoch 17/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2399 - accuracy: 0.9093 - val_loss: 0.2342 - val_accuracy: 0.9117
# Epoch 18/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2372 - accuracy: 0.9105 - val_loss: 0.2349 - val_accuracy: 0.9116
# Epoch 19/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2367 - accuracy: 0.9104 - val_loss: 0.2330 - val_accuracy: 0.9117
# Epoch 20/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2365 - accuracy: 0.9111 - val_loss: 0.2319 - val_accuracy: 0.9121
# Epoch 21/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2360 - accuracy: 0.9115 - val_loss: 0.2316 - val_accuracy: 0.9119
# Epoch 22/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2354 - accuracy: 0.9115 - val_loss: 0.2348 - val_accuracy: 0.9119
# Epoch 23/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2355 - accuracy: 0.9114 - val_loss: 0.2311 - val_accuracy: 0.9127
# Epoch 24/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2342 - accuracy: 0.9121 - val_loss: 0.2316 - val_accuracy: 0.9123
# Epoch 25/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2334 - accuracy: 0.9122 - val_loss: 0.2293 - val_accuracy: 0.9133
# Epoch 26/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2331 - accuracy: 0.9122 - val_loss: 0.2314 - val_accuracy: 0.9122
# Epoch 27/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2325 - accuracy: 0.9123 - val_loss: 0.2295 - val_accuracy: 0.9133
# Epoch 28/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2313 - accuracy: 0.9127 - val_loss: 0.2275 - val_accuracy: 0.9138
# Epoch 29/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2313 - accuracy: 0.9128 - val_loss: 0.2286 - val_accuracy: 0.9130
# Epoch 30/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2301 - accuracy: 0.9131 - val_loss: 0.2285 - val_accuracy: 0.9137
# Epoch 31/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2304 - accuracy: 0.9130 - val_loss: 0.2266 - val_accuracy: 0.9148
# Epoch 32/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2295 - accuracy: 0.9136 - val_loss: 0.2260 - val_accuracy: 0.9147
# Epoch 33/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2282 - accuracy: 0.9139 - val_loss: 0.2255 - val_accuracy: 0.9146
# Epoch 34/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2281 - accuracy: 0.9145 - val_loss: 0.2258 - val_accuracy: 0.9143
# Epoch 35/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2282 - accuracy: 0.9133 - val_loss: 0.2249 - val_accuracy: 0.9148
# Epoch 36/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2266 - accuracy: 0.9147 - val_loss: 0.2244 - val_accuracy: 0.9152
# Epoch 37/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2257 - accuracy: 0.9146 - val_loss: 0.2242 - val_accuracy: 0.9151
# Epoch 38/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2256 - accuracy: 0.9155 - val_loss: 0.2243 - val_accuracy: 0.9161
# Epoch 39/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2247 - accuracy: 0.9153 - val_loss: 0.2237 - val_accuracy: 0.9160
# Epoch 40/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2247 - accuracy: 0.9155 - val_loss: 0.2233 - val_accuracy: 0.9151
# Epoch 41/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2245 - accuracy: 0.9154 - val_loss: 0.2238 - val_accuracy: 0.9154
# Epoch 42/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2244 - accuracy: 0.9157 - val_loss: 0.2232 - val_accuracy: 0.9158
# Epoch 43/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2235 - accuracy: 0.9159 - val_loss: 0.2226 - val_accuracy: 0.9159
# Epoch 44/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2229 - accuracy: 0.9161 - val_loss: 0.2225 - val_accuracy: 0.9164
# Epoch 45/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2219 - accuracy: 0.9166 - val_loss: 0.2226 - val_accuracy: 0.9158
# Epoch 46/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2220 - accuracy: 0.9163 - val_loss: 0.2237 - val_accuracy: 0.9155
# Epoch 47/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2229 - accuracy: 0.9167 - val_loss: 0.2239 - val_accuracy: 0.9161
# Epoch 48/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2218 - accuracy: 0.9164 - val_loss: 0.2222 - val_accuracy: 0.9159
# Epoch 49/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2217 - accuracy: 0.9165 - val_loss: 0.2220 - val_accuracy: 0.9162
# Epoch 50/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2217 - accuracy: 0.9171 - val_loss: 0.2232 - val_accuracy: 0.9161
# Epoch 51/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2220 - accuracy: 0.9162 - val_loss: 0.2220 - val_accuracy: 0.9161
# Epoch 52/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2207 - accuracy: 0.9166 - val_loss: 0.2218 - val_accuracy: 0.9161
# Epoch 53/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2191 - accuracy: 0.9174 - val_loss: 0.2219 - val_accuracy: 0.9166
# Epoch 54/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2206 - accuracy: 0.9173 - val_loss: 0.2216 - val_accuracy: 0.9169
# Epoch 55/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2196 - accuracy: 0.9177 - val_loss: 0.2233 - val_accuracy: 0.9165
# Epoch 56/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2203 - accuracy: 0.9175 - val_loss: 0.2216 - val_accuracy: 0.9161
# Epoch 57/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2191 - accuracy: 0.9171 - val_loss: 0.2221 - val_accuracy: 0.9168
# Epoch 58/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2195 - accuracy: 0.9175 - val_loss: 0.2230 - val_accuracy: 0.9161
# Epoch 59/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2202 - accuracy: 0.9175 - val_loss: 0.2219 - val_accuracy: 0.9168
# Epoch 60/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2194 - accuracy: 0.9177 - val_loss: 0.2216 - val_accuracy: 0.9163
# Epoch 61/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2182 - accuracy: 0.9181 - val_loss: 0.2219 - val_accuracy: 0.9168
# Wall time: 25.1 s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 5462

# %%
model.save("latest_models/model_" + wireplane + "plane_nu.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2164 - accuracy: 0.9185
# [0.21636593341827393, 0.9185400009155273]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 2ms/step
# Wall time: 492 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10, 8))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.9587377735383635

# %%
np.save("latest_results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("latest_results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("latest_results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 10ms/step
# Wall time: 102 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)
# Out:
# 0.9539805704002822

# %%
np.save("latest_results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("latest_results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("latest_results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 13ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# Wall time: 269 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([  538., 28508., 10524.,  4142.,  2014.,  1184.,   741.,   506.,
#           368.,   299.,   231.,   187.,   164.,   108.,   109.,   105.,
#            85.,    77.,    66.,    44.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([1.7000e+01, 2.0280e+03, 1.4680e+03, 9.4300e+02, 6.5600e+02,
#         4.9200e+02, 4.3600e+02, 3.4700e+02, 3.2700e+02, 2.5600e+02,
#         2.8700e+02, 2.7100e+02, 2.8200e+02, 2.4600e+02, 2.9300e+02,
#         3.3700e+02, 3.6400e+02, 4.6600e+02, 6.6100e+02, 3.9823e+04]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)
