# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
#!{sys.executable} -m pip install tensorflow-gpu==2.4
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/vlian/anaconda3/envs/dune-1dcnn/lib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from tqdm import trange

# %% [markdown]
# # Load data, select ADC

# %%
wireplane = "Z"
sig_name = wireplane+"-signal"
cln_name = wireplane+"-clnsig"
np.random.seed(42)
nticks = 200
max_mels = 11000
min_edp = 50000
ADC_MIN = 3
ADC_MAX = 10
waveform_scaler = StandardScaler()

def extract_wave(data):
    string = 'tck_'
    waveforms = []
    #Here I extract a column in each iteration and append to list
    for i in range(nticks):
        waveforms.append(data[string+str(i)].astype(np.int16))
    #convert to numpy ndarray
    waveforms = np.array(waveforms).astype(np.int16)
    #since raws and columns are inverted we need to transpose it
    return np.transpose(waveforms)

def extract_peak(data):
    #extract index of peak
    idx = np.array([data['stp0'], data['adc0'], data['stp1'], data['adc1'], data['stp2'], data['adc2'], data['stp3'], data['adc3'], data['stp4'], data['adc4']])
    #same as before
    return np.transpose(idx)

def extract_peak_info(data):
    peaks_pos = [data['stp0'], data['stp1'], data['stp2'], data['stp3'], data['stp4']]
    adcs = [data['adc0'], data['adc1'], data['adc2'], data['adc3'], data['adc4']]
    return np.array(peaks_pos).T, np.array(adcs).T

def extract_nel_info(data):
    nels = [data['nel0'], data['nel1'], data['nel2'], data['nel3'], data['nel4']]
    return np.array(nels).T

def extract_edp_info(data):
    edp = [data['edp0'], data['edp1'], data['edp2'], data['edp3'], data['edp4']]
    return np.array(edp).T

def filter_signals(data, clean_data, filter_adc_max=True):
    #edp_mask = np.all(extract_edp_info(data)>min_edp, axis = 1)
    #nel_mask = np.all(extract_nel_info(data)<max_mels, axis = 1)
    #pd.DataFrame(np.all(extract_edp_info(data)>min_edp, axis = 1)).describe()
    #print(edp_mask)
    #print(nel_mask)
    #filter_mask = nel_mask #np.logical_and(edp_mask,nel_mask) 
    filtered_data = data#[filter_mask]
    cln_filtered_data = clean_data#[filter_mask]
    
    filtered_peak = extract_peak_info(filtered_data)[1]
    if filter_adc_max:
        peak_mask = np.any(filtered_peak>ADC_MIN, axis = 1)
        peak_mask &= np.any(filtered_peak<ADC_MAX, axis = 1)
    else:
        peak_mask = np.any(filtered_peak>ADC_MIN, axis = 1)
    
    filtered_data = filtered_data[peak_mask]
    cln_filtered_data = cln_filtered_data[peak_mask]
    
    return filtered_data, cln_filtered_data, filtered_peak

def get_std_waveforms(data):
    #Extract and scale waveform data (passthrough rn)
    raw_waveforms = extract_wave(data)
    #print(raw_waveforms) 
    #scaled_waveforms = waveform_scaler.fit_transform(raw_waveforms)
    return raw_waveforms

# %%
#Load Training Data
#path = "../../dunesnb/1dcnn/train/train/nu_cc/"
#path2 = "../../dunesnb/1dcnn/train/train/nu_es/"

# NEW DATA SET WITH
path = "../../Workspace/new_data/train_v1/nu_cc/"
path2 = "../../Workspace/new_data/train_v1/nu_cc/"

filenames1 = [path+f for f in listdir(path) if (isfile(join(path, f)) and sig_name in f)]
filenames1 = [path+f for f in listdir(path) if (isfile(join(path, f)) and sig_name in f)]
clean_filenames1 = [path+f for f in listdir(path) if (isfile(join(path, f)) and cln_name in f)]
filenames2 = [path2+f for f in listdir(path2) if (isfile(join(path2, f)) and sig_name in f)]
clean_filenames2 = [path2+f for f in listdir(path2) if (isfile(join(path2, f)) and cln_name in f)]

filenames =  filenames1+filenames2
clean_filenames = clean_filenames1+clean_filenames2

combined_data = np.concatenate([np.load(fname) for fname in filenames])
combined_clean_data = np.concatenate([np.load(fname) for fname in clean_filenames])

# %%
noise_path = "../../Workspace/new_data/train_v1/noise/"
noise_filenames = [f for f in listdir(noise_path) if (isfile(join(noise_path, f)) and wireplane in f)]
print(len(noise_filenames))

combined_noise = np.concatenate([np.load(noise_path+fname) for fname in noise_filenames])
print(len(combined_noise))
# Out:
# 50
# 100000

# %% [markdown]
# # Train/Noise Data Preprocessing

# %%
from sklearn.utils import shuffle
print(combined_data.shape[0])
#Filter out tiny signals < ADC_MIN, but leave big signals to test on (incl > ADC_MAX)
combined_data, combined_clean_data, peak = filter_signals(combined_data, combined_clean_data, False)
print(combined_data.shape[0])

#split train and test sets (~50k ea before filtering) 
combined_data, x_test_data, combined_clean_data, x_test_clean  = train_test_split(
    combined_data, combined_clean_data, test_size=0.5, shuffle=True
)
print(combined_data.shape[0])
#filter data and extract waveforms of filtered data
combined_data, combined_clean_data, peak = filter_signals(combined_data, combined_clean_data, True)
signal_waveforms = get_std_waveforms(combined_data)
print(combined_data.shape[0])
#extract waveforms of noise
noise_waveforms = get_std_waveforms(combined_noise)

#extract waveforms of test data
test_signal_waveforms = get_std_waveforms(x_test_data)
print(test_signal_waveforms.shape[0])
# Out:
# 229418
# 133494
# 66747
# 66387
# 66747

# %%
print(test_signal_waveforms.shape, signal_waveforms.shape, noise_waveforms.shape)
# Out:
# (66747, 200) (66387, 200) (100000, 200)

# %%
for idx in range(5):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30, 4))
    ax1.plot(signal_waveforms[idx], color='blue')

    ax2.plot(noise_waveforms[idx], color='orange')
    plt.show()

# %%
#generate y data (assuming all radiologicals contain signal, all noise does not)
y_noise_full = np.zeros(noise_waveforms.shape[0])
y_signal = np.ones(signal_waveforms.shape[0])
y_test_signal = np.ones(test_signal_waveforms.shape[0])

# split test and train noise datasets (50k)
x_noise_train, x_noise_test, y_noise_train, y_noise_test = train_test_split(
    noise_waveforms, y_noise_full, test_size=0.5, shuffle=True
)

#Shuffle signal waveforms to be safe
signal_waveforms, y_signal = shuffle(signal_waveforms,y_signal)

#Shuffle test waveformst to be safe
x_test, y_test = shuffle(test_signal_waveforms,y_test_signal)

# %%
print(x_noise_train.shape, signal_waveforms.shape, x_test.shape)
# Out:
# (50000, 200) (66387, 200) (66747, 200)

# %%
for idx in range(14205-4, 14205):
    fig, (ax1) = plt.subplots(figsize=(15, 4))
    ax1.plot(signal_waveforms[idx], color='blue', label= "target: " + str(y_signal[idx]))
    ax1.legend()
    plt.show()

# %%
for idx in range(4):
    fig, (ax1) = plt.subplots(figsize=(15, 4))
    ax1.plot(x_noise_train[idx], color='blue', label= "target: " + str(y_noise_train[idx]))
    ax1.legend()
    plt.show()

# %%
#Select First n signal samples from (shuffled) set of signals where n = noise samples for balanced train set 
x_train = np.concatenate((signal_waveforms[:int(x_noise_train.shape[0])], x_noise_train))
y_train = np.concatenate((y_signal[:int(x_noise_train.shape[0])], y_noise_train))

x_test = np.concatenate((x_test[:int(x_noise_test.shape[0])], x_noise_test))
y_test = np.concatenate((y_test_signal[:int(x_noise_test.shape[0])], y_noise_test))


# extra train shuffle for good measure 
x_train, y_train = shuffle(x_train,y_train)
# extra test shuffle for good measure 
x_test, y_test = shuffle(x_test,y_test)

#split train and valid sets (40k train 10k valid) 
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_valid.shape, y_valid.shape)
# Out:
# (80000, 200) (80000,) (100000, 200) (100000,) (20000, 200) (20000,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std
#cc_x_test_scaled = (cc_x_test-mean)/std 
#es_x_test_scaled = (es_x_test-mean)/std 
time_periods = 200

# %%
np.save("models/mean_"+wireplane+"_nu", mean)
np.save("models/scale_"+wireplane+"_nu", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %% [markdown]
# # 1D-CNN LArTPC Waveform Recognition

# %%
time_periods = 200
def create_model():
  model = Sequential()  
  #first convolutional block
  model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
  model.add(MaxPooling1D(pool_size=2))

  #second convolutional block
  model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(0.1))
  
  #forth convolutional block                                      
  model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
  model.add(GlobalMaxPooling1D())
  model.add(Dropout(0.2)) 
    
  model.add(Flatten())

  
 
  model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
  return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
#cc_x_test_scaled = cc_x_test_scaled.reshape(cc_x_test_scaled.shape[0], cc_x_test_scaled.shape[1], 1)
#es_x_test_scaled = es_x_test_scaled.reshape(es_x_test_scaled.shape[0], es_x_test_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
# %%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 12s 28ms/step - loss: 0.4820 - accuracy: 0.7829 - val_loss: 0.3527 - val_accuracy: 0.8500
# Epoch 2/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.3259 - accuracy: 0.8646 - val_loss: 0.2892 - val_accuracy: 0.8812
# Epoch 3/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2892 - accuracy: 0.8853 - val_loss: 0.2711 - val_accuracy: 0.8945
# Epoch 4/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2777 - accuracy: 0.8909 - val_loss: 0.2659 - val_accuracy: 0.8975
# Epoch 5/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2726 - accuracy: 0.8937 - val_loss: 0.2605 - val_accuracy: 0.8992
# Epoch 6/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2692 - accuracy: 0.8956 - val_loss: 0.2589 - val_accuracy: 0.9014
# Epoch 7/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2670 - accuracy: 0.8965 - val_loss: 0.2576 - val_accuracy: 0.9008
# Epoch 8/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2657 - accuracy: 0.8972 - val_loss: 0.2555 - val_accuracy: 0.9023
# Epoch 9/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2643 - accuracy: 0.8977 - val_loss: 0.2544 - val_accuracy: 0.9032
# Epoch 10/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2628 - accuracy: 0.8988 - val_loss: 0.2525 - val_accuracy: 0.9033
# Epoch 11/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2619 - accuracy: 0.8985 - val_loss: 0.2528 - val_accuracy: 0.9038
# Epoch 12/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2614 - accuracy: 0.8990 - val_loss: 0.2511 - val_accuracy: 0.9045
# Epoch 13/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2603 - accuracy: 0.8995 - val_loss: 0.2527 - val_accuracy: 0.9030
# Epoch 14/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2594 - accuracy: 0.8995 - val_loss: 0.2496 - val_accuracy: 0.9051
# Epoch 15/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2580 - accuracy: 0.8998 - val_loss: 0.2531 - val_accuracy: 0.9038
# Epoch 16/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2571 - accuracy: 0.9005 - val_loss: 0.2488 - val_accuracy: 0.9054
# Epoch 17/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2561 - accuracy: 0.9006 - val_loss: 0.2462 - val_accuracy: 0.9057
# Epoch 18/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2548 - accuracy: 0.9011 - val_loss: 0.2454 - val_accuracy: 0.9054
# Epoch 19/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2541 - accuracy: 0.9010 - val_loss: 0.2449 - val_accuracy: 0.9060
# Epoch 20/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2538 - accuracy: 0.9014 - val_loss: 0.2454 - val_accuracy: 0.9060
# Epoch 21/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2534 - accuracy: 0.9015 - val_loss: 0.2434 - val_accuracy: 0.9064
# Epoch 22/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2520 - accuracy: 0.9022 - val_loss: 0.2433 - val_accuracy: 0.9078
# Epoch 23/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2512 - accuracy: 0.9030 - val_loss: 0.2440 - val_accuracy: 0.9063
# Epoch 24/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2507 - accuracy: 0.9025 - val_loss: 0.2418 - val_accuracy: 0.9077
# Epoch 25/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2499 - accuracy: 0.9029 - val_loss: 0.2412 - val_accuracy: 0.9076
# Epoch 26/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2490 - accuracy: 0.9028 - val_loss: 0.2406 - val_accuracy: 0.9074
# Epoch 27/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.9035 - val_loss: 0.2411 - val_accuracy: 0.9075
# Epoch 28/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2484 - accuracy: 0.9033 - val_loss: 0.2406 - val_accuracy: 0.9079
# Epoch 29/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2485 - accuracy: 0.9036 - val_loss: 0.2397 - val_accuracy: 0.9079
# Epoch 30/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2474 - accuracy: 0.9043 - val_loss: 0.2400 - val_accuracy: 0.9083
# Epoch 31/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2471 - accuracy: 0.9043 - val_loss: 0.2395 - val_accuracy: 0.9085
# Epoch 32/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2473 - accuracy: 0.9041 - val_loss: 0.2394 - val_accuracy: 0.9085
# Epoch 33/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2460 - accuracy: 0.9050 - val_loss: 0.2400 - val_accuracy: 0.9074
# Epoch 34/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2464 - accuracy: 0.9042 - val_loss: 0.2386 - val_accuracy: 0.9086
# Epoch 35/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2451 - accuracy: 0.9045 - val_loss: 0.2377 - val_accuracy: 0.9086
# Epoch 36/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2446 - accuracy: 0.9051 - val_loss: 0.2381 - val_accuracy: 0.9087
# Epoch 37/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2456 - accuracy: 0.9047 - val_loss: 0.2374 - val_accuracy: 0.9088
# Epoch 38/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2438 - accuracy: 0.9049 - val_loss: 0.2374 - val_accuracy: 0.9086
# Epoch 39/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2434 - accuracy: 0.9058 - val_loss: 0.2377 - val_accuracy: 0.9085
# Epoch 40/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2434 - accuracy: 0.9056 - val_loss: 0.2373 - val_accuracy: 0.9093
# Epoch 41/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2426 - accuracy: 0.9061 - val_loss: 0.2381 - val_accuracy: 0.9080
# Epoch 42/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2431 - accuracy: 0.9054 - val_loss: 0.2373 - val_accuracy: 0.9091
# Epoch 43/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2421 - accuracy: 0.9065 - val_loss: 0.2408 - val_accuracy: 0.9058
# Epoch 44/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2426 - accuracy: 0.9062 - val_loss: 0.2363 - val_accuracy: 0.9099
# Epoch 45/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2417 - accuracy: 0.9061 - val_loss: 0.2361 - val_accuracy: 0.9094
# Epoch 46/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2412 - accuracy: 0.9067 - val_loss: 0.2360 - val_accuracy: 0.9099
# Epoch 47/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2405 - accuracy: 0.9065 - val_loss: 0.2360 - val_accuracy: 0.9101
# Epoch 48/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2399 - accuracy: 0.9068 - val_loss: 0.2353 - val_accuracy: 0.9096
# Epoch 49/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2399 - accuracy: 0.9073 - val_loss: 0.2357 - val_accuracy: 0.9090
# Epoch 50/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2393 - accuracy: 0.9075 - val_loss: 0.2353 - val_accuracy: 0.9093
# Epoch 51/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2389 - accuracy: 0.9075 - val_loss: 0.2353 - val_accuracy: 0.9097
# Epoch 52/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2390 - accuracy: 0.9073 - val_loss: 0.2346 - val_accuracy: 0.9096
# Epoch 53/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2392 - accuracy: 0.9066 - val_loss: 0.2349 - val_accuracy: 0.9096
# Epoch 54/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2386 - accuracy: 0.9082 - val_loss: 0.2343 - val_accuracy: 0.9104
# Epoch 55/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2387 - accuracy: 0.9075 - val_loss: 0.2359 - val_accuracy: 0.9079
# Epoch 56/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2384 - accuracy: 0.9075 - val_loss: 0.2346 - val_accuracy: 0.9099
# Epoch 57/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2382 - accuracy: 0.9077 - val_loss: 0.2344 - val_accuracy: 0.9103
# Epoch 58/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2376 - accuracy: 0.9082 - val_loss: 0.2343 - val_accuracy: 0.9100
# Epoch 59/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2373 - accuracy: 0.9080 - val_loss: 0.2343 - val_accuracy: 0.9100
# Epoch 60/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2361 - accuracy: 0.9092 - val_loss: 0.2340 - val_accuracy: 0.9100
# Epoch 61/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2365 - accuracy: 0.9085 - val_loss: 0.2340 - val_accuracy: 0.9099
# Epoch 62/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2356 - accuracy: 0.9087 - val_loss: 0.2351 - val_accuracy: 0.9086
# Epoch 63/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2365 - accuracy: 0.9086 - val_loss: 0.2342 - val_accuracy: 0.9098
# Epoch 64/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2352 - accuracy: 0.9087 - val_loss: 0.2339 - val_accuracy: 0.9093
# Epoch 65/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2351 - accuracy: 0.9089 - val_loss: 0.2375 - val_accuracy: 0.9106
# Epoch 66/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2362 - accuracy: 0.9087 - val_loss: 0.2351 - val_accuracy: 0.9104
# Epoch 67/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2346 - accuracy: 0.9089 - val_loss: 0.2337 - val_accuracy: 0.9096
# Epoch 68/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2341 - accuracy: 0.9097 - val_loss: 0.2333 - val_accuracy: 0.9100
# Epoch 69/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2335 - accuracy: 0.9087 - val_loss: 0.2332 - val_accuracy: 0.9104
# Epoch 70/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2330 - accuracy: 0.9093 - val_loss: 0.2335 - val_accuracy: 0.9107
# Epoch 71/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2337 - accuracy: 0.9098 - val_loss: 0.2346 - val_accuracy: 0.9109
# Epoch 72/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2339 - accuracy: 0.9092 - val_loss: 0.2337 - val_accuracy: 0.9103
# Epoch 73/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2332 - accuracy: 0.9099 - val_loss: 0.2336 - val_accuracy: 0.9097
# Epoch 74/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2321 - accuracy: 0.9104 - val_loss: 0.2332 - val_accuracy: 0.9107
# Epoch 75/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2320 - accuracy: 0.9096 - val_loss: 0.2338 - val_accuracy: 0.9092
# Epoch 76/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2313 - accuracy: 0.9107 - val_loss: 0.2331 - val_accuracy: 0.9106
# Epoch 77/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2313 - accuracy: 0.9105 - val_loss: 0.2340 - val_accuracy: 0.9090
# Epoch 78/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2310 - accuracy: 0.9107 - val_loss: 0.2338 - val_accuracy: 0.9094
# Epoch 79/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2317 - accuracy: 0.9095 - val_loss: 0.2335 - val_accuracy: 0.9111
# Epoch 80/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2309 - accuracy: 0.9110 - val_loss: 0.2336 - val_accuracy: 0.9106
# Epoch 81/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2304 - accuracy: 0.9107 - val_loss: 0.2333 - val_accuracy: 0.9100
# Wall time: 30.7 s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 22956

# %%
model.save("models/" + wireplane + "plane_nu.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2391 - accuracy: 0.9077
# [0.2391330897808075, 0.9077100157737732]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 1ms/step
# Wall time: 408 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10, 8))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.9567506145594912

# %%
np.save("results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 37ms/step
# Wall time: 214 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)
# Out:
# 0.9522361489219602

# %%
np.save("results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 2ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 9ms/step
# 13/13 [==============================] - 0s 2ms/step
# Wall time: 466 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([  765., 25497., 10826.,  4559.,  2454.,  1523.,   987.,   703.,
#           505.,   410.,   329.,   269.,   195.,   195.,   144.,   132.,
#           140.,   110.,   117.,   140.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([3.6000e+01, 1.9740e+03, 1.5510e+03, 9.8700e+02, 7.5500e+02,
#         5.3100e+02, 5.1100e+02, 4.0000e+02, 3.8900e+02, 3.2400e+02,
#         3.3900e+02, 2.9300e+02, 3.0100e+02, 3.3600e+02, 3.1200e+02,
#         3.2400e+02, 3.7800e+02, 5.2200e+02, 6.8000e+02, 3.9057e+04]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)
