# %% [markdown]
# train autoencoder using 1DCNN roi finder

# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
wireplane = "U"
np.random.seed(42)
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/mean_U.npy',
#  'processed_data/std_U.npy',
#  'processed_data/x_test_U.npy',
#  'processed_data/x_train_U.npy',
#  'processed_data/y_test_AE_U.npy',
#  'processed_data/y_test_ROI_U.npy',
#  'processed_data/y_train_AE_U.npy',
#  'processed_data/y_train_ROI_U.npy']

# %%
x_test = np.load(filenames[2])
x_train = np.load(filenames[3])
y_test = np.load(filenames[4])
y_train = np.load(filenames[6])

# %%
for idx in range(4,6):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train[idx],color='blue', label='signal+noise')
    ax1.plot(y_train[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()

    plt.show()

# %%
mean = x_train.mean()
std = x_train.std()
np.save("latest_models/mean_AE_"+wireplane+"_nu", mean)
np.save("latest_models/scale_AE_"+wireplane+"_nu", std)

# %%
x_train_scaled = (x_train-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
y_train_scaled = []
for i in range(len(y_train)):
    if sum(y_train[i]) == 0:
        y_train_scaled.append(y_train[i])
    else:
        scaled = (y_train[i]-mean)/std
        y_train_scaled.append(scaled)
y_train_scaled = np.array(y_train_scaled)

# %%
y_test_scaled = []
for i in range(len(y_test)):
    if sum(y_test[i]) == 0:
        y_test_scaled.append(y_test[i])
    else:
        scaled = (y_test[i]-mean)/std
        y_test_scaled.append(scaled)
y_test_scaled = np.array(y_test_scaled)

# %%
for idx in range(4,6):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train_scaled[idx],color='blue', label='signal+noise')
    ax1.plot(y_train_scaled[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()
    print(sum(y_train_scaled[idx]))
    plt.show()
# Out:
# -1.2418376635852035
# 0.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Dense,Flatten, AveragePooling1D
from tensorflow.keras.layers import Input,  UpSampling1D
from tensorflow.keras.models import Model
#from keras import backend as K

# %%
from tensorflow.keras.models import load_model
model = load_model('latest_models/model_' + wireplane + 'plane_nu.h5')

# %%
for i,layer in enumerate(model.layers):
  print(i,layer.name)
# Out:
# 0 conv1d
# 1 max_pooling1d
# 2 conv1d_1
# 3 max_pooling1d_1
# 4 dropout
# 5 conv1d_2
# 6 global_max_pooling1d
# 7 dropout_1
# 8 flatten
# 9 wavrec_out

# %%
time_periods = 200
input_wave = Input(shape=(x_train_scaled.shape[1], 1)) 
x = Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", weights=model.layers[0].get_weights() , input_shape=(time_periods,1))(input_wave)
x = MaxPooling1D(pool_size=2)(x)
 
#second convolutional block
x = Conv1D(filters=32, kernel_size=5, strides=2, weights=model.layers[2].get_weights(), activation = "relu", )(x)
x = MaxPooling1D(pool_size=2)(x)

encoded = Conv1D(filters=64, kernel_size=9, weights=model.layers[5].get_weights(), activation = "relu")(x)


x = Conv1D(filters=64, kernel_size=9, padding = "same", activation = "relu")(encoded)
x = UpSampling1D(4)(x)

x = Conv1D(filters=32, kernel_size=5, padding = "same", activation = "relu")(x)
x = UpSampling1D(3)(x)

x = Conv1D(filters=16, kernel_size=3,  activation = "relu")(x)
x = UpSampling1D(6)(x)

decoded = Conv1D(filters=1, kernel_size=5,  activation = "linear")(x)



autoencoder = Model(input_wave, decoded)

# %%
for i,layer in enumerate(autoencoder.layers):                                      
  print(i,layer.name)
# Out:
# 0 input_1
# 1 conv1d
# 2 max_pooling1d
# 3 conv1d_1
# 4 max_pooling1d_1
# 5 conv1d_2
# 6 conv1d_3
# 7 up_sampling1d
# 8 conv1d_4
# 9 up_sampling1d_1
# 10 conv1d_5
# 11 up_sampling1d_2
# 12 conv1d_6

# %%
# see what happens when we unfreeze more layers of the 1dcnn
for layer in autoencoder.layers[:6]:                                               
    layer.trainable=False                                                          
for layer in autoencoder.layers[6:]:                                               
    layer.trainable=True                                                           
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 1)]          0
#
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  conv1d_3 (Conv1D)           (None, 3, 64)             36928
#
#  up_sampling1d (UpSampling1D  (None, 12, 64)           0
#  )
#
#  conv1d_4 (Conv1D)           (None, 12, 32)            10272
#
#  up_sampling1d_1 (UpSampling  (None, 36, 32)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 34, 16)            1552
#
#  up_sampling1d_2 (UpSampling  (None, 204, 16)          0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 200, 1)            81
#
# =================================================================
# Total params: 69,985
# Trainable params: 48,833
# Non-trainable params: 21,152
# _________________________________________________________________

# %%
# %%time
history = autoencoder.fit(x_train_scaled,                                                              
                    y_train_scaled,                                                            
                    batch_size=2048,                                              
                    epochs=100,                                                      
                    callbacks=None, # callbacks=callbacks_list,                         
                    validation_split=0.2, shuffle=False,                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 7s 33ms/step - loss: 0.7494 - val_loss: 0.5992
# Epoch 2/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.5431 - val_loss: 0.4507
# Epoch 3/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.3971 - val_loss: 0.3200
# Epoch 4/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.2971 - val_loss: 0.2498
# Epoch 5/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.2396 - val_loss: 0.2037
# Epoch 6/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.2006 - val_loss: 0.1729
# Epoch 7/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1755 - val_loss: 0.1548
# Epoch 8/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1582 - val_loss: 0.1432
# Epoch 9/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1474 - val_loss: 0.1367
# Epoch 10/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1383 - val_loss: 0.1274
# Epoch 11/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1294 - val_loss: 0.1184
# Epoch 12/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1234 - val_loss: 0.1142
# Epoch 13/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1182 - val_loss: 0.1094
# Epoch 14/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1136 - val_loss: 0.1055
# Epoch 15/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1099 - val_loss: 0.1027
# Epoch 16/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1074 - val_loss: 0.0995
# Epoch 17/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1038 - val_loss: 0.0970
# Epoch 18/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1010 - val_loss: 0.0947
# Epoch 19/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0986 - val_loss: 0.0925
# Epoch 20/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0975 - val_loss: 0.0929
# Epoch 21/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0940 - val_loss: 0.0886
# Epoch 22/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0919 - val_loss: 0.0873
# Epoch 23/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0919 - val_loss: 0.0856
# Epoch 24/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0885 - val_loss: 0.0853
# Epoch 25/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0865 - val_loss: 0.0823
# Epoch 26/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0849 - val_loss: 0.0809
# Epoch 27/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0837 - val_loss: 0.0802
# Epoch 28/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0824 - val_loss: 0.0790
# Epoch 29/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0811 - val_loss: 0.0777
# Epoch 30/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0800 - val_loss: 0.0763
# Epoch 31/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0789 - val_loss: 0.0760
# Epoch 32/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0785 - val_loss: 0.0751
# Epoch 33/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0770 - val_loss: 0.0741
# Epoch 34/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0768 - val_loss: 0.0743
# Epoch 35/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0760 - val_loss: 0.0721
# Epoch 36/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0748 - val_loss: 0.0722
# Epoch 37/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0745 - val_loss: 0.0710
# Epoch 38/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0735 - val_loss: 0.0705
# Epoch 39/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0730 - val_loss: 0.0693
# Epoch 40/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0722 - val_loss: 0.0687
# Epoch 41/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0715 - val_loss: 0.0681
# Epoch 42/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0714 - val_loss: 0.0699
# Epoch 43/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0707 - val_loss: 0.0701
# Epoch 44/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0693 - val_loss: 0.0670
# Epoch 45/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0685 - val_loss: 0.0674
# Epoch 46/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0681 - val_loss: 0.0677
# Epoch 47/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0677 - val_loss: 0.0676
# Epoch 48/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0671 - val_loss: 0.0660
# Epoch 49/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0667 - val_loss: 0.0657
# Epoch 50/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0663 - val_loss: 0.0649
# Epoch 51/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0659 - val_loss: 0.0648
# Epoch 52/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0653 - val_loss: 0.0633
# Epoch 53/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0648 - val_loss: 0.0627
# Epoch 54/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0654 - val_loss: 0.0644
# Epoch 55/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0642 - val_loss: 0.0619
# Epoch 56/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0634 - val_loss: 0.0613
# Epoch 57/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0627 - val_loss: 0.0607
# Epoch 58/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0621 - val_loss: 0.0601
# Epoch 59/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0615 - val_loss: 0.0596
# Epoch 60/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0611 - val_loss: 0.0593
# Epoch 61/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0605 - val_loss: 0.0592
# Epoch 62/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0610 - val_loss: 0.0595
# Epoch 63/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0605 - val_loss: 0.0591
# Epoch 64/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0603 - val_loss: 0.0600
# Epoch 65/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0608 - val_loss: 0.0622
# Epoch 66/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0617 - val_loss: 0.0590
# Epoch 67/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0593 - val_loss: 0.0585
# Epoch 68/100
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0585 - val_loss: 0.0583
# Epoch 69/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0581 - val_loss: 0.0575
# Epoch 70/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0576 - val_loss: 0.0570
# Epoch 71/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0575 - val_loss: 0.0571
# Epoch 72/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0571 - val_loss: 0.0569
# Epoch 73/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0570 - val_loss: 0.0570
# Epoch 74/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0565 - val_loss: 0.0563
# Epoch 75/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0565 - val_loss: 0.0557
# Epoch 76/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0556 - val_loss: 0.0561
# Epoch 77/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0555 - val_loss: 0.0554
# Epoch 78/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0556 - val_loss: 0.0553
# Epoch 79/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0550 - val_loss: 0.0556
# Epoch 80/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0551 - val_loss: 0.0549
# Epoch 81/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0549 - val_loss: 0.0554
# Epoch 82/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0546 - val_loss: 0.0546
# Epoch 83/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0544 - val_loss: 0.0548
# Epoch 84/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0542 - val_loss: 0.0540
# Epoch 85/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0538 - val_loss: 0.0545
# Epoch 86/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0534 - val_loss: 0.0536
# Epoch 87/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0531 - val_loss: 0.0536
# Epoch 88/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0528 - val_loss: 0.0533
# Epoch 89/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0526 - val_loss: 0.0531
# Epoch 90/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0521 - val_loss: 0.0530
# Epoch 91/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0520 - val_loss: 0.0524
# Epoch 92/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0514 - val_loss: 0.0528
# Epoch 93/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0514 - val_loss: 0.0523
# Epoch 94/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0511 - val_loss: 0.0524
# Epoch 95/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0508 - val_loss: 0.0521
# Epoch 96/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0507 - val_loss: 0.0520
# Epoch 97/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0505 - val_loss: 0.0523
# Epoch 98/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0506 - val_loss: 0.0520
# Epoch 99/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0502 - val_loss: 0.0523
# Epoch 100/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0502 - val_loss: 0.0515
# Wall time: 51 s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Loss',fontsize=15)                                            
plt.ylabel('Loss (MSE)', fontsize=12)                                                 
plt.xlabel('Training Epoch', fontsize=12)                                                                                                                       
plt.legend(fontsize=12)                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 14999

# %%
autoencoder.save("latest_models/model_AE_" + wireplane + "plane_nu.h5")

# %%
autoencoder.evaluate(x_test_scaled, y_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0608
# 0.060787804424762726

# %%
# %%time
y = autoencoder.predict(x_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 5ms/step
# Wall time: 401 ms

# %%
y = y.reshape(y.shape[0], y.shape[1])
#y = std*y + mean

# %%
#y_test_rescaled = std*y_test_scaled + mean

# %%
for idx in range(10):
    fig, (ax1) = plt.subplots(figsize=(12, 8), facecolor='white')
    ax1.plot(y_test_scaled[idx],color='blue', label='target')
    ax1.plot(y[idx],color='m',alpha=0.7, label='model prediction')
    ax1.plot(x_test_scaled[idx], color='orange',alpha=0.7, label = 'original input')
    ax1.set_title("trained using clean signals as target", fontsize=15)
    ax1.legend()
    

    plt.show()
    print(sum(y[idx])/len(y[idx]))
    print(y[idx].std())
# Out:
# 0.00948425568640232
# 1.8626451e-09
# 0.00948425568640232
# 1.8626451e-09
# 0.00948425568640232
# 1.8626451e-09
# 0.00948425568640232
# 1.8626451e-09
# 0.007054483974352479
# 0.008560506
# 0.008286578881088644
# 0.059902266
# 0.00948425568640232
# 1.8626451e-09
# 0.005076438933610916
# 1.582144
# 0.015645758751779794
# 1.1264564
# 0.009375113621354103
# 0.0006026845
