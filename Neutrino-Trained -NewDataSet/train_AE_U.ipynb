# %% [markdown]
# train autoencoder using 1DCNN roi finder

# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
wireplane = "U"
np.random.seed(42)
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/mean_U.npy',
#  'processed_data/std_U.npy',
#  'processed_data/x_test_U.npy',
#  'processed_data/x_train_U.npy',
#  'processed_data/y_test_AE_U.npy',
#  'processed_data/y_test_ROI_U.npy',
#  'processed_data/y_train_AE_U.npy',
#  'processed_data/y_train_ROI_U.npy']

# %%
x_test = np.load(filenames[2])
x_train = np.load(filenames[3])
y_test = np.load(filenames[4])
y_train = np.load(filenames[6])

# %%
for idx in range(4,6):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train[idx],color='blue', label='signal+noise')
    ax1.plot(y_train[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()

    plt.show()

# %%
mean = x_train.mean()
std = x_train.std()
np.save("latest_models/mean_AE_"+wireplane+"_nu", mean)
np.save("latest_models/scale_AE_"+wireplane+"_nu", std)

# %%
x_train_scaled = (x_train-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
y_train_scaled = []
for i in range(len(y_train)):
    if sum(y_train[i]) == 0:
        y_train_scaled.append(y_train[i])
    else:
        scaled = (y_train[i]-mean)/std
        y_train_scaled.append(scaled)
y_train_scaled = np.array(y_train_scaled)

# %%
y_test_scaled = []
for i in range(len(y_test)):
    if sum(y_test[i]) == 0:
        y_test_scaled.append(y_test[i])
    else:
        scaled = (y_test[i]-mean)/std
        y_test_scaled.append(scaled)
y_test_scaled = np.array(y_test_scaled)

# %%
for idx in range(4,6):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train_scaled[idx],color='blue', label='signal+noise')
    ax1.plot(y_train_scaled[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()
    print(sum(y_train_scaled[idx]))
    plt.show()
# Out:
# -1.2418376635852035
# 0.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Dense,Flatten, AveragePooling1D
from tensorflow.keras.layers import Input,  UpSampling1D
from tensorflow.keras.models import Model
#from keras import backend as K

# %%
from tensorflow.keras.models import load_model
model = load_model('latest_models/model_' + wireplane + 'plane_nu.h5')

# %%
for i,layer in enumerate(model.layers):
  print(i,layer.name)
# Out:
# 0 conv1d
# 1 max_pooling1d
# 2 conv1d_1
# 3 max_pooling1d_1
# 4 dropout
# 5 conv1d_2
# 6 global_max_pooling1d
# 7 dropout_1
# 8 flatten
# 9 wavrec_out

# %%
time_periods = 200
input_wave = Input(shape=(x_train_scaled.shape[1], 1)) 
x = Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", weights=model.layers[0].get_weights() , input_shape=(time_periods,1))(input_wave)
x = MaxPooling1D(pool_size=2)(x)
 
#second convolutional block
x = Conv1D(filters=32, kernel_size=5, strides=2, weights=model.layers[2].get_weights(), activation = "relu", )(x)
x = MaxPooling1D(pool_size=2)(x)

encoded = Conv1D(filters=64, kernel_size=9, weights=model.layers[5].get_weights(), activation = "relu")(x)


x = Conv1D(filters=64, kernel_size=9, padding = "same", activation = "relu")(encoded)
x = UpSampling1D(4)(x)

x = Conv1D(filters=32, kernel_size=5, padding = "same", activation = "relu")(x)
x = UpSampling1D(3)(x)

x = Conv1D(filters=16, kernel_size=3,  activation = "relu")(x)
x = UpSampling1D(6)(x)

decoded = Conv1D(filters=1, kernel_size=5,  activation = "linear")(x)



autoencoder = Model(input_wave, decoded)

# %%
for i,layer in enumerate(autoencoder.layers):                                      
  print(i,layer.name)
# Out:
# 0 input_1
# 1 conv1d
# 2 max_pooling1d
# 3 conv1d_1
# 4 max_pooling1d_1
# 5 conv1d_2
# 6 conv1d_3
# 7 up_sampling1d
# 8 conv1d_4
# 9 up_sampling1d_1
# 10 conv1d_5
# 11 up_sampling1d_2
# 12 conv1d_6

# %%
for layer in autoencoder.layers[:6]:                                               
    layer.trainable=False                                                          
for layer in autoencoder.layers[6:]:                                               
    layer.trainable=True                                                           
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 1)]          0
#
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  conv1d_3 (Conv1D)           (None, 3, 64)             36928
#
#  up_sampling1d (UpSampling1D  (None, 12, 64)           0
#  )
#
#  conv1d_4 (Conv1D)           (None, 12, 32)            10272
#
#  up_sampling1d_1 (UpSampling  (None, 36, 32)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 34, 16)            1552
#
#  up_sampling1d_2 (UpSampling  (None, 204, 16)          0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 200, 1)            81
#
# =================================================================
# Total params: 69,985
# Trainable params: 48,833
# Non-trainable params: 21,152
# _________________________________________________________________

# %%
# %%time
history = autoencoder.fit(x_train_scaled,                                                              
                    y_train_scaled,                                                            
                    batch_size=1024,                                              
                    epochs=100,                                                      
                    callbacks=None, # callbacks=callbacks_list,                         
                    validation_split=0.2, shuffle=False,                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 4s 12ms/step - loss: 0.5594 - val_loss: 0.3425
# Epoch 2/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.2540 - val_loss: 0.1813
# Epoch 3/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.1709 - val_loss: 0.1535
# Epoch 4/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.1474 - val_loss: 0.1386
# Epoch 5/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.1362 - val_loss: 0.1257
# Epoch 6/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.1268 - val_loss: 0.1177
# Epoch 7/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.1197 - val_loss: 0.1119
# Epoch 8/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.1137 - val_loss: 0.1079
# Epoch 9/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.1087 - val_loss: 0.1048
# Epoch 10/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.1044 - val_loss: 0.0995
# Epoch 11/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.1014 - val_loss: 0.0999
# Epoch 12/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0977 - val_loss: 0.0940
# Epoch 13/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0963 - val_loss: 0.0899
# Epoch 14/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0927 - val_loss: 0.0875
# Epoch 15/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0893 - val_loss: 0.0855
# Epoch 16/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0864 - val_loss: 0.0844
# Epoch 17/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0847 - val_loss: 0.0845
# Epoch 18/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0827 - val_loss: 0.0809
# Epoch 19/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0808 - val_loss: 0.0794
# Epoch 20/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0792 - val_loss: 0.0780
# Epoch 21/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0774 - val_loss: 0.0770
# Epoch 22/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0763 - val_loss: 0.0760
# Epoch 23/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0749 - val_loss: 0.0756
# Epoch 24/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0740 - val_loss: 0.0752
# Epoch 25/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0729 - val_loss: 0.0739
# Epoch 26/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0718 - val_loss: 0.0728
# Epoch 27/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0716 - val_loss: 0.0707
# Epoch 28/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0703 - val_loss: 0.0689
# Epoch 29/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0690 - val_loss: 0.0679
# Epoch 30/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0681 - val_loss: 0.0678
# Epoch 31/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0671 - val_loss: 0.0660
# Epoch 32/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0658 - val_loss: 0.0659
# Epoch 33/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0655 - val_loss: 0.0656
# Epoch 34/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0649 - val_loss: 0.0655
# Epoch 35/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0641 - val_loss: 0.0642
# Epoch 36/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0626 - val_loss: 0.0628
# Epoch 37/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0620 - val_loss: 0.0641
# Epoch 38/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0618 - val_loss: 0.0621
# Epoch 39/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0608 - val_loss: 0.0612
# Epoch 40/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0607 - val_loss: 0.0618
# Epoch 41/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0612 - val_loss: 0.0623
# Epoch 42/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0609 - val_loss: 0.0604
# Epoch 43/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0594 - val_loss: 0.0617
# Epoch 44/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0596 - val_loss: 0.0606
# Epoch 45/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0594 - val_loss: 0.0600
# Epoch 46/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0590 - val_loss: 0.0609
# Epoch 47/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0581 - val_loss: 0.0602
# Epoch 48/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0574 - val_loss: 0.0600
# Epoch 49/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0569 - val_loss: 0.0589
# Epoch 50/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0570 - val_loss: 0.0582
# Epoch 51/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0561 - val_loss: 0.0574
# Epoch 52/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0555 - val_loss: 0.0569
# Epoch 53/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0556 - val_loss: 0.0579
# Epoch 54/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0553 - val_loss: 0.0560
# Epoch 55/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0547 - val_loss: 0.0555
# Epoch 56/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0539 - val_loss: 0.0554
# Epoch 57/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0538 - val_loss: 0.0557
# Epoch 58/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0538 - val_loss: 0.0551
# Epoch 59/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0533 - val_loss: 0.0553
# Epoch 60/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0532 - val_loss: 0.0555
# Epoch 61/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0530 - val_loss: 0.0548
# Epoch 62/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0535 - val_loss: 0.0548
# Epoch 63/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0536 - val_loss: 0.0544
# Epoch 64/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0527 - val_loss: 0.0544
# Epoch 65/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0523 - val_loss: 0.0534
# Epoch 66/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0517 - val_loss: 0.0533
# Epoch 67/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0516 - val_loss: 0.0534
# Epoch 68/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0517 - val_loss: 0.0532
# Epoch 69/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0514 - val_loss: 0.0532
# Epoch 70/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0519 - val_loss: 0.0543
# Epoch 71/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0518 - val_loss: 0.0544
# Epoch 72/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0513 - val_loss: 0.0542
# Epoch 73/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0511 - val_loss: 0.0534
# Epoch 74/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0510 - val_loss: 0.0538
# Epoch 75/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0508 - val_loss: 0.0534
# Epoch 76/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0504 - val_loss: 0.0532
# Epoch 77/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0501 - val_loss: 0.0526
# Epoch 78/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0500 - val_loss: 0.0528
# Epoch 79/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0499 - val_loss: 0.0524
# Epoch 80/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0497 - val_loss: 0.0517
# Epoch 81/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0495 - val_loss: 0.0523
# Epoch 82/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0493 - val_loss: 0.0524
# Epoch 83/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0488 - val_loss: 0.0521
# Epoch 84/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0488 - val_loss: 0.0524
# Epoch 85/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0483 - val_loss: 0.0513
# Epoch 86/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0480 - val_loss: 0.0509
# Epoch 87/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0479 - val_loss: 0.0514
# Epoch 88/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0476 - val_loss: 0.0510
# Epoch 89/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0477 - val_loss: 0.0508
# Epoch 90/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0474 - val_loss: 0.0502
# Epoch 91/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0468 - val_loss: 0.0501
# Epoch 92/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0472 - val_loss: 0.0501
# Epoch 93/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0476 - val_loss: 0.0517
# Epoch 94/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0473 - val_loss: 0.0507
# Epoch 95/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0470 - val_loss: 0.0500
# Epoch 96/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0466 - val_loss: 0.0499
# Epoch 97/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0467 - val_loss: 0.0503
# Epoch 98/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0470 - val_loss: 0.0494
# Epoch 99/100
# 79/79 [==============================] - 1s 9ms/step - loss: 0.0462 - val_loss: 0.0500
# Epoch 100/100
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0460 - val_loss: 0.0497
# Wall time: 1min 11s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Loss',fontsize=15)                                            
plt.ylabel('Loss (MSE)', fontsize=12)                                                 
plt.xlabel('Training Epoch', fontsize=12)                                                                                                                       
plt.legend(fontsize=12)                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 14845

# %%
autoencoder.save("latest_models/model_AE_" + wireplane + "plane_nu.h5")

# %%
autoencoder.evaluate(x_test_scaled, y_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0588
# 0.05882152169942856

# %%
# %%time
y = autoencoder.predict(x_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 5ms/step
# Wall time: 470 ms

# %%
y = y.reshape(y.shape[0], y.shape[1])
#y = std*y + mean

# %%
#y_test_rescaled = std*y_test_scaled + mean

# %%
for idx in range(10):
    fig, (ax1) = plt.subplots(figsize=(12, 8), facecolor='white')
    ax1.plot(y_test_scaled[idx],color='blue', label='target')
    ax1.plot(y[idx],color='m',alpha=0.7, label='model prediction')
    ax1.plot(x_test_scaled[idx], color='orange',alpha=0.7, label = 'original input')
    ax1.set_title("trained using clean signals as target", fontsize=15)
    ax1.legend()
    

    plt.show()
    print(sum(y[idx])/len(y[idx]))
    print(y[idx].std())
# Out:
# 0.00819888524711132
# 9.313226e-10
# 0.00819888524711132
# 9.313226e-10
# 0.006530568557791412
# 0.019869423
# 0.00819888524711132
# 9.313226e-10
# 0.008691392652690411
# 0.0016181333
# 0.001810006774030626
# 0.05268267
# 0.00819888524711132
# 9.313226e-10
# -0.005990254073403776
# 1.5810138
# -0.05378411553800106
# 1.1207602
# 0.008981721987947822
# 0.009558675
