# %% [markdown]
# train autoencoder using 1DCNN roi finder

# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split 
from sklearn.utils import shuffle

# %%
wireplane = "Z"
np.random.seed(42)
path = 'processed_data/current/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/current/mean_Z.npy',
#  'processed_data/current/std_Z.npy',
#  'processed_data/current/x_test_Z.npy',
#  'processed_data/current/x_train_Z.npy',
#  'processed_data/current/y_test_AE_Z.npy',
#  'processed_data/current/y_test_ROI_Z.npy',
#  'processed_data/current/y_train_AE_Z.npy',
#  'processed_data/current/y_train_ROI_Z.npy']

# %%
x_test = np.load(filenames[2])
x_train = np.load(filenames[3])
y_test = np.load(filenames[4])
y_train = np.load(filenames[6])

# %%
for idx in range(8,14):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train[idx],color='blue', label='signal+noise')
    ax1.plot(y_train[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()

    plt.show()

# %%
mean = x_train.mean()
std = x_train.std()
#np.save("latest_models/mean_AE_"+wireplane+"_nu", mean)
#np.save("latest_models/scale_AE_"+wireplane+"_nu", std)

# %%
x_train_scaled = (x_train-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
y_train_scaled = []
for i in range(len(y_train)):
    if sum(y_train[i]) == 0:
        y_train_scaled.append(y_train[i])
    else:
        scaled = (y_train[i]-mean)/std
        y_train_scaled.append(scaled)
y_train_scaled = np.array(y_train_scaled)

# %%
y_test_scaled = []
for i in range(len(y_test)):
    if sum(y_test[i]) == 0:
        y_test_scaled.append(y_test[i])
    else:
        scaled = (y_test[i]-mean)/std
        y_test_scaled.append(scaled)
y_test_scaled = np.array(y_test_scaled)

# %%
for idx in range(11,14):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train_scaled[idx],color='blue', label='signal+noise')
    ax1.plot(y_train_scaled[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()
    print(sum(y_train_scaled[idx]))
    plt.show()
# Out:
# 105.45339920827469
# -23.38887128247449
# 0.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Dense,Flatten, AveragePooling1D
from tensorflow.keras.layers import Input,  UpSampling1D
from tensorflow.keras.models import Model
#from keras import backend as K

# %%
from tensorflow.keras.models import load_model
model = load_model('latest_models/model_' + wireplane + 'plane_nu.h5')

# %%
for i,layer in enumerate(model.layers):
  print(i,layer.name)
# Out:
# 0 conv1d
# 1 max_pooling1d
# 2 conv1d_1
# 3 max_pooling1d_1
# 4 dropout
# 5 conv1d_2
# 6 global_max_pooling1d
# 7 dropout_1
# 8 flatten
# 9 wavrec_out

# %%
time_periods = 200
input_wave = Input(shape=(x_train_scaled.shape[1], 1)) 
x = Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", weights=model.layers[0].get_weights() , input_shape=(time_periods,1))(input_wave)
x = MaxPooling1D(pool_size=2)(x)
 
#second convolutional block
x = Conv1D(filters=32, kernel_size=5, strides=2, weights=model.layers[2].get_weights(), activation = "relu", )(x)
x = MaxPooling1D(pool_size=2)(x)

encoded = Conv1D(filters=64, kernel_size=9, weights=model.layers[5].get_weights(), activation = "relu")(x)


x = Conv1D(filters=64, kernel_size=9, padding = "same", activation = "relu")(encoded)
x = UpSampling1D(4)(x)

x = Conv1D(filters=32, kernel_size=5, padding = "same", activation = "relu")(x)
x = UpSampling1D(3)(x)

x = Conv1D(filters=16, kernel_size=3,  activation = "relu")(x)
x = UpSampling1D(6)(x)

decoded = Conv1D(filters=1, kernel_size=5,  activation = "linear")(x)



autoencoder = Model(input_wave, decoded)

# %%
for i,layer in enumerate(autoencoder.layers):                                      
  print(i,layer.name)
# Out:
# 0 input_1
# 1 conv1d
# 2 max_pooling1d
# 3 conv1d_1
# 4 max_pooling1d_1
# 5 conv1d_2
# 6 conv1d_3
# 7 up_sampling1d
# 8 conv1d_4
# 9 up_sampling1d_1
# 10 conv1d_5
# 11 up_sampling1d_2
# 12 conv1d_6

# %%
# see what happens when we unfreeze more layers of the 1dcnn
for layer in autoencoder.layers[:6]:                                               
    layer.trainable=False                                                          
for layer in autoencoder.layers[6:]:                                               
    layer.trainable=True                                                           
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 1)]          0
#
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  conv1d_3 (Conv1D)           (None, 3, 64)             36928
#
#  up_sampling1d (UpSampling1D  (None, 12, 64)           0
#  )
#
#  conv1d_4 (Conv1D)           (None, 12, 32)            10272
#
#  up_sampling1d_1 (UpSampling  (None, 36, 32)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 34, 16)            1552
#
#  up_sampling1d_2 (UpSampling  (None, 204, 16)          0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 200, 1)            81
#
# =================================================================
# Total params: 69,985
# Trainable params: 48,833
# Non-trainable params: 21,152
# _________________________________________________________________

# %%
# %%time
history = autoencoder.fit(x_train_scaled,                                                              
                    y_train_scaled,                                                            
                    batch_size=2048,                                              
                    epochs=100,                                                      
                    callbacks=None, # callbacks=callbacks_list,                         
                    validation_split=0.2, shuffle=False,                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 5s 104ms/step - loss: 0.5979 - val_loss: 0.3208
# Epoch 2/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.2426 - val_loss: 0.1881
# Epoch 3/100
# 40/40 [==============================] - 4s 104ms/step - loss: 0.1645 - val_loss: 0.1611
# Epoch 4/100
# 40/40 [==============================] - 4s 106ms/step - loss: 0.1362 - val_loss: 0.1364
# Epoch 5/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.1195 - val_loss: 0.1212
# Epoch 6/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1094 - val_loss: 0.1070
# Epoch 7/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1000 - val_loss: 0.0979
# Epoch 8/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0928 - val_loss: 0.0934
# Epoch 9/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0876 - val_loss: 0.0877
# Epoch 10/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0821 - val_loss: 0.0832
# Epoch 11/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0800 - val_loss: 0.0878
# Epoch 12/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0768 - val_loss: 0.0788
# Epoch 13/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0736 - val_loss: 0.0748
# Epoch 14/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0692 - val_loss: 0.0723
# Epoch 15/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0674 - val_loss: 0.0698
# Epoch 16/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0646 - val_loss: 0.0665
# Epoch 17/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0630 - val_loss: 0.0666
# Epoch 18/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0620 - val_loss: 0.0651
# Epoch 19/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0628 - val_loss: 0.0653
# Epoch 20/100
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0615 - val_loss: 0.0668
# Epoch 21/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0614 - val_loss: 0.0706
# Epoch 22/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0620 - val_loss: 0.0630
# Epoch 23/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0585 - val_loss: 0.0646
# Epoch 24/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0566 - val_loss: 0.0639
# Epoch 25/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0548 - val_loss: 0.0606
# Epoch 26/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0534 - val_loss: 0.0572
# Epoch 27/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0519 - val_loss: 0.0561
# Epoch 28/100
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0509 - val_loss: 0.0554
# Epoch 29/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0504 - val_loss: 0.0551
# Epoch 30/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0507 - val_loss: 0.0548
# Epoch 31/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0505 - val_loss: 0.0552
# Epoch 32/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0498 - val_loss: 0.0559
# Epoch 33/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0493 - val_loss: 0.0546
# Epoch 34/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0487 - val_loss: 0.0536
# Epoch 35/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0476 - val_loss: 0.0532
# Epoch 36/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0471 - val_loss: 0.0532
# Epoch 37/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0468 - val_loss: 0.0519
# Epoch 38/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0459 - val_loss: 0.0518
# Epoch 39/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0453 - val_loss: 0.0520
# Epoch 40/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0450 - val_loss: 0.0507
# Epoch 41/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0444 - val_loss: 0.0513
# Epoch 42/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0451 - val_loss: 0.0517
# Epoch 43/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0445 - val_loss: 0.0520
# Epoch 44/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0476 - val_loss: 0.0561
# Epoch 45/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0491 - val_loss: 0.0566
# Epoch 46/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0452 - val_loss: 0.0563
# Epoch 47/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0451 - val_loss: 0.0512
# Epoch 48/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0441 - val_loss: 0.0510
# Epoch 49/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0445 - val_loss: 0.0513
# Epoch 50/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0432 - val_loss: 0.0498
# Epoch 51/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0419 - val_loss: 0.0494
# Epoch 52/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0412 - val_loss: 0.0485
# Epoch 53/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0408 - val_loss: 0.0488
# Epoch 54/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0413 - val_loss: 0.0468
# Epoch 55/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0403 - val_loss: 0.0488
# Epoch 56/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0402 - val_loss: 0.0481
# Epoch 57/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0402 - val_loss: 0.0469
# Epoch 58/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0399 - val_loss: 0.0480
# Epoch 59/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0421 - val_loss: 0.0501
# Epoch 60/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0417 - val_loss: 0.0484
# Epoch 61/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0398 - val_loss: 0.0480
# Epoch 62/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0393 - val_loss: 0.0476
# Epoch 63/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0391 - val_loss: 0.0460
# Epoch 64/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0384 - val_loss: 0.0456
# Epoch 65/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0388 - val_loss: 0.0460
# Epoch 66/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0387 - val_loss: 0.0466
# Epoch 67/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0382 - val_loss: 0.0481
# Epoch 68/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0388 - val_loss: 0.0468
# Epoch 69/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0376 - val_loss: 0.0461
# Epoch 70/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0374 - val_loss: 0.0463
# Epoch 71/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0371 - val_loss: 0.0453
# Epoch 72/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0373 - val_loss: 0.0481
# Epoch 73/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0377 - val_loss: 0.0462
# Epoch 74/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0372 - val_loss: 0.0452
# Epoch 75/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0370 - val_loss: 0.0457
# Epoch 76/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0366 - val_loss: 0.0453
# Epoch 77/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0375 - val_loss: 0.0460
# Epoch 78/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0375 - val_loss: 0.0498
# Epoch 79/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0375 - val_loss: 0.0489
# Epoch 80/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0377 - val_loss: 0.0499
# Epoch 81/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0386 - val_loss: 0.0463
# Epoch 82/100
# 40/40 [==============================] - 5s 117ms/step - loss: 0.0373 - val_loss: 0.0470
# Epoch 83/100
# 40/40 [==============================] - 5s 122ms/step - loss: 0.0387 - val_loss: 0.0457
# Epoch 84/100
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0380 - val_loss: 0.0497
# Epoch 85/100
# 40/40 [==============================] - 4s 102ms/step - loss: 0.0371 - val_loss: 0.0470
# Epoch 86/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0362 - val_loss: 0.0440
# Epoch 87/100
# 40/40 [==============================] - 5s 118ms/step - loss: 0.0355 - val_loss: 0.0428
# Epoch 88/100
# 40/40 [==============================] - 4s 111ms/step - loss: 0.0351 - val_loss: 0.0440
# Epoch 89/100
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0355 - val_loss: 0.0451
# Epoch 90/100
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0354 - val_loss: 0.0457
# Epoch 91/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0349 - val_loss: 0.0435
# Epoch 92/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0348 - val_loss: 0.0467
# Epoch 93/100
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0363 - val_loss: 0.0473
# Epoch 94/100
# 40/40 [==============================] - 4s 106ms/step - loss: 0.0359 - val_loss: 0.0458
# Epoch 95/100
# 40/40 [==============================] - 4s 106ms/step - loss: 0.0361 - val_loss: 0.0433
# Epoch 96/100
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0350 - val_loss: 0.0425
# Epoch 97/100
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0340 - val_loss: 0.0446
# Epoch 98/100
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0346 - val_loss: 0.0425
# Epoch 99/100
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0339 - val_loss: 0.0418
# Epoch 100/100
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0335 - val_loss: 0.0413
# Wall time: 6min 36s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Loss',fontsize=15)                                            
plt.ylabel('Loss (MSE)', fontsize=12)                                                 
plt.xlabel('Training Epoch', fontsize=12)                                                                                                                       
plt.legend(fontsize=12)                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 12987

# %%
autoencoder.save("latest_models/model_AE_" + wireplane + "plane_nu.h5")

# %%
autoencoder.evaluate(x_test_scaled, y_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 1s 43ms/step - loss: 0.0453
# 0.04526272416114807

# %%
# %%time
y = autoencoder.predict(x_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 1s 41ms/step
# Wall time: 1.23 s

# %%
y = y.reshape(y.shape[0], y.shape[1])
#y = std*y + mean

# %%
#y_test_rescaled = std*y_test_scaled + mean

# %%
for idx in range(10):
    fig, (ax1) = plt.subplots(figsize=(12, 8), facecolor='white')
    ax1.plot(y_test_scaled[idx],color='blue', label='target')
    ax1.plot(y[idx],color='m',alpha=0.7, label='model prediction')
    ax1.plot(x_test_scaled[idx], color='orange',alpha=0.7, label = 'original input')
    ax1.set_title("trained using clean signals as target", fontsize=15)
    ax1.legend()
    

    plt.show()
    print(sum(y[idx])/len(y[idx]))
    print(y[idx].std())
# Out:
# -0.01853453379124403
# 0.007620589
# -0.018713061399757862
# 0.0060534813
# -0.06076167199760676
# 0.1837282
# -0.03260016165673733
# 0.016634014
# -0.00791585199534893
# 0.00836609
# -0.009498832151293754
# 0.0081434455
# -0.018030943498015404
# 0.008166761
# -0.033345520198345184
# 0.011689157
# 0.005766745470464229
# 0.47407368
# -0.04330776205286384
# 0.01880836
