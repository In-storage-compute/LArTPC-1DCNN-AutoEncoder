# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
#!{sys.executable} -m pip install tensorflow-gpu==2.4
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/vlian/anaconda3/envs/dune-1dcnn/lib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from tqdm import trange

# %% [markdown]
# # Load data, select ADC

# %%
wireplane = "Z"
sig_name = wireplane+"-signal"
cln_name = wireplane+"-clnsig"
np.random.seed(42)
nticks = 200
max_mels = 11000
min_edp = 50000
ADC_MIN = 3
ADC_MAX = 10
waveform_scaler = StandardScaler()

def extract_wave(data):
    string = 'tck_'
    waveforms = []
    #Here I extract a column in each iteration and append to list
    for i in range(nticks):
        waveforms.append(data[string+str(i)].astype(np.int16))
    #convert to numpy ndarray
    waveforms = np.array(waveforms).astype(np.int16)
    #since raws and columns are inverted we need to transpose it
    return np.transpose(waveforms)

def extract_peak(data):
    #extract index of peak
    idx = np.array([data['stp0'], data['adc0'], data['stp1'], data['adc1'], data['stp2'], data['adc2'], data['stp3'], data['adc3'], data['stp4'], data['adc4']])
    #same as before
    return np.transpose(idx)

def extract_peak_info(data):
    peaks_pos = [data['stp0'], data['stp1'], data['stp2'], data['stp3'], data['stp4']]
    adcs = [data['adc0'], data['adc1'], data['adc2'], data['adc3'], data['adc4']]
    return np.array(peaks_pos).T, np.array(adcs).T

def extract_nel_info(data):
    nels = [data['nel0'], data['nel1'], data['nel2'], data['nel3'], data['nel4']]
    return np.array(nels).T

def extract_edp_info(data):
    edp = [data['edp0'], data['edp1'], data['edp2'], data['edp3'], data['edp4']]
    return np.array(edp).T

def filter_signals(data, clean_data, filter_adc_max=True):
    #edp_mask = np.all(extract_edp_info(data)>min_edp, axis = 1)
    #nel_mask = np.all(extract_nel_info(data)<max_mels, axis = 1)
    #pd.DataFrame(np.all(extract_edp_info(data)>min_edp, axis = 1)).describe()
    #print(edp_mask)
    #print(nel_mask)
    #filter_mask = nel_mask #np.logical_and(edp_mask,nel_mask) 
    filtered_data = data#[filter_mask]
    cln_filtered_data = clean_data#[filter_mask]
    
    filtered_peak = extract_peak_info(filtered_data)[1]
    if filter_adc_max:
        peak_mask = np.any(filtered_peak>ADC_MIN, axis = 1)
        peak_mask &= np.any(filtered_peak<ADC_MAX, axis = 1)
    else:
        peak_mask = np.any(filtered_peak>ADC_MIN, axis = 1)
    
    filtered_data = filtered_data[peak_mask]
    cln_filtered_data = cln_filtered_data[peak_mask]
    
    return filtered_data, cln_filtered_data, filtered_peak

def get_std_waveforms(data):
    #Extract and scale waveform data (passthrough rn)
    raw_waveforms = extract_wave(data)
    #print(raw_waveforms) 
    #scaled_waveforms = waveform_scaler.fit_transform(raw_waveforms)
    return raw_waveforms

# %%
#Load Training Data
#path = "../../dunesnb/1dcnn/train/train/nu_cc/"
#path2 = "../../dunesnb/1dcnn/train/train/nu_es/"

# NEW DATA SET WITH
path_cc = "../../Workspace/new_data/train_v1/nu_cc/"
path_es = "../../Workspace/new_data/train_v1/nu_es/"

filenames1 = [path_cc+f for f in listdir(path_cc) if (isfile(join(path_cc, f)) and sig_name in f)]
clean_filenames1 = [path_cc+f for f in listdir(path_cc) if (isfile(join(path_cc, f)) and cln_name in f)]
filenames2 = [path_es+f for f in listdir(path_es) if (isfile(join(path_es, f)) and sig_name in f)]
clean_filenames2 = [path_es+f for f in listdir(path_es) if (isfile(join(path_es, f)) and cln_name in f)]

filenames =  filenames1+filenames2
clean_filenames = clean_filenames1+clean_filenames2

combined_data = np.concatenate([np.load(fname) for fname in filenames])
combined_clean_data = np.concatenate([np.load(fname) for fname in clean_filenames])

# %%
noise_path = "../../Workspace/new_data/train_v1/noise/"
noise_filenames = [f for f in listdir(noise_path) if (isfile(join(noise_path, f)) and wireplane in f)]
print(len(noise_filenames))

combined_noise = np.concatenate([np.load(noise_path+fname) for fname in noise_filenames])
print(len(combined_noise))
# Out:
# 50
# 100000

# %% [markdown]
# # Train/Noise Data Preprocessing

# %%
from sklearn.utils import shuffle
print(combined_data.shape[0])
#Filter out tiny signals < ADC_MIN, but leave big signals to test on (incl > ADC_MAX)
combined_data, combined_clean_data, peak = filter_signals(combined_data, combined_clean_data, False)
print(combined_data.shape[0])

#split train and test sets (~50k ea before filtering) 
combined_data, x_test_data, combined_clean_data, x_test_clean  = train_test_split(
    combined_data, combined_clean_data, test_size=0.5, shuffle=True
)
print(combined_data.shape[0])
#filter data and extract waveforms of filtered data
combined_data, combined_clean_data, peak = filter_signals(combined_data, combined_clean_data, True)
signal_waveforms = get_std_waveforms(combined_data)
print(combined_data.shape[0])
#extract waveforms of noise
noise_waveforms = get_std_waveforms(combined_noise)

#extract waveforms of test data
test_signal_waveforms = get_std_waveforms(x_test_data)
print(test_signal_waveforms.shape[0])
# Out:
# 223385
# 140227
# 70113
# 69749
# 70114

# %%
print(test_signal_waveforms.shape, signal_waveforms.shape, noise_waveforms.shape)
# Out:
# (70114, 200) (69749, 200) (100000, 200)

# %%
for idx in range(5):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30, 4))
    ax1.plot(signal_waveforms[idx], color='blue')

    ax2.plot(noise_waveforms[idx], color='orange')
    plt.show()

# %%
#generate y data (assuming all radiologicals contain signal, all noise does not)
y_noise_full = np.zeros(noise_waveforms.shape[0])
y_signal = np.ones(signal_waveforms.shape[0])
y_test_signal = np.ones(test_signal_waveforms.shape[0])

# split test and train noise datasets (50k)
x_noise_train, x_noise_test, y_noise_train, y_noise_test = train_test_split(
    noise_waveforms, y_noise_full, test_size=0.5, shuffle=True
)

#Shuffle signal waveforms to be safe
signal_waveforms, y_signal = shuffle(signal_waveforms,y_signal)

#Shuffle test waveformst to be safe
x_test, y_test = shuffle(test_signal_waveforms,y_test_signal)

# %%
print(x_noise_train.shape, signal_waveforms.shape, x_test.shape)
# Out:
# (50000, 200) (69749, 200) (70114, 200)

# %%
for idx in range(14205-4, 14205):
    fig, (ax1) = plt.subplots(figsize=(15, 4))
    ax1.plot(signal_waveforms[idx], color='blue', label= "target: " + str(y_signal[idx]))
    ax1.legend()
    plt.show()

# %%
for idx in range(4):
    fig, (ax1) = plt.subplots(figsize=(15, 4))
    ax1.plot(x_noise_train[idx], color='blue', label= "target: " + str(y_noise_train[idx]))
    ax1.legend()
    plt.show()

# %%
#Select First n signal samples from (shuffled) set of signals where n = noise samples for balanced train set 
x_train = np.concatenate((signal_waveforms[:int(x_noise_train.shape[0])], x_noise_train))
y_train = np.concatenate((y_signal[:int(x_noise_train.shape[0])], y_noise_train))

x_test = np.concatenate((x_test[:int(x_noise_test.shape[0])], x_noise_test))
y_test = np.concatenate((y_test_signal[:int(x_noise_test.shape[0])], y_noise_test))


# extra train shuffle for good measure 
x_train, y_train = shuffle(x_train,y_train)
# extra test shuffle for good measure 
x_test, y_test = shuffle(x_test,y_test)

#split train and valid sets (40k train 10k valid) 
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_valid.shape, y_valid.shape)
# Out:
# (80000, 200) (80000,) (100000, 200) (100000,) (20000, 200) (20000,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std
#cc_x_test_scaled = (cc_x_test-mean)/std 
#es_x_test_scaled = (es_x_test-mean)/std 
time_periods = 200

# %%
np.save("processed_data/test_scaled_Z", x_test_scaled)

# %%
np.save("models/mean_"+wireplane+"_nu", mean)
np.save("models/scale_"+wireplane+"_nu", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %% [markdown]
# # 1D-CNN LArTPC Waveform Recognition

# %%
time_periods = 200
def create_model():
  model = Sequential()  
  #first convolutional block
  model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
  model.add(MaxPooling1D(pool_size=2))

  #second convolutional block
  model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(0.1))
  
  #forth convolutional block                                      
  model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
  model.add(GlobalMaxPooling1D())
  model.add(Dropout(0.2)) 
    
  model.add(Flatten())

  
 
  model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
  return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
#cc_x_test_scaled = cc_x_test_scaled.reshape(cc_x_test_scaled.shape[0], cc_x_test_scaled.shape[1], 1)
#es_x_test_scaled = es_x_test_scaled.reshape(es_x_test_scaled.shape[0], es_x_test_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
# %%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 7s 22ms/step - loss: 0.4834 - accuracy: 0.7577 - val_loss: 0.3650 - val_accuracy: 0.8441
# Epoch 2/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.3210 - accuracy: 0.8664 - val_loss: 0.2946 - val_accuracy: 0.8816
# Epoch 3/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.2758 - accuracy: 0.8900 - val_loss: 0.2716 - val_accuracy: 0.8911
# Epoch 4/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2591 - accuracy: 0.8988 - val_loss: 0.2607 - val_accuracy: 0.8973
# Epoch 5/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2513 - accuracy: 0.9033 - val_loss: 0.2554 - val_accuracy: 0.9007
# Epoch 6/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2468 - accuracy: 0.9056 - val_loss: 0.2520 - val_accuracy: 0.9032
# Epoch 7/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2439 - accuracy: 0.9066 - val_loss: 0.2554 - val_accuracy: 0.9017
# Epoch 8/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2427 - accuracy: 0.9082 - val_loss: 0.2499 - val_accuracy: 0.9050
# Epoch 9/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.2411 - accuracy: 0.9090 - val_loss: 0.2481 - val_accuracy: 0.9062
# Epoch 10/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2395 - accuracy: 0.9094 - val_loss: 0.2468 - val_accuracy: 0.9065
# Epoch 11/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2390 - accuracy: 0.9097 - val_loss: 0.2457 - val_accuracy: 0.9075
# Epoch 12/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2381 - accuracy: 0.9099 - val_loss: 0.2449 - val_accuracy: 0.9075
# Epoch 13/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2368 - accuracy: 0.9107 - val_loss: 0.2438 - val_accuracy: 0.9075
# Epoch 14/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2359 - accuracy: 0.9108 - val_loss: 0.2440 - val_accuracy: 0.9086
# Epoch 15/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2357 - accuracy: 0.9112 - val_loss: 0.2427 - val_accuracy: 0.9084
# Epoch 16/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2346 - accuracy: 0.9114 - val_loss: 0.2412 - val_accuracy: 0.9086
# Epoch 17/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2327 - accuracy: 0.9125 - val_loss: 0.2403 - val_accuracy: 0.9086
# Epoch 18/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2331 - accuracy: 0.9119 - val_loss: 0.2398 - val_accuracy: 0.9093
# Epoch 19/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2321 - accuracy: 0.9126 - val_loss: 0.2419 - val_accuracy: 0.9081
# Epoch 20/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2318 - accuracy: 0.9128 - val_loss: 0.2386 - val_accuracy: 0.9090
# Epoch 21/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2318 - accuracy: 0.9122 - val_loss: 0.2390 - val_accuracy: 0.9100
# Epoch 22/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2307 - accuracy: 0.9133 - val_loss: 0.2367 - val_accuracy: 0.9106
# Epoch 23/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2296 - accuracy: 0.9135 - val_loss: 0.2360 - val_accuracy: 0.9105
# Epoch 24/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2292 - accuracy: 0.9134 - val_loss: 0.2352 - val_accuracy: 0.9108
# Epoch 25/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2287 - accuracy: 0.9135 - val_loss: 0.2349 - val_accuracy: 0.9108
# Epoch 26/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2282 - accuracy: 0.9144 - val_loss: 0.2344 - val_accuracy: 0.9118
# Epoch 27/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2273 - accuracy: 0.9145 - val_loss: 0.2341 - val_accuracy: 0.9115
# Epoch 28/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2270 - accuracy: 0.9143 - val_loss: 0.2335 - val_accuracy: 0.9117
# Epoch 29/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2260 - accuracy: 0.9154 - val_loss: 0.2340 - val_accuracy: 0.9115
# Epoch 30/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2256 - accuracy: 0.9150 - val_loss: 0.2333 - val_accuracy: 0.9116
# Epoch 31/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2260 - accuracy: 0.9145 - val_loss: 0.2326 - val_accuracy: 0.9114
# Epoch 32/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2253 - accuracy: 0.9156 - val_loss: 0.2322 - val_accuracy: 0.9125
# Epoch 33/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2243 - accuracy: 0.9152 - val_loss: 0.2336 - val_accuracy: 0.9111
# Epoch 34/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2248 - accuracy: 0.9154 - val_loss: 0.2323 - val_accuracy: 0.9115
# Epoch 35/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2243 - accuracy: 0.9158 - val_loss: 0.2315 - val_accuracy: 0.9118
# Epoch 36/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2242 - accuracy: 0.9157 - val_loss: 0.2329 - val_accuracy: 0.9125
# Epoch 37/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2239 - accuracy: 0.9157 - val_loss: 0.2308 - val_accuracy: 0.9127
# Epoch 38/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2234 - accuracy: 0.9156 - val_loss: 0.2321 - val_accuracy: 0.9123
# Epoch 39/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2223 - accuracy: 0.9168 - val_loss: 0.2309 - val_accuracy: 0.9125
# Epoch 40/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2234 - accuracy: 0.9162 - val_loss: 0.2301 - val_accuracy: 0.9134
# Epoch 41/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2215 - accuracy: 0.9165 - val_loss: 0.2301 - val_accuracy: 0.9129
# Epoch 42/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2219 - accuracy: 0.9169 - val_loss: 0.2297 - val_accuracy: 0.9138
# Epoch 43/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2207 - accuracy: 0.9170 - val_loss: 0.2303 - val_accuracy: 0.9128
# Epoch 44/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2209 - accuracy: 0.9169 - val_loss: 0.2294 - val_accuracy: 0.9133
# Epoch 45/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2208 - accuracy: 0.9165 - val_loss: 0.2299 - val_accuracy: 0.9132
# Epoch 46/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2204 - accuracy: 0.9173 - val_loss: 0.2296 - val_accuracy: 0.9136
# Epoch 47/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2204 - accuracy: 0.9171 - val_loss: 0.2314 - val_accuracy: 0.9119
# Epoch 48/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2210 - accuracy: 0.9177 - val_loss: 0.2293 - val_accuracy: 0.9140
# Epoch 49/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2201 - accuracy: 0.9172 - val_loss: 0.2302 - val_accuracy: 0.9125
# Epoch 50/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2200 - accuracy: 0.9172 - val_loss: 0.2295 - val_accuracy: 0.9133
# Epoch 51/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2190 - accuracy: 0.9183 - val_loss: 0.2289 - val_accuracy: 0.9142
# Epoch 52/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2190 - accuracy: 0.9176 - val_loss: 0.2290 - val_accuracy: 0.9141
# Epoch 53/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2183 - accuracy: 0.9183 - val_loss: 0.2287 - val_accuracy: 0.9136
# Epoch 54/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2184 - accuracy: 0.9173 - val_loss: 0.2286 - val_accuracy: 0.9144
# Epoch 55/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2181 - accuracy: 0.9184 - val_loss: 0.2291 - val_accuracy: 0.9136
# Epoch 56/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2180 - accuracy: 0.9185 - val_loss: 0.2298 - val_accuracy: 0.9133
# Epoch 57/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2183 - accuracy: 0.9183 - val_loss: 0.2294 - val_accuracy: 0.9130
# Epoch 58/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2183 - accuracy: 0.9181 - val_loss: 0.2302 - val_accuracy: 0.9121
# Epoch 59/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2183 - accuracy: 0.9177 - val_loss: 0.2282 - val_accuracy: 0.9144
# Epoch 60/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2173 - accuracy: 0.9183 - val_loss: 0.2282 - val_accuracy: 0.9142
# Epoch 61/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2174 - accuracy: 0.9188 - val_loss: 0.2285 - val_accuracy: 0.9139
# Epoch 62/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2170 - accuracy: 0.9191 - val_loss: 0.2281 - val_accuracy: 0.9144
# Epoch 63/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2171 - accuracy: 0.9190 - val_loss: 0.2279 - val_accuracy: 0.9143
# Epoch 64/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2177 - accuracy: 0.9180 - val_loss: 0.2297 - val_accuracy: 0.9133
# Epoch 65/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2162 - accuracy: 0.9191 - val_loss: 0.2279 - val_accuracy: 0.9144
# Epoch 66/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2159 - accuracy: 0.9194 - val_loss: 0.2281 - val_accuracy: 0.9144
# Epoch 67/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2160 - accuracy: 0.9190 - val_loss: 0.2281 - val_accuracy: 0.9146
# Epoch 68/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2172 - accuracy: 0.9185 - val_loss: 0.2282 - val_accuracy: 0.9144
# Epoch 69/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2163 - accuracy: 0.9185 - val_loss: 0.2283 - val_accuracy: 0.9144
# Epoch 70/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2153 - accuracy: 0.9195 - val_loss: 0.2296 - val_accuracy: 0.9136
# Wall time: 23.1 s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 9062

# %%
model.save("models/" + wireplane + "plane_nu.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2165 - accuracy: 0.9189
# [0.2165452390909195, 0.918940007686615]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 1ms/step
# Wall time: 304 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10, 8))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.9599061092025827

# %%
np.save("results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 6ms/step
# Wall time: 78 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <AxesSubplot:>

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)
# Out:
# 0.9522646793273082

# %%
np.save("results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 3ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 4ms/step
# Wall time: 274 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([1.0000e+01, 2.4882e+04, 1.2687e+04, 4.8940e+03, 2.4500e+03,
#         1.4310e+03, 9.3300e+02, 5.9900e+02, 4.6100e+02, 3.2400e+02,
#         2.4000e+02, 2.0600e+02, 1.8500e+02, 1.5500e+02, 1.3400e+02,
#         9.3000e+01, 9.8000e+01, 9.0000e+01, 7.6000e+01, 5.2000e+01]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([    0.,  1633.,  1531.,   985.,   654.,   532.,   451.,   377.,
#           305.,   309.,   296.,   262.,   273.,   294.,   295.,   307.,
#           378.,   477.,   673., 39968.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ],
#        dtype=float32),
#  <BarContainer object of 20 artists>)
