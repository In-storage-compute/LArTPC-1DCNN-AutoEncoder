# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
wireplane = "Z"
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/x_test_Z.npy',
#  'processed_data/x_train_Z.npy',
#  'processed_data/y_test_AE_Z.npy',
#  'processed_data/y_test_ROI_Z.npy',
#  'processed_data/y_train_AE_Z.npy',
#  'processed_data/y_train_ROI_Z.npy']

# %%
x_train = np.load(path+'x_train_' + wireplane + '.npy')
x_test = np.load(path+'x_test_' + wireplane + '.npy')
y_train = np.load(path+'y_train_ROI_' + wireplane + '.npy')
y_test = np.load(path+'y_test_ROI_'+ wireplane + '.npy')

# %%
print(x_test.shape, y_train.shape, y_test.shape, y_train.shape)
# Out:
# (100000, 200) (100000,) (100000,) (100000,)

# %%
#split train and valid sets
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (80000, 200) (80000,)
# (100000, 200) (100000,)
# (20000, 200) (20000,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
np.save("ROI_models/mean_"+wireplane+"_nu_ROI", mean)
np.save("ROI_models/scale_"+wireplane+"_nu_ROI", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
  model = Sequential()  
  #first convolutional block
  model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
  model.add(MaxPooling1D(pool_size=2))

  #second convolutional block
  model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(0.1))
  
  #forth convolutional block                                      
  model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
  model.add(GlobalMaxPooling1D())
  model.add(Dropout(0.2)) 
    
  model.add(Flatten())

  
 
  model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
  return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#%%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 2s 39ms/step - loss: 0.5089 - accuracy: 0.7437 - val_loss: 0.4159 - val_accuracy: 0.8033
# Epoch 2/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3869 - accuracy: 0.8245 - val_loss: 0.3632 - val_accuracy: 0.8400
# Epoch 3/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3560 - accuracy: 0.8442 - val_loss: 0.3483 - val_accuracy: 0.8511
# Epoch 4/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3476 - accuracy: 0.8499 - val_loss: 0.3424 - val_accuracy: 0.8539
# Epoch 5/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3419 - accuracy: 0.8520 - val_loss: 0.3388 - val_accuracy: 0.8554
# Epoch 6/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3396 - accuracy: 0.8541 - val_loss: 0.3372 - val_accuracy: 0.8559
# Epoch 7/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3380 - accuracy: 0.8553 - val_loss: 0.3348 - val_accuracy: 0.8564
# Epoch 8/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3361 - accuracy: 0.8559 - val_loss: 0.3339 - val_accuracy: 0.8573
# Epoch 9/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3357 - accuracy: 0.8565 - val_loss: 0.3332 - val_accuracy: 0.8564
# Epoch 10/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3343 - accuracy: 0.8570 - val_loss: 0.3319 - val_accuracy: 0.8583
# Epoch 11/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3347 - accuracy: 0.8572 - val_loss: 0.3319 - val_accuracy: 0.8571
# Epoch 12/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3326 - accuracy: 0.8580 - val_loss: 0.3330 - val_accuracy: 0.8572
# Epoch 13/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3324 - accuracy: 0.8577 - val_loss: 0.3297 - val_accuracy: 0.8587
# Epoch 14/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3312 - accuracy: 0.8587 - val_loss: 0.3296 - val_accuracy: 0.8599
# Epoch 15/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3310 - accuracy: 0.8582 - val_loss: 0.3295 - val_accuracy: 0.8589
# Epoch 16/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3303 - accuracy: 0.8590 - val_loss: 0.3290 - val_accuracy: 0.8595
# Epoch 17/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3309 - accuracy: 0.8585 - val_loss: 0.3300 - val_accuracy: 0.8605
# Epoch 18/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3297 - accuracy: 0.8596 - val_loss: 0.3288 - val_accuracy: 0.8602
# Epoch 19/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3286 - accuracy: 0.8598 - val_loss: 0.3272 - val_accuracy: 0.8607
# Epoch 20/100
# 40/40 [==============================] - 2s 39ms/step - loss: 0.3287 - accuracy: 0.8598 - val_loss: 0.3269 - val_accuracy: 0.8609
# Epoch 21/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3282 - accuracy: 0.8599 - val_loss: 0.3283 - val_accuracy: 0.8608
# Epoch 22/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.3283 - accuracy: 0.8605 - val_loss: 0.3305 - val_accuracy: 0.8590
# Epoch 23/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3279 - accuracy: 0.8605 - val_loss: 0.3258 - val_accuracy: 0.8615
# Epoch 24/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3264 - accuracy: 0.8607 - val_loss: 0.3262 - val_accuracy: 0.8613
# Epoch 25/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3267 - accuracy: 0.8606 - val_loss: 0.3249 - val_accuracy: 0.8627
# Epoch 26/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3257 - accuracy: 0.8613 - val_loss: 0.3248 - val_accuracy: 0.8615
# Epoch 27/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3254 - accuracy: 0.8623 - val_loss: 0.3261 - val_accuracy: 0.8616
# Epoch 28/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3255 - accuracy: 0.8616 - val_loss: 0.3248 - val_accuracy: 0.8615
# Epoch 29/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3245 - accuracy: 0.8619 - val_loss: 0.3248 - val_accuracy: 0.8620
# Epoch 30/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3246 - accuracy: 0.8613 - val_loss: 0.3235 - val_accuracy: 0.8613
# Epoch 31/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3243 - accuracy: 0.8616 - val_loss: 0.3241 - val_accuracy: 0.8622
# Epoch 32/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3224 - accuracy: 0.8627 - val_loss: 0.3228 - val_accuracy: 0.8622
# Epoch 33/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3224 - accuracy: 0.8623 - val_loss: 0.3227 - val_accuracy: 0.8624
# Epoch 34/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3222 - accuracy: 0.8622 - val_loss: 0.3216 - val_accuracy: 0.8623
# Epoch 35/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3215 - accuracy: 0.8631 - val_loss: 0.3216 - val_accuracy: 0.8625
# Epoch 36/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3202 - accuracy: 0.8636 - val_loss: 0.3208 - val_accuracy: 0.8623
# Epoch 37/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3209 - accuracy: 0.8639 - val_loss: 0.3204 - val_accuracy: 0.8626
# Epoch 38/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3201 - accuracy: 0.8637 - val_loss: 0.3203 - val_accuracy: 0.8632
# Epoch 39/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3199 - accuracy: 0.8643 - val_loss: 0.3220 - val_accuracy: 0.8627
# Epoch 40/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3203 - accuracy: 0.8641 - val_loss: 0.3201 - val_accuracy: 0.8634
# Epoch 41/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3190 - accuracy: 0.8642 - val_loss: 0.3204 - val_accuracy: 0.8637
# Epoch 42/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3188 - accuracy: 0.8641 - val_loss: 0.3193 - val_accuracy: 0.8634
# Epoch 43/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3179 - accuracy: 0.8648 - val_loss: 0.3204 - val_accuracy: 0.8632
# Epoch 44/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3186 - accuracy: 0.8640 - val_loss: 0.3188 - val_accuracy: 0.8645
# Epoch 45/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3175 - accuracy: 0.8649 - val_loss: 0.3187 - val_accuracy: 0.8647
# Epoch 46/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3177 - accuracy: 0.8646 - val_loss: 0.3190 - val_accuracy: 0.8641
# Epoch 47/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3170 - accuracy: 0.8650 - val_loss: 0.3187 - val_accuracy: 0.8640
# Epoch 48/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3164 - accuracy: 0.8652 - val_loss: 0.3183 - val_accuracy: 0.8641
# Epoch 49/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3173 - accuracy: 0.8656 - val_loss: 0.3182 - val_accuracy: 0.8648
# Epoch 50/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3160 - accuracy: 0.8661 - val_loss: 0.3181 - val_accuracy: 0.8648
# Epoch 51/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3161 - accuracy: 0.8660 - val_loss: 0.3181 - val_accuracy: 0.8639
# Epoch 52/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3162 - accuracy: 0.8658 - val_loss: 0.3183 - val_accuracy: 0.8650
# Epoch 53/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3153 - accuracy: 0.8663 - val_loss: 0.3182 - val_accuracy: 0.8641
# Epoch 54/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3150 - accuracy: 0.8669 - val_loss: 0.3185 - val_accuracy: 0.8641
# Epoch 55/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3151 - accuracy: 0.8661 - val_loss: 0.3178 - val_accuracy: 0.8651
# Epoch 56/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3145 - accuracy: 0.8668 - val_loss: 0.3182 - val_accuracy: 0.8647
# Epoch 57/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3145 - accuracy: 0.8667 - val_loss: 0.3188 - val_accuracy: 0.8641
# Epoch 58/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3147 - accuracy: 0.8668 - val_loss: 0.3173 - val_accuracy: 0.8644
# Epoch 59/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.3139 - accuracy: 0.8668 - val_loss: 0.3173 - val_accuracy: 0.8641
# Epoch 60/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3134 - accuracy: 0.8666 - val_loss: 0.3174 - val_accuracy: 0.8646
# Epoch 61/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3129 - accuracy: 0.8669 - val_loss: 0.3193 - val_accuracy: 0.8644
# Epoch 62/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3150 - accuracy: 0.8665 - val_loss: 0.3169 - val_accuracy: 0.8643
# Epoch 63/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3133 - accuracy: 0.8670 - val_loss: 0.3171 - val_accuracy: 0.8644
# Epoch 64/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3129 - accuracy: 0.8671 - val_loss: 0.3168 - val_accuracy: 0.8650
# Epoch 65/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3129 - accuracy: 0.8673 - val_loss: 0.3175 - val_accuracy: 0.8641
# Epoch 66/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3121 - accuracy: 0.8673 - val_loss: 0.3167 - val_accuracy: 0.8652
# Epoch 67/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3121 - accuracy: 0.8674 - val_loss: 0.3164 - val_accuracy: 0.8644
# Epoch 68/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3127 - accuracy: 0.8677 - val_loss: 0.3176 - val_accuracy: 0.8652
# Epoch 69/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3112 - accuracy: 0.8676 - val_loss: 0.3167 - val_accuracy: 0.8645
# Epoch 70/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3110 - accuracy: 0.8683 - val_loss: 0.3168 - val_accuracy: 0.8650
# Epoch 71/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.3108 - accuracy: 0.8681 - val_loss: 0.3170 - val_accuracy: 0.8652
# Epoch 72/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.3108 - accuracy: 0.8676 - val_loss: 0.3172 - val_accuracy: 0.8646

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 5768

# %%
model.save("ROI_models/model_" + wireplane + "plane_nu_ROI.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 16ms/step - loss: 0.3154 - accuracy: 0.8651
# [0.3153808116912842, 0.865149974822998]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 5ms/step
# Wall time: 574 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot: >

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <AxesSubplot: >

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10,6))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.9220841284180805

# %%
np.save("ROI_results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 15ms/step
# Wall time: 118 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <AxesSubplot: >

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10,6))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)
# Out:
# 0.9156558552256742

# %%
np.save("ROI_results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 15ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 14ms/step
# 13/13 [==============================] - 0s 14ms/step
# Wall time: 510 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([    0.,  2717., 19774., 11376.,  5986.,  3236.,  2055.,  1339.,
#           882.,   654.,   462.,   328.,   265.,   236.,   184.,   144.,
#           102.,    93.,    98.,    69.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([    0.,   242.,  2668.,  2378.,  1737.,  1314.,  1083.,   815.,
#           686.,   581.,   523.,   454.,   422.,   447.,   437.,   460.,
#           507.,   574.,   784., 33888.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)
