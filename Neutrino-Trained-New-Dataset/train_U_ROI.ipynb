# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
wireplane = "U"
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/x_test_U.npy',
#  'processed_data/x_train_U.npy',
#  'processed_data/y_test_AE_U.npy',
#  'processed_data/y_test_ROI_U.npy',
#  'processed_data/y_train_AE_U.npy',
#  'processed_data/y_train_ROI_U.npy']

# %%
x_train = np.load(path+'x_train_' + wireplane + '.npy')
x_test = np.load(path+'x_test_' + wireplane + '.npy')
y_train = np.load(path+'y_train_ROI_' + wireplane + '.npy')
y_test = np.load(path+'y_test_ROI_U.npy')

# %%
print(x_test.shape, y_train.shape, y_test.shape, y_train.shape)
# Out:
# (100000, 200) (100000,) (100000,) (100000,)

# %%
#split train and valid sets
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (80000, 200) (80000,)
# (100000, 200) (100000,)
# (20000, 200) (20000,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
np.save("ROI_models/mean_"+wireplane+"_nu_ROI", mean)
np.save("ROI_models/scale_"+wireplane+"_nu_ROI", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
  model = Sequential()  
  #first convolutional block
  model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
  model.add(MaxPooling1D(pool_size=2))

  #second convolutional block
  model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(0.1))
  
  #forth convolutional block                                      
  model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
  model.add(GlobalMaxPooling1D())
  model.add(Dropout(0.2)) 
    
  model.add(Flatten())

  
 
  model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
  return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#%%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 2s 42ms/step - loss: 0.5319 - accuracy: 0.6951 - val_loss: 0.3693 - val_accuracy: 0.8672
# Epoch 2/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.3203 - accuracy: 0.8731 - val_loss: 0.2755 - val_accuracy: 0.8900
# Epoch 3/100
# 40/40 [==============================] - 2s 39ms/step - loss: 0.2787 - accuracy: 0.8885 - val_loss: 0.2639 - val_accuracy: 0.8952
# Epoch 4/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.2697 - accuracy: 0.8928 - val_loss: 0.2547 - val_accuracy: 0.8997
# Epoch 5/100
# 40/40 [==============================] - 2s 39ms/step - loss: 0.2641 - accuracy: 0.8954 - val_loss: 0.2534 - val_accuracy: 0.9006
# Epoch 6/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.2605 - accuracy: 0.8985 - val_loss: 0.2503 - val_accuracy: 0.9013
# Epoch 7/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.2586 - accuracy: 0.8986 - val_loss: 0.2488 - val_accuracy: 0.9032
# Epoch 8/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2565 - accuracy: 0.9002 - val_loss: 0.2475 - val_accuracy: 0.9035
# Epoch 9/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2542 - accuracy: 0.9014 - val_loss: 0.2485 - val_accuracy: 0.9029
# Epoch 10/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2532 - accuracy: 0.9021 - val_loss: 0.2464 - val_accuracy: 0.9040
# Epoch 11/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2520 - accuracy: 0.9019 - val_loss: 0.2456 - val_accuracy: 0.9053
# Epoch 12/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2515 - accuracy: 0.9028 - val_loss: 0.2447 - val_accuracy: 0.9054
# Epoch 13/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2509 - accuracy: 0.9031 - val_loss: 0.2444 - val_accuracy: 0.9051
# Epoch 14/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2505 - accuracy: 0.9030 - val_loss: 0.2436 - val_accuracy: 0.9060
# Epoch 15/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2488 - accuracy: 0.9040 - val_loss: 0.2437 - val_accuracy: 0.9061
# Epoch 16/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2489 - accuracy: 0.9044 - val_loss: 0.2432 - val_accuracy: 0.9058
# Epoch 17/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2477 - accuracy: 0.9044 - val_loss: 0.2426 - val_accuracy: 0.9065
# Epoch 18/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2475 - accuracy: 0.9049 - val_loss: 0.2422 - val_accuracy: 0.9071
# Epoch 19/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2472 - accuracy: 0.9042 - val_loss: 0.2440 - val_accuracy: 0.9064
# Epoch 20/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2462 - accuracy: 0.9053 - val_loss: 0.2429 - val_accuracy: 0.9072
# Epoch 21/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2465 - accuracy: 0.9058 - val_loss: 0.2418 - val_accuracy: 0.9069
# Epoch 22/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2459 - accuracy: 0.9053 - val_loss: 0.2433 - val_accuracy: 0.9066
# Epoch 23/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2454 - accuracy: 0.9050 - val_loss: 0.2411 - val_accuracy: 0.9072
# Epoch 24/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2448 - accuracy: 0.9057 - val_loss: 0.2428 - val_accuracy: 0.9071
# Epoch 25/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2447 - accuracy: 0.9058 - val_loss: 0.2412 - val_accuracy: 0.9070
# Epoch 26/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2436 - accuracy: 0.9060 - val_loss: 0.2408 - val_accuracy: 0.9073
# Epoch 27/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2435 - accuracy: 0.9058 - val_loss: 0.2411 - val_accuracy: 0.9075
# Epoch 28/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2442 - accuracy: 0.9060 - val_loss: 0.2405 - val_accuracy: 0.9079
# Epoch 29/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2430 - accuracy: 0.9065 - val_loss: 0.2413 - val_accuracy: 0.9077
# Epoch 30/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2438 - accuracy: 0.9061 - val_loss: 0.2426 - val_accuracy: 0.9075
# Epoch 31/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2428 - accuracy: 0.9065 - val_loss: 0.2401 - val_accuracy: 0.9079
# Epoch 32/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2418 - accuracy: 0.9070 - val_loss: 0.2400 - val_accuracy: 0.9082
# Epoch 33/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2423 - accuracy: 0.9063 - val_loss: 0.2401 - val_accuracy: 0.9079
# Epoch 34/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2417 - accuracy: 0.9068 - val_loss: 0.2406 - val_accuracy: 0.9083
# Epoch 35/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2410 - accuracy: 0.9067 - val_loss: 0.2399 - val_accuracy: 0.9085
# Epoch 36/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2416 - accuracy: 0.9064 - val_loss: 0.2411 - val_accuracy: 0.9082
# Epoch 37/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2402 - accuracy: 0.9074 - val_loss: 0.2398 - val_accuracy: 0.9086
# Epoch 38/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2403 - accuracy: 0.9078 - val_loss: 0.2397 - val_accuracy: 0.9083
# Epoch 39/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2400 - accuracy: 0.9070 - val_loss: 0.2397 - val_accuracy: 0.9080
# Epoch 40/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2393 - accuracy: 0.9071 - val_loss: 0.2400 - val_accuracy: 0.9083
# Epoch 41/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2404 - accuracy: 0.9070 - val_loss: 0.2395 - val_accuracy: 0.9087
# Epoch 42/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2396 - accuracy: 0.9079 - val_loss: 0.2407 - val_accuracy: 0.9082
# Epoch 43/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.2395 - accuracy: 0.9079 - val_loss: 0.2421 - val_accuracy: 0.9074
# Epoch 44/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2389 - accuracy: 0.9076 - val_loss: 0.2399 - val_accuracy: 0.9083
# Epoch 45/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.2385 - accuracy: 0.9081 - val_loss: 0.2402 - val_accuracy: 0.9083
# Epoch 46/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.2388 - accuracy: 0.9081 - val_loss: 0.2397 - val_accuracy: 0.9086

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 5556

# %%
model.save("ROI_models/model_" + wireplane + "plane_nu_ROI.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 15ms/step - loss: 0.2419 - accuracy: 0.9074
# [0.24185480177402496, 0.9073600172996521]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 5ms/step
# Wall time: 674 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot: >

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <AxesSubplot: >

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10,6))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.9505807110085075

# %%
np.save("ROI_results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 16ms/step
# Wall time: 125 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <AxesSubplot: >

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10,6))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)

# %%
np.save("ROI_results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 17ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 16ms/step
# 13/13 [==============================] - 0s 17ms/step
# Wall time: 575 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([2.0000e+00, 2.3233e+04, 1.4311e+04, 4.8770e+03, 2.3900e+03,
#         1.4040e+03, 9.2600e+02, 6.7100e+02, 5.0100e+02, 3.7600e+02,
#         2.5100e+02, 2.1800e+02, 1.8900e+02, 1.4700e+02, 1.3000e+02,
#         1.1100e+02, 8.6000e+01, 7.4000e+01, 5.3000e+01, 5.0000e+01]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([    0.,  1952.,  2119.,  1133.,   722.,   552.,   451.,   365.,
#           339.,   322.,   301.,   303.,   252.,   330.,   293.,   317.,
#           336.,   485.,   705., 38723.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)
