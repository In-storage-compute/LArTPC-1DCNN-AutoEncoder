# %% [markdown]
# train autoencoder WITHOUT using 1DCNN roi finder

# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split 
from sklearn.utils import shuffle
from PyPDF2 import PdfMerger
import os
from tensorflow.keras.models import load_model
# Out:
# 2023-05-04 13:04:17.700645: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 13:04:18.197293: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
wireplane = "Z"
np.random.seed(77)
path = '../processed_data/'

# %%
def load_data(path, wireplane):
    x_train = np.load(path+'x_train_' + wireplane + '.npy')
    x_test = np.load(path+'x_test_' + wireplane + '.npy')
    y_train = np.load(path+'y_train_AE_' + wireplane + '.npy')
    y_test = np.load(path+'y_test_AE_' + wireplane + '.npy')
    
    #split train and valid sets (40k train 10k valid) 
    x_train, x_valid, y_train, y_valid = train_test_split(
        x_train, y_train, test_size=0.2, shuffle=False
    )
    
    mean = x_train.mean()
    std = x_train.std()

    x_train_scaled = (x_train-mean)/std
    x_test_scaled = (x_test-mean)/std
    x_valid_scaled = (x_valid-mean)/std
    
    y_train_scaled = (y_train-mean)/std
    y_test_scaled = (y_test-mean)/std
    y_valid_scaled = (y_valid-mean)/std

    return x_train_scaled, x_test_scaled, y_train_scaled, y_test_scaled, x_valid_scaled, y_valid_scaled, mean, std

# %%
x_train_scaled, x_test_scaled, y_train_scaled, y_test_scaled, x_valid_scaled, y_valid_scaled, mean, std = load_data(path, wireplane)

# %%
for idx in range(6,9):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train_scaled[idx],color='blue', label='signal+noise')
    ax1.plot(y_train_scaled[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()

    plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Dense,Flatten, AveragePooling1D
from tensorflow.keras.layers import Input,  UpSampling1D
from tensorflow.keras.models import Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization
#from keras import backend as K

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Conv1DTranspose

# %%
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, UpSampling1D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import PReLU

def get_fcn_dae(input_shape):
    # Encoder
    inputs = Input(shape=input_shape)
    x = Conv1D(filters=40, kernel_size=16, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = Conv1D(filters=20, kernel_size=16, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = Conv1D(filters=20, kernel_size=16, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = Conv1D(filters=20, kernel_size=16, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = Conv1D(filters=40, kernel_size=16, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = Conv1D(filters=1, kernel_size=16, strides=1, padding='same')(x)
    encoded = BatchNormalization()(x)

    # Decoder
    x = Conv1D(filters=40, kernel_size=16, strides=1, padding='same')(encoded)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = UpSampling1D(size=2)(x)
    x = Conv1D(filters=20, kernel_size=16, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = UpSampling1D(size=2)(x)
    x = Conv1D(filters=20, kernel_size=16, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = UpSampling1D(size=2)(x)
    x = Conv1D(filters=20, kernel_size=16, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('elu')(x)
    x = UpSampling1D(size=2)(x)
    decoded = Conv1D(filters=1, kernel_size=16, strides=1, padding='same', activation='linear')(x)
    decoded = UpSampling1D(size=2)(decoded)
    decoded = tf.keras.layers.Cropping1D(cropping = (12, 12))(decoded)

    model = Model(inputs=inputs, outputs=decoded)
    return model

# %%
autoencoder = get_fcn_dae((200,1))
autoencoder.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001), loss='mse')
autoencoder.summary()
# Out:
# 2023-05-04 13:04:28.839954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:28.856910: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:28.856968: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:28.859098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:28.859146: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:28.859181: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:29.518985: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:29.519155: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:29.519166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1722] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-04 13:04:29.519239: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 13:04:29.519284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7335 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:09:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 1)]          0
#
#  conv1d (Conv1D)             (None, 100, 40)           680
#
#  batch_normalization (BatchN  (None, 100, 40)          160
#  ormalization)
#
#  activation (Activation)     (None, 100, 40)           0
#
#  conv1d_1 (Conv1D)           (None, 50, 20)            12820
#
#  batch_normalization_1 (Batc  (None, 50, 20)           80
#  hNormalization)
#
#  activation_1 (Activation)   (None, 50, 20)            0
#
#  conv1d_2 (Conv1D)           (None, 25, 20)            6420
#
#  batch_normalization_2 (Batc  (None, 25, 20)           80
#  hNormalization)
#
#  activation_2 (Activation)   (None, 25, 20)            0
#
#  conv1d_3 (Conv1D)           (None, 13, 20)            6420
#
#  batch_normalization_3 (Batc  (None, 13, 20)           80
#  hNormalization)
#
#  activation_3 (Activation)   (None, 13, 20)            0
#
#  conv1d_4 (Conv1D)           (None, 7, 40)             12840
#
#  batch_normalization_4 (Batc  (None, 7, 40)            160
#  hNormalization)
#
#  activation_4 (Activation)   (None, 7, 40)             0
#
#  conv1d_5 (Conv1D)           (None, 7, 1)              641
#
#  batch_normalization_5 (Batc  (None, 7, 1)             4
#  hNormalization)
#
#  conv1d_6 (Conv1D)           (None, 7, 40)             680
#
#  batch_normalization_6 (Batc  (None, 7, 40)            160
#  hNormalization)
#
#  activation_5 (Activation)   (None, 7, 40)             0
#
#  up_sampling1d (UpSampling1D  (None, 14, 40)           0
#  )
#
#  conv1d_7 (Conv1D)           (None, 14, 20)            12820
#
#  batch_normalization_7 (Batc  (None, 14, 20)           80
#  hNormalization)
#
#  activation_6 (Activation)   (None, 14, 20)            0
#
#  up_sampling1d_1 (UpSampling  (None, 28, 20)           0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 28, 20)            6420
#
#  batch_normalization_8 (Batc  (None, 28, 20)           80
#  hNormalization)
#
#  activation_7 (Activation)   (None, 28, 20)            0
#
#  up_sampling1d_2 (UpSampling  (None, 56, 20)           0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 56, 20)            6420
#
#  batch_normalization_9 (Batc  (None, 56, 20)           80
#  hNormalization)
#
#  activation_8 (Activation)   (None, 56, 20)            0
#
#  up_sampling1d_3 (UpSampling  (None, 112, 20)          0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 112, 1)            321
#
#  up_sampling1d_4 (UpSampling  (None, 224, 1)           0
#  1D)
#
#  cropping1d (Cropping1D)     (None, 200, 1)            0
#
# =================================================================
# Total params: 67,446
# Trainable params: 66,964
# Non-trainable params: 482
# _________________________________________________________________

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
batch_size_ = 2048

# %%
# %%time
history = autoencoder.fit(x_train_scaled,                                                              
            y_train_scaled,                                                            
            batch_size=batch_size_,                                              
            epochs=100,                                                      
            callbacks= [earlystop], #[NewCallback(alpha)], # callbacks=callbacks_list,
            validation_data=(x_valid_scaled, y_valid_scaled),                                                                      
            verbose=1)
# Out:
# Epoch 1/100
# 2023-05-04 13:04:44.901273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-04 13:04:46.462760: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-04 13:04:47.609961: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x359931e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-04 13:04:47.609997: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2023-05-04 13:04:47.637983: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-04 13:04:47.863077: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-04 13:04:47.919745: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 40/40 [==============================] - 14s 76ms/step - loss: 0.4531 - val_loss: 0.7895
# Epoch 2/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.1708 - val_loss: 0.7811
# Epoch 3/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.1184 - val_loss: 0.7035
# Epoch 4/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0976 - val_loss: 0.6675
# Epoch 5/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0803 - val_loss: 0.5981
# Epoch 6/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0727 - val_loss: 0.5381
# Epoch 7/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0762 - val_loss: 0.3442
# Epoch 8/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0677 - val_loss: 0.2422
# Epoch 9/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0636 - val_loss: 0.1475
# Epoch 10/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0540 - val_loss: 0.1168
# Epoch 11/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0542 - val_loss: 0.0660
# Epoch 12/100
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0493 - val_loss: 0.0541
# Epoch 13/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0463 - val_loss: 0.0508
# Epoch 14/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0451 - val_loss: 0.0453
# Epoch 15/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0451 - val_loss: 0.0520
# Epoch 16/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0445 - val_loss: 0.0517
# Epoch 17/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0414 - val_loss: 0.0426
# Epoch 18/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0420 - val_loss: 0.0495
# Epoch 19/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0414 - val_loss: 0.0675
# Epoch 20/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0445 - val_loss: 0.0554
# Epoch 21/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0367 - val_loss: 0.0663
# Epoch 22/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0392 - val_loss: 0.0596
# Epoch 23/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0365 - val_loss: 0.0484
# Epoch 24/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0361 - val_loss: 0.0394
# Epoch 25/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0347 - val_loss: 0.0402
# Epoch 26/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0346 - val_loss: 0.0432
# Epoch 27/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0346 - val_loss: 0.0469
# Epoch 28/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0339 - val_loss: 0.0711
# Epoch 29/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0362 - val_loss: 0.0806
# Epoch 30/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0370 - val_loss: 0.0376
# Epoch 31/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0332 - val_loss: 0.0560
# Epoch 32/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0365 - val_loss: 0.0370
# Epoch 33/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0340 - val_loss: 0.0366
# Epoch 34/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0315 - val_loss: 0.0353
# Epoch 35/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0310 - val_loss: 0.0308
# Epoch 36/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0293 - val_loss: 0.0336
# Epoch 37/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0317 - val_loss: 0.0443
# Epoch 38/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0334 - val_loss: 0.0376
# Epoch 39/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0331 - val_loss: 0.0817
# Epoch 40/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0333 - val_loss: 0.0453
# Epoch 41/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0312 - val_loss: 0.0479
# Epoch 42/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0318 - val_loss: 0.0464
# Epoch 43/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0307 - val_loss: 0.0429
# Epoch 44/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0271 - val_loss: 0.0374
# Epoch 45/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0279 - val_loss: 0.0302
# Epoch 46/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0281 - val_loss: 0.0293
# Epoch 47/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0288 - val_loss: 0.0311
# Epoch 48/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0266 - val_loss: 0.0293
# Epoch 49/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0281 - val_loss: 0.0287
# Epoch 50/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0286 - val_loss: 0.0375
# Epoch 51/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0279 - val_loss: 0.0368
# Epoch 52/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0280 - val_loss: 0.0290
# Epoch 53/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0273 - val_loss: 0.0285
# Epoch 54/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0255 - val_loss: 0.0348
# Epoch 55/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0256 - val_loss: 0.0480
# Epoch 56/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0304 - val_loss: 0.0441
# Epoch 57/100
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0259 - val_loss: 0.0355
# Epoch 58/100
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0263 - val_loss: 0.0374
# Epoch 59/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0261 - val_loss: 0.0292
# Epoch 60/100
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0267 - val_loss: 0.0337
# Epoch 61/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0267 - val_loss: 0.0321
# Epoch 62/100
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0256 - val_loss: 0.0364
# Epoch 63/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0258 - val_loss: 0.0352
# CPU times: user 1min 17s, sys: 23 s, total: 1min 40s
# Wall time: 1min 25s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['loss'], "r", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "g--", label="Loss of validation data", antialiased=True)
plt.title('Model Loss',fontsize=15)                                            
plt.ylabel('Loss (MSE)', fontsize=12)                                                 
plt.xlabel('Training Epoch', fontsize=12)                                                                                                                       
plt.legend(fontsize=12)                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 5636

# %%
#autoencoder.save('./AE_experiment/model_AE_'+str(batch_size_)+'_mse_FCN' + wireplane + 'plane_nu.h5')

# %%
#autoencoder = load_model('./AE_experiment/models/model_AE_'+str(batch_size_)+'_mse_original' + wireplane + 'plane_nu.h5')

# %%
autoencoder.evaluate(x_test_scaled, y_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 1s 27ms/step - loss: 0.0277
# 0.02771029807627201

# %%
autoencoder.evaluate(x_train_scaled, y_train_scaled, batch_size=4096)
# Out:
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0250
# 0.02503114379942417

# %%
autoencoder.evaluate(x_valid_scaled, y_valid_scaled, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 102ms/step - loss: 0.0285
# 0.028469478711485863

# %%
#ae128 = load_model('./AE_models/model_AE_'+str(batch_size_)+'_mse' + wireplane + 'plane_nu.h5')

# %%
# %%time
predictions = autoencoder.predict(x_test_scaled, batch_size=4096)
predictions = predictions.reshape(predictions.shape[0], predictions.shape[1])
# Out:
# 25/25 [==============================] - 0s 7ms/step
# CPU times: user 572 ms, sys: 138 ms, total: 710 ms
# Wall time: 579 ms

# %%
from scipy import stats
x_test_ = std*x_test_scaled+mean
y_test_ = y_test_scaled*std + mean


pred = predictions*std + mean

# %%
# takes in prediction of AE and for every wave assigns 0 or 1
# 0 --> predicted as noise
# 1 --> pricicted as containing some kind of signals
# note that this is crude and does not consider how close the predicted signal is from truth
def label_predictions(ae_pred_wave):
    label_ = 0
    if max(abs(ae_pred_wave)) > 3:
        label_ = 1
    return label_


def label_truths(wave):
    label_ = 1
    if max(abs(wave)) <= 3:
        label_ = 0
    return label_

# %%
pred_labels = [label_predictions(wave) for wave in pred]
truth_labels = [label_truths(t_wave) for t_wave in y_test_]

# %%
cnn = load_model('../ROI_models/model_'+wireplane+'plane_nu_ROI.h5')
cnn_pred = cnn.predict(x_test_scaled, batch_size=4096)
cnn_pred = cnn_pred.squeeze()
# Out:
# 25/25 [==============================] - 0s 7ms/step

# %%
for i in range(100,200):
    if max(abs(y_test_[i])) < 20 and sum(abs(y_test_[i])) !=0:
        fig = plt.figure(figsize=(10,4))
        plt.plot(x_test_[i], color='black', alpha=0.3, label='input')
        plt.plot(y_test_[i], color='blue', alpha=0.9, label='truth ----- ' + str(truth_labels[i]))
        plt.plot(pred[i], color='m', alpha=0.7, label='pred ----- ' + str(pred_labels[i]))
        plt.title('CNN output: ' + str( round(cnn_pred[i], 3)))
        plt.legend()
        plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

fpr, tpr, thresholds = roc_curve(truth_labels, pred_labels, drop_intermediate=False)
roc_auc = auc(fpr, tpr)

# %%
fig = plt.figure(figsize=(8, 4))
plt.plot(fpr, tpr, color='m', label='(area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--', lw=2)
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate', size=12)
plt.ylabel('True Positive Rate', size=12)
plt.title('ROC Curve', size=12)
plt.legend(loc="lower right")
plt.show()

# %%
def make_single_pdf(wave_idx, pg_num, min_cnn, max_cnn):

    fig, axs = plt.subplots(3,2, figsize=(30, 18), facecolor='w', edgecolor='k')
    fig.subplots_adjust(hspace = .375, wspace=.1)

    axes = axs.ravel()

    for i in range(6):
        index_ = i + wave_idx
        max_adc = int((max(x_test_[index_])))
        
        if not (max_adc < 20 and cnn_pred[index_] > min_cnn and cnn_pred[index_] <= max_cnn and sum(abs(y_test_[index_])) != 0):
            while True:
                index_ += 1
                max_adc = int((max(x_test_[index_])))
                
                if (max_adc < 20 and cnn_pred[index_] > min_cnn and cnn_pred[index_] <= max_cnn and sum(abs(y_test_[index_])) != 0):
                    break
        wave_idx = index_


        axes[i].plot(x_test_[index_], color='black',alpha=0.2, label = 'original input (adc_max: ' + str(max_adc) + ')')
        axes[i].plot(y_test_[index_],color='blue', label='target', alpha=1)
        axes[i].plot(pred128[index_], color='m', label='model_128  ---   ' + str(pred_labels128[index_]))
        axes[i].plot(pred128_cmse[index_], color='green', label='model_128_cmse  ---   ' + str(pred_labels128_cmse[index_]))
        axes[i].legend(fontsize=12)
        axes[i].set_title('CNN output: ' + str(round(cnn_pred[index_], 4)) + ' --- [idx: ' + str(index_) + ']', size=15)
        axes[i].set_ylabel('ADC', size=12)


    plt.savefig('./AE_TEST/pdfs/tmp_plts/plts_cnn_page' + str(pg_num) +  '.pdf',
                dpi=300,
                bbox_inches='tight', pad_inches=0.75)
    plt.close()

    return wave_idx

# %%
# creates and merges pdf, removes all single page pdfs from tmp folder
def make_complete_pdf(num_pages, min_cnn, max_cnn):
    wave_idx_ = 0
    page_num = 0

    while page_num < num_pages:
        wave_idx_ = make_single_pdf(wave_idx_, page_num, min_cnn, max_cnn) + 1
        page_num += 1

    merger = PdfMerger()
    path = './AE_TEST/pdfs/tmp_plts/'
    pdf_files = [path+f for f in listdir(path) if (isfile(join(path, f)))]
    print(pdf_files)
    for pdf_file in pdf_files:
        #Append PDF files
        merger.append(pdf_file)
    #merger.write('pdfs/plts_tmp/plts_' + wireplane + '_cnn_'+str(int(min_cnn*100)) + '-' + str(int(max_cnn*100)) + '_' + str(num_pages) +  'pages.pdf')
    merger.write('./AE_TEST/pdfs/'+wireplane+'/plts_' + wireplane + '_cnn_'+str(int(min_cnn*100)) + '-' + str(int(max_cnn*100)) + '_' + str(num_pages) +  'pages.pdf')
    merger.close()

    for file in pdf_files:
        os.remove(file)

# %%
make_complete_pdf(10, 0.94, 1)

# %%
min_ = 0.94
prev = min_
max_ = 1
while min_ > 0:
    min_ = min_ - 0.2 
    make_complete_pdf(10, min_, prev)
    prev = min_
