# %% [markdown]
# train autoencoder WITHOUT using 1DCNN roi finder

# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split 
from sklearn.utils import shuffle
from PyPDF2 import PdfMerger
import os
from tensorflow.keras.models import load_model
# Out:
# 2023-05-05 02:40:47.601450: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-05 02:40:47.602987: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-05 02:40:47.633048: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-05 02:40:47.633781: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-05 02:40:48.241984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
wireplane = "U"
np.random.seed(77)
path = '../processed_data/'

# %%
def load_data(path, wireplane):
    x_train = np.load(path+'x_train_' + wireplane + '.npy')
    x_test = np.load(path+'x_test_' + wireplane + '.npy')
    y_train = np.load(path+'y_train_AE_' + wireplane + '.npy')
    y_test = np.load(path+'y_test_AE_' + wireplane + '.npy')
    
    #split train and valid sets (40k train 10k valid) 
    x_train, x_valid, y_train, y_valid = train_test_split(
        x_train, y_train, test_size=0.2, shuffle=False
    )
    
    mean = x_train.mean()
    std = x_train.std()

    x_train_scaled = (x_train-mean)/std
    x_test_scaled = (x_test-mean)/std
    x_valid_scaled = (x_valid-mean)/std
    
    y_train_scaled = (y_train-mean)/std
    y_test_scaled = (y_test-mean)/std
    y_valid_scaled = (y_valid-mean)/std

    return x_train_scaled, x_test_scaled, y_train_scaled, y_test_scaled, x_valid_scaled, y_valid_scaled, mean, std

# %%
x_train_scaled, x_test_scaled, y_train_scaled, y_test_scaled, x_valid_scaled, y_valid_scaled, mean, std = load_data(path, wireplane)

# %%
for idx in range(6,9):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train_scaled[idx],color='blue', label='signal+noise')
    ax1.plot(y_train_scaled[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()

    plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Dense,Flatten, AveragePooling1D
from tensorflow.keras.layers import Input,  UpSampling1D
from tensorflow.keras.models import Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization
#from keras import backend as K

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Conv1DTranspose

# %%
time_periods = 200
input_wave = Input(shape=(time_periods, 1)) 
x = Conv1D(filters=16, kernel_size=3, strides=2, activation="relu", input_shape=(time_periods,1))(input_wave)
x = MaxPooling1D(pool_size=2)(x)
 
# second convolutional block
x = Conv1D(filters=32, kernel_size=5, strides=2, activation="relu")(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.1)(x)

x = Conv1D(filters=64, kernel_size=9, strides=1, activation="relu")(x)

x = GlobalMaxPooling1D()(x)

x = Dropout(0.2)(x)

encoded = Reshape((1, x.shape[1]))(x)


x = UpSampling1D(size=3)(encoded)


# first deconvolutional block
x = Conv1DTranspose(filters=64, kernel_size=9, strides =1, activation="relu")(x)
x = UpSampling1D(size=2)(x)

x = Dropout(0.1)(x)

# second deconvolutional block
x = Conv1DTranspose(filters=32, kernel_size=5, strides=2, activation="relu")(x)

x = UpSampling1D(size=2)(x) # increase the size to match the encoder

decoded = Conv1DTranspose(filters=16, kernel_size=3, strides=2, activation="relu")(x)
decoded = Conv1DTranspose(filters=1, kernel_size=12, strides=1)(decoded)
autoencoder = Model(input_wave, decoded)

# %%
for i,layer in enumerate(autoencoder.layers):                                      
  print(i,layer.name)
# Out:
# 0 input_2
# 1 conv1d_3
# 2 max_pooling1d_2
# 3 conv1d_4
# 4 max_pooling1d_3
# 5 dropout_3
# 6 conv1d_5
# 7 global_max_pooling1d_1
# 8 dropout_4
# 9 reshape_1
# 10 up_sampling1d_3
# 11 conv1d_transpose_4
# 12 up_sampling1d_4
# 13 dropout_5
# 14 conv1d_transpose_5
# 15 up_sampling1d_5
# 16 conv1d_transpose_6
# 17 conv1d_transpose_7

# %%
# see what happens when we unfreeze more layers of the 1dcnn
for layer in autoencoder.layers:                                               
    layer.trainable=True                                                                                                                     
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 1)]          0
#
#  conv1d_3 (Conv1D)           (None, 99, 16)            64
#
#  max_pooling1d_2 (MaxPooling  (None, 49, 16)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_3 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout_3 (Dropout)         (None, 11, 32)            0
#
#  conv1d_5 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  reshape_1 (Reshape)         (None, 1, 64)             0
#
#  up_sampling1d_3 (UpSampling  (None, 3, 64)            0
#  1D)
#
#  conv1d_transpose_4 (Conv1DT  (None, 11, 64)           36928
#  ranspose)
#
#  up_sampling1d_4 (UpSampling  (None, 22, 64)           0
#  1D)
#
#  dropout_5 (Dropout)         (None, 22, 64)            0
#
#  conv1d_transpose_5 (Conv1DT  (None, 47, 32)           10272
#  ranspose)
#
#  up_sampling1d_5 (UpSampling  (None, 94, 32)           0
#  1D)
#
#  conv1d_transpose_6 (Conv1DT  (None, 189, 16)          1552
#  ranspose)
#
#  conv1d_transpose_7 (Conv1DT  (None, 200, 1)           193
#  ranspose)
#
# =================================================================
# Total params: 70,097
# Trainable params: 70,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
batch_size_ = 2048

# %%
# %%time
history = autoencoder.fit(x_train_scaled,                                                              
            y_train_scaled,                                                            
            batch_size=batch_size_,                                              
            epochs=1000,                                                      
            callbacks= [earlystop], #[NewCallback(alpha)], # callbacks=callbacks_list,
            validation_data=(x_valid_scaled, y_valid_scaled),                                                                      
            verbose=1)
# Out:
# Epoch 1/1000
# 40/40 [==============================] - 4s 86ms/step - loss: 0.6856 - val_loss: 0.3965
# Epoch 2/1000
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3567 - val_loss: 0.2066
# Epoch 3/1000
# 40/40 [==============================] - 3s 83ms/step - loss: 0.2632 - val_loss: 0.1682
# Epoch 4/1000
# 40/40 [==============================] - 3s 82ms/step - loss: 0.2196 - val_loss: 0.1447
# Epoch 5/1000
# 40/40 [==============================] - 3s 82ms/step - loss: 0.1966 - val_loss: 0.1339
# Epoch 6/1000
# 40/40 [==============================] - 3s 81ms/step - loss: 0.1827 - val_loss: 0.1244
# Epoch 7/1000
# 40/40 [==============================] - 3s 86ms/step - loss: 0.1666 - val_loss: 0.1136
# Epoch 8/1000
# 40/40 [==============================] - 4s 98ms/step - loss: 0.1563 - val_loss: 0.1103
# Epoch 9/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1475 - val_loss: 0.1095
# Epoch 10/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1420 - val_loss: 0.1038
# Epoch 11/1000
# 40/40 [==============================] - 4s 101ms/step - loss: 0.1356 - val_loss: 0.1022
# Epoch 12/1000
# 40/40 [==============================] - 4s 104ms/step - loss: 0.1329 - val_loss: 0.0947
# Epoch 13/1000
# 40/40 [==============================] - 4s 105ms/step - loss: 0.1274 - val_loss: 0.0936
# Epoch 14/1000
# 40/40 [==============================] - 4s 104ms/step - loss: 0.1199 - val_loss: 0.0875
# Epoch 15/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1179 - val_loss: 0.0820
# Epoch 16/1000
# 40/40 [==============================] - 4s 94ms/step - loss: 0.1174 - val_loss: 0.0853
# Epoch 17/1000
# 40/40 [==============================] - 4s 94ms/step - loss: 0.1130 - val_loss: 0.0805
# Epoch 18/1000
# 40/40 [==============================] - 4s 94ms/step - loss: 0.1093 - val_loss: 0.0789
# Epoch 19/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1077 - val_loss: 0.0789
# Epoch 20/1000
# 40/40 [==============================] - 4s 102ms/step - loss: 0.1050 - val_loss: 0.0770
# Epoch 21/1000
# 40/40 [==============================] - 4s 98ms/step - loss: 0.1029 - val_loss: 0.0790
# Epoch 22/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.1016 - val_loss: 0.0763
# Epoch 23/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0985 - val_loss: 0.0726
# Epoch 24/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0976 - val_loss: 0.0701
# Epoch 25/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0951 - val_loss: 0.0681
# Epoch 26/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0941 - val_loss: 0.0646
# Epoch 27/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0929 - val_loss: 0.0712
# Epoch 28/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0920 - val_loss: 0.0648
# Epoch 29/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0933 - val_loss: 0.0653
# Epoch 30/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0909 - val_loss: 0.0652
# Epoch 31/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0883 - val_loss: 0.0618
# Epoch 32/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0887 - val_loss: 0.0675
# Epoch 33/1000
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0868 - val_loss: 0.0628
# Epoch 34/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0846 - val_loss: 0.0622
# Epoch 35/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0834 - val_loss: 0.0634
# Epoch 36/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0818 - val_loss: 0.0659
# Epoch 37/1000
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0835 - val_loss: 0.0609
# Epoch 38/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0821 - val_loss: 0.0610
# Epoch 39/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0807 - val_loss: 0.0606
# Epoch 40/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0811 - val_loss: 0.0602
# Epoch 41/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0804 - val_loss: 0.0657
# Epoch 42/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0791 - val_loss: 0.0626
# Epoch 43/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0777 - val_loss: 0.0580
# Epoch 44/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0775 - val_loss: 0.0543
# Epoch 45/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0786 - val_loss: 0.0598
# Epoch 46/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0762 - val_loss: 0.0550
# Epoch 47/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0758 - val_loss: 0.0568
# Epoch 48/1000
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0756 - val_loss: 0.0530
# Epoch 49/1000
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0750 - val_loss: 0.0576
# Epoch 50/1000
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0736 - val_loss: 0.0569
# Epoch 51/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0729 - val_loss: 0.0593
# Epoch 52/1000
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0733 - val_loss: 0.0587
# Epoch 53/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0732 - val_loss: 0.0619
# Epoch 54/1000
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0747 - val_loss: 0.0528
# Epoch 55/1000
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0715 - val_loss: 0.0577
# Epoch 56/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0719 - val_loss: 0.0517
# Epoch 57/1000
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0723 - val_loss: 0.0593
# Epoch 58/1000
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0711 - val_loss: 0.0531
# Epoch 59/1000
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0723 - val_loss: 0.0637
# Epoch 60/1000
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0699 - val_loss: 0.0579
# Epoch 61/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0710 - val_loss: 0.0542
# Epoch 62/1000
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0693 - val_loss: 0.0605
# Epoch 63/1000
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0684 - val_loss: 0.0560
# Epoch 64/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0683 - val_loss: 0.0524
# Epoch 65/1000
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0671 - val_loss: 0.0570
# Epoch 66/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0666 - val_loss: 0.0547
# CPU times: user 20min 14s, sys: 13.4 s, total: 20min 27s
# Wall time: 4min 13s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['loss'], "r", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "g--", label="Loss of validation data", antialiased=True)
plt.title('Model Loss',fontsize=15)                                            
plt.ylabel('Loss (MSE)', fontsize=12)                                                 
plt.xlabel('Training Epoch', fontsize=12)                                                                                                                       
plt.legend(fontsize=12)                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 6015

# %%
#autoencoder.save('./models/model_AE_'+str(batch_size_)+'_mirrored_1dcnn' + wireplane + 'plane_nu.h5')

# %%
autoencoder = load_model('./models/model_AE_'+str(batch_size_)+'_mirrored_1dcnn' + wireplane + 'plane_nu.h5')

# %%
autoencoder.evaluate(x_test_scaled, y_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0509
# 0.05090855062007904

# %%
autoencoder.evaluate(x_train_scaled, y_train_scaled, batch_size=4096)
# Out:
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0452
# 0.045244503766298294

# %%
autoencoder.evaluate(x_valid_scaled, y_valid_scaled, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0517
# 0.051722802221775055

# %%
#ae128 = load_model('./AE_models/model_AE_'+str(batch_size_)+'_mse' + wireplane + 'plane_nu.h5')

# %%
# %%time
predictions = autoencoder.predict(x_test_scaled, batch_size=4096)
predictions = predictions.reshape(predictions.shape[0], predictions.shape[1])
# Out:
# 25/25 [==============================] - 2s 66ms/step
# CPU times: user 6.65 s, sys: 197 ms, total: 6.85 s
# Wall time: 2.06 s

# %%
from scipy import stats
x_test_ = std*x_test_scaled+mean
y_test_ = y_test_scaled*std + mean


pred = predictions*std + mean

# %%
# takes in prediction of AE and for every wave assigns 0 or 1
# 0 --> predicted as noise
# 1 --> pricicted as containing some kind of signals
# note that this is crude and does not consider how close the predicted signal is from truth
def label_predictions(ae_pred_wave):
    label_ = 0
    if max(abs(ae_pred_wave)) > 3:
        label_ = 1
    return label_


def label_truths(wave):
    label_ = 1
    if max(abs(wave)) <= 3:
        label_ = 0
    return label_

# %%
pred_labels = [label_predictions(wave) for wave in pred]
truth_labels = [label_truths(t_wave) for t_wave in y_test_]

# %%
cnn = load_model('../ROI_models/model_'+wireplane+'plane_nu_ROI.h5')
cnn_pred = cnn.predict(x_test_scaled, batch_size=4096)
cnn_pred = cnn_pred.squeeze()
# Out:
# 25/25 [==============================] - 0s 11ms/step

# %%
for i in range(100,200):
    if max(abs(y_test_[i])) < 20 and sum(abs(y_test_[i])) !=0:
        fig = plt.figure(figsize=(10,4))
        plt.plot(x_test_[i], color='black', alpha=0.3, label='input')
        plt.plot(y_test_[i], color='blue', alpha=0.9, label='truth ----- ' + str(truth_labels[i]))
        plt.plot(pred[i], color='m', alpha=0.7, label='pred ----- ' + str(pred_labels[i]))
        plt.title('CNN output: ' + str( round(cnn_pred[i], 3)))
        plt.legend()
        plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

fpr, tpr, thresholds = roc_curve(truth_labels, pred_labels, drop_intermediate=False)
roc_auc = auc(fpr, tpr)

# %%
fig = plt.figure(figsize=(8, 4))
plt.plot(fpr, tpr, color='m', label='(area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--', lw=2)
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate', size=12)
plt.ylabel('True Positive Rate', size=12)
plt.title('ROC Curve', size=12)
plt.legend(loc="lower right")
plt.show()

# %%
def make_single_pdf(wave_idx, pg_num, min_cnn, max_cnn):

    fig, axs = plt.subplots(3,2, figsize=(30, 18), facecolor='w', edgecolor='k')
    fig.subplots_adjust(hspace = .375, wspace=.1)

    axes = axs.ravel()

    for i in range(6):
        index_ = i + wave_idx
        max_adc = int((max(x_test_[index_])))
        
        if not (max_adc < 20 and cnn_pred[index_] > min_cnn and cnn_pred[index_] <= max_cnn and sum(abs(y_test_[index_])) != 0):
            while True:
                index_ += 1
                max_adc = int((max(x_test_[index_])))
                
                if (max_adc < 20 and cnn_pred[index_] > min_cnn and cnn_pred[index_] <= max_cnn and sum(abs(y_test_[index_])) != 0):
                    break
        wave_idx = index_


        axes[i].plot(x_test_[index_], color='black',alpha=0.2, label = 'original input (adc_max: ' + str(max_adc) + ')')
        axes[i].plot(y_test_[index_],color='blue', label='target', alpha=1)
        axes[i].plot(pred128[index_], color='m', label='model_128  ---   ' + str(pred_labels128[index_]))
        axes[i].plot(pred128_cmse[index_], color='green', label='model_128_cmse  ---   ' + str(pred_labels128_cmse[index_]))
        axes[i].legend(fontsize=12)
        axes[i].set_title('CNN output: ' + str(round(cnn_pred[index_], 4)) + ' --- [idx: ' + str(index_) + ']', size=15)
        axes[i].set_ylabel('ADC', size=12)


    plt.savefig('./AE_TEST/pdfs/tmp_plts/plts_cnn_page' + str(pg_num) +  '.pdf',
                dpi=300,
                bbox_inches='tight', pad_inches=0.75)
    plt.close()

    return wave_idx

# %%
# creates and merges pdf, removes all single page pdfs from tmp folder
def make_complete_pdf(num_pages, min_cnn, max_cnn):
    wave_idx_ = 0
    page_num = 0

    while page_num < num_pages:
        wave_idx_ = make_single_pdf(wave_idx_, page_num, min_cnn, max_cnn) + 1
        page_num += 1

    merger = PdfMerger()
    path = './AE_TEST/pdfs/tmp_plts/'
    pdf_files = [path+f for f in listdir(path) if (isfile(join(path, f)))]
    print(pdf_files)
    for pdf_file in pdf_files:
        #Append PDF files
        merger.append(pdf_file)
    #merger.write('pdfs/plts_tmp/plts_' + wireplane + '_cnn_'+str(int(min_cnn*100)) + '-' + str(int(max_cnn*100)) + '_' + str(num_pages) +  'pages.pdf')
    merger.write('./AE_TEST/pdfs/'+wireplane+'/plts_' + wireplane + '_cnn_'+str(int(min_cnn*100)) + '-' + str(int(max_cnn*100)) + '_' + str(num_pages) +  'pages.pdf')
    merger.close()

    for file in pdf_files:
        os.remove(file)

# %%
make_complete_pdf(10, 0.94, 1)

# %%
min_ = 0.94
prev = min_
max_ = 1
while min_ > 0:
    min_ = min_ - 0.2 
    make_complete_pdf(10, min_, prev)
    prev = min_
