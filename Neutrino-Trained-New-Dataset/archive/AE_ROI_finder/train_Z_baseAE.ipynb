# %% [markdown]
# train autoencoder WITHOUT using 1DCNN roi finder

# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split 
from sklearn.utils import shuffle
from PyPDF2 import PdfMerger
import os
from tensorflow.keras.models import load_model
# Out:
# 2023-06-03 16:31:27.661054: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-03 16:31:27.662977: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-03 16:31:27.695712: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-03 16:31:27.696361: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-03 16:31:28.346935: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
wireplane = "Z"
np.random.seed(77)
path = '/home/vlian/Workspace/processed_data_LATEST/'

# %%
def load_data(path, wireplane):
    x_train = np.load(path+'x_train_' + wireplane + '.npy')
    x_test = np.load(path+'x_test_' + wireplane + '.npy')
    y_train = np.load(path+'y_train_AE_' + wireplane + '.npy')
    y_test = np.load(path+'y_test_AE_' + wireplane + '.npy')
    
    #split train and valid sets (40k train 10k valid) 
    x_train, x_valid, y_train, y_valid = train_test_split(
        x_train, y_train, test_size=0.2, shuffle=True
    )
    
    mean = x_train.mean()
    std = x_train.std()

    x_train_scaled = (x_train-mean)/std
    x_test_scaled = (x_test-mean)/std
    x_valid_scaled = (x_valid-mean)/std
    
    y_train_scaled = (y_train-mean)/std
    y_test_scaled = (y_test-mean)/std
    y_valid_scaled = (y_valid-mean)/std

    return x_train_scaled, x_test_scaled, y_train_scaled, y_test_scaled, x_valid_scaled, y_valid_scaled, mean, std

# %%
x_train_scaled, x_test_scaled, y_train_scaled, y_test_scaled, x_valid_scaled, y_valid_scaled, mean, std = load_data(path, wireplane)

# %%
np.save('./models/mean_baseAE_'+wireplane, mean)
np.save('./models/std_baseAE_'+wireplane, std)

# %%
for idx in range(6,9):
    fig, (ax1) = plt.subplots(figsize=(12, 2), facecolor='white')
    ax1.plot(x_train_scaled[idx],color='blue', label='signal+noise')
    ax1.plot(y_train_scaled[idx],color='m',alpha=0.7, label='target')
    ax1.set_title("waveform", fontsize=15)
    ax1.legend()

    plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Dense,Flatten, AveragePooling1D
from tensorflow.keras.layers import Input,  UpSampling1D
from tensorflow.keras.models import Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization
#from keras import backend as K

# %%
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Conv1DTranspose

# %%
from tensorflow.keras.models import load_model
cnn_roi_finder = load_model('../ROI_finder/ROI_models/model_'+wireplane+'plane_nu_ROI.h5')

# %%
for i,layer in enumerate(cnn_roi_finder.layers):
  print(i,layer.name)
# Out:
# 0 conv1d
# 1 max_pooling1d
# 2 conv1d_1
# 3 max_pooling1d_1
# 4 dropout
# 5 conv1d_2
# 6 global_max_pooling1d
# 7 dropout_1
# 8 flatten
# 9 wavrec_out

# %%
time_periods = 200
input_wave = Input(shape=(time_periods, 1)) 
x = Conv1D(filters=16, kernel_size=3, strides=2, activation="relu", weights=cnn_roi_finder.layers[0].get_weights(), input_shape=(time_periods,1))(input_wave)
x = MaxPooling1D(pool_size=2)(x)
 
# second convolutional block
x = Conv1D(filters=32, kernel_size=5, strides=2,weights=cnn_roi_finder.layers[2].get_weights(), activation="relu")(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.1)(x)

x = Conv1D(filters=64, kernel_size=9, strides=1, weights=cnn_roi_finder.layers[5].get_weights(), activation="relu")(x)

x = GlobalMaxPooling1D()(x)

x = Dropout(0.2)(x)

encoded = Reshape((1, x.shape[1]), name='encoded')(x)


x = UpSampling1D(size=3)(encoded)


# first deconvolutional block
x = Conv1DTranspose(filters=64, kernel_size=9, strides =1, activation="relu")(x)
x = UpSampling1D(size=2)(x)

x = Dropout(0.1)(x)

# second deconvolutional block
x = Conv1DTranspose(filters=32, kernel_size=5, strides=2, activation="relu")(x)

x = UpSampling1D(size=2)(x) # increase the size to match the encoder

decoded = Conv1DTranspose(filters=16, kernel_size=3, strides=2, activation="relu")(x)
decoded = Conv1DTranspose(filters=1, kernel_size=12, strides=1)(decoded)
autoencoder = Model(input_wave, decoded)

# %%
for i,layer in enumerate(autoencoder.layers):                                      
  print(i,layer.name)
# Out:
# 0 input_1
# 1 conv1d
# 2 max_pooling1d
# 3 conv1d_1
# 4 max_pooling1d_1
# 5 dropout
# 6 conv1d_2
# 7 global_max_pooling1d
# 8 dropout_1
# 9 encoded
# 10 up_sampling1d
# 11 conv1d_transpose
# 12 up_sampling1d_1
# 13 dropout_2
# 14 conv1d_transpose_1
# 15 up_sampling1d_2
# 16 conv1d_transpose_2
# 17 conv1d_transpose_3

# %%
# see what happens when we unfreeze more layers of the 1dcnn
for layer in autoencoder.layers[:9]:                                               
    layer.trainable=False                                                          
for layer in autoencoder.layers[9:]:                                               
    layer.trainable=True                                                           
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 1)]          0
#
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  encoded (Reshape)           (None, 1, 64)             0
#
#  up_sampling1d (UpSampling1D  (None, 3, 64)            0
#  )
#
#  conv1d_transpose (Conv1DTra  (None, 11, 64)           36928
#  nspose)
#
#  up_sampling1d_1 (UpSampling  (None, 22, 64)           0
#  1D)
#
#  dropout_2 (Dropout)         (None, 22, 64)            0
#
#  conv1d_transpose_1 (Conv1DT  (None, 47, 32)           10272
#  ranspose)
#
#  up_sampling1d_2 (UpSampling  (None, 94, 32)           0
#  1D)
#
#  conv1d_transpose_2 (Conv1DT  (None, 189, 16)          1552
#  ranspose)
#
#  conv1d_transpose_3 (Conv1DT  (None, 200, 1)           193
#  ranspose)
#
# =================================================================
# Total params: 70,097
# Trainable params: 48,945
# Non-trainable params: 21,152
# _________________________________________________________________

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
batch_size_ = 2048

# %%
# %%time
history = autoencoder.fit(x_train_scaled,                                                              
            y_train_scaled,                                                            
            batch_size=batch_size_,                                              
            epochs=1000,                                                      
            callbacks= [earlystop], #[NewCallback(alpha)], # callbacks=callbacks_list,
            validation_data=(x_valid_scaled, y_valid_scaled),                                                                      
            verbose=1)
# Out:
# Epoch 1/1000
# 40/40 [==============================] - 4s 86ms/step - loss: 1.0760 - val_loss: 0.6693
# Epoch 2/1000
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6729 - val_loss: 0.5432
# Epoch 3/1000
# 40/40 [==============================] - 3s 82ms/step - loss: 0.5905 - val_loss: 0.4776
# Epoch 4/1000
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5473 - val_loss: 0.4643
# Epoch 5/1000
# 40/40 [==============================] - 3s 86ms/step - loss: 0.5085 - val_loss: 0.4093
# Epoch 6/1000
# 40/40 [==============================] - 3s 86ms/step - loss: 0.4821 - val_loss: 0.3829
# Epoch 7/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.4574 - val_loss: 0.3852
# Epoch 8/1000
# 40/40 [==============================] - 3s 86ms/step - loss: 0.4392 - val_loss: 0.3485
# Epoch 9/1000
# 40/40 [==============================] - 4s 88ms/step - loss: 0.4210 - val_loss: 0.3442
# Epoch 10/1000
# 40/40 [==============================] - 3s 85ms/step - loss: 0.4105 - val_loss: 0.3240
# Epoch 11/1000
# 40/40 [==============================] - 3s 86ms/step - loss: 0.4019 - val_loss: 0.3328
# Epoch 12/1000
# 40/40 [==============================] - 3s 85ms/step - loss: 0.3940 - val_loss: 0.2983
# Epoch 13/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.3905 - val_loss: 0.3424
# Epoch 14/1000
# 40/40 [==============================] - 4s 93ms/step - loss: 0.3756 - val_loss: 0.2854
# Epoch 15/1000
# 40/40 [==============================] - 4s 94ms/step - loss: 0.3717 - val_loss: 0.2952
# Epoch 16/1000
# 40/40 [==============================] - 3s 88ms/step - loss: 0.3644 - val_loss: 0.2912
# Epoch 17/1000
# 40/40 [==============================] - 3s 88ms/step - loss: 0.3570 - val_loss: 0.2992
# Epoch 18/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.3668 - val_loss: 0.2790
# Epoch 19/1000
# 40/40 [==============================] - 3s 88ms/step - loss: 0.3512 - val_loss: 0.2689
# Epoch 20/1000
# 40/40 [==============================] - 4s 90ms/step - loss: 0.3465 - val_loss: 0.2805
# Epoch 21/1000
# 40/40 [==============================] - 3s 86ms/step - loss: 0.3503 - val_loss: 0.2822
# Epoch 22/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.3368 - val_loss: 0.2581
# Epoch 23/1000
# 40/40 [==============================] - 4s 88ms/step - loss: 0.3307 - val_loss: 0.2565
# Epoch 24/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.3282 - val_loss: 0.2602
# Epoch 25/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.3275 - val_loss: 0.2481
# Epoch 26/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.3211 - val_loss: 0.2588
# Epoch 27/1000
# 40/40 [==============================] - 4s 88ms/step - loss: 0.3263 - val_loss: 0.2357
# Epoch 28/1000
# 40/40 [==============================] - 4s 88ms/step - loss: 0.3178 - val_loss: 0.2247
# Epoch 29/1000
# 40/40 [==============================] - 4s 88ms/step - loss: 0.3183 - val_loss: 0.2342
# Epoch 30/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.3111 - val_loss: 0.2655
# Epoch 31/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.3117 - val_loss: 0.2118
# Epoch 32/1000
# 40/40 [==============================] - 3s 86ms/step - loss: 0.3121 - val_loss: 0.2673
# Epoch 33/1000
# 40/40 [==============================] - 4s 90ms/step - loss: 0.3299 - val_loss: 0.2332
# Epoch 34/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.3072 - val_loss: 0.2345
# Epoch 35/1000
# 40/40 [==============================] - 3s 88ms/step - loss: 0.3057 - val_loss: 0.2325
# Epoch 36/1000
# 40/40 [==============================] - 3s 88ms/step - loss: 0.3039 - val_loss: 0.2298
# Epoch 37/1000
# 40/40 [==============================] - 4s 91ms/step - loss: 0.3002 - val_loss: 0.2405
# Epoch 38/1000
# 40/40 [==============================] - 4s 90ms/step - loss: 0.2960 - val_loss: 0.2192
# Epoch 39/1000
# 40/40 [==============================] - 4s 92ms/step - loss: 0.2946 - val_loss: 0.2237
# Epoch 40/1000
# 40/40 [==============================] - 4s 90ms/step - loss: 0.2967 - val_loss: 0.2391
# Epoch 41/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2879 - val_loss: 0.2110
# Epoch 42/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.2918 - val_loss: 0.2256
# Epoch 43/1000
# 40/40 [==============================] - 3s 84ms/step - loss: 0.2827 - val_loss: 0.2197
# Epoch 44/1000
# 40/40 [==============================] - 3s 84ms/step - loss: 0.2843 - val_loss: 0.2093
# Epoch 45/1000
# 40/40 [==============================] - 3s 85ms/step - loss: 0.2837 - val_loss: 0.2180
# Epoch 46/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.2837 - val_loss: 0.2290
# Epoch 47/1000
# 40/40 [==============================] - 4s 90ms/step - loss: 0.2858 - val_loss: 0.2277
# Epoch 48/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.2866 - val_loss: 0.2308
# Epoch 49/1000
# 40/40 [==============================] - 4s 108ms/step - loss: 0.2866 - val_loss: 0.2044
# Epoch 50/1000
# 40/40 [==============================] - 4s 97ms/step - loss: 0.2732 - val_loss: 0.2090
# Epoch 51/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.2844 - val_loss: 0.2093
# Epoch 52/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.2810 - val_loss: 0.2281
# Epoch 53/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.2721 - val_loss: 0.2110
# Epoch 54/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.2764 - val_loss: 0.2101
# Epoch 55/1000
# 40/40 [==============================] - 4s 96ms/step - loss: 0.2682 - val_loss: 0.1961
# Epoch 56/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2657 - val_loss: 0.2024
# Epoch 57/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2734 - val_loss: 0.1980
# Epoch 58/1000
# 40/40 [==============================] - 4s 88ms/step - loss: 0.2662 - val_loss: 0.2611
# Epoch 59/1000
# 40/40 [==============================] - 3s 87ms/step - loss: 0.2768 - val_loss: 0.2196
# Epoch 60/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2701 - val_loss: 0.2087
# Epoch 61/1000
# 40/40 [==============================] - 4s 92ms/step - loss: 0.2660 - val_loss: 0.2018
# Epoch 62/1000
# 40/40 [==============================] - 4s 92ms/step - loss: 0.2600 - val_loss: 0.2087
# Epoch 63/1000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.2657 - val_loss: 0.2132
# Epoch 64/1000
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2907 - val_loss: 0.2139
# Epoch 65/1000
# 40/40 [==============================] - 4s 91ms/step - loss: 0.2664 - val_loss: 0.2056
# CPU times: user 16min 52s, sys: 11.8 s, total: 17min 4s
# Wall time: 3min 52s

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['loss'], "r", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "g--", label="Loss of validation data", antialiased=True)
plt.title('Model Loss',fontsize=15)                                            
plt.ylabel('Loss (MSE)', fontsize=12)                                                 
plt.xlabel('Training Epoch', fontsize=12)                                                                                                                       
plt.legend(fontsize=12)                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 5419

# %%
autoencoder.save('./models/model_AE_'+str(batch_size_)+'_baseAE' + wireplane + 'plane_nu.h5')

# %%
#autoencoder = load_model('./models/model_AE_'+str(batch_size_)+'_mirrored_1dcnn' + wireplane + 'plane_nu.h5')

# %%
autoencoder.evaluate(x_test_scaled, y_test_scaled, batch_size=4096)
# Out:
# 25/25 [==============================] - 2s 76ms/step - loss: 0.1980
# 0.19801339507102966

# %%
autoencoder.evaluate(x_train_scaled, y_train_scaled, batch_size=4096)
# Out:
# 20/20 [==============================] - 1s 71ms/step - loss: 0.1961
# 0.19610241055488586

# %%
autoencoder.evaluate(x_valid_scaled, y_valid_scaled, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1961
# 0.19611909985542297

# %%
#ae128 = load_model('./AE_models/model_AE_'+str(batch_size_)+'_mse' + wireplane + 'plane_nu.h5')

# %%
# %%time
predictions = autoencoder.predict(x_test_scaled, batch_size=4096)
predictions = predictions.reshape(predictions.shape[0], predictions.shape[1])
# Out:
# 25/25 [==============================] - 2s 74ms/step
# CPU times: user 7.36 s, sys: 58.9 ms, total: 7.42 s
# Wall time: 2.15 s

# %%
from scipy import stats
x_test_ = std*x_test_scaled+mean
y_test_ = y_test_scaled*std + mean


pred = predictions*std + mean

# %%
# takes in prediction of AE and for every wave assigns 0 or 1
# 0 --> predicted as noise
# 1 --> pricicted as containing some kind of signals
# note that this is crude and does not consider how close the predicted signal is from truth
def label_predictions(ae_pred_wave):
    label_ = 0
    if max(abs(ae_pred_wave)) > 3:
        label_ = 1
    return label_


def label_truths(wave):
    label_ = 1
    if max(abs(wave)) <= 3:
        label_ = 0
    return label_

# %%
pred_labels = [label_predictions(wave) for wave in pred]
truth_labels = [label_truths(t_wave) for t_wave in y_test_]

# %%
cnn = load_model('../ROI_finder/ROI_models/model_'+wireplane+'plane_nu_ROI.h5')
cnn_pred = cnn.predict(x_test_scaled, batch_size=4096)
cnn_pred = cnn_pred.squeeze()
# Out:
# 25/25 [==============================] - 0s 13ms/step

# %%
for i in range(100,200):
    if max(abs(y_test_[i])) < 20 and sum(abs(y_test_[i])) !=0:
        fig = plt.figure(figsize=(10,4))
        plt.plot(x_test_[i], color='black', alpha=0.3, label='input')
        plt.plot(y_test_[i], color='blue', alpha=0.9, label='truth ----- ' + str(truth_labels[i]))
        plt.plot(pred[i], color='m', alpha=0.7, label='pred ----- ' + str(pred_labels[i]))
        plt.title('CNN output: ' + str( round(cnn_pred[i], 3)))
        plt.legend()
        plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

fpr, tpr, thresholds = roc_curve(truth_labels, pred_labels, drop_intermediate=False)
roc_auc = auc(fpr, tpr)

# %%
fig = plt.figure(figsize=(8, 4))
plt.plot(fpr, tpr, color='m', label='(area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--', lw=2)
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate', size=12)
plt.ylabel('True Positive Rate', size=12)
plt.title('ROC Curve', size=12)
plt.legend(loc="lower right")
plt.show()

# %%
def make_single_pdf(wave_idx, pg_num, min_cnn, max_cnn):

    fig, axs = plt.subplots(3,2, figsize=(30, 18), facecolor='w', edgecolor='k')
    fig.subplots_adjust(hspace = .375, wspace=.1)

    axes = axs.ravel()

    for i in range(6):
        index_ = i + wave_idx
        max_adc = int((max(x_test_[index_])))
        
        if not (max_adc < 20 and cnn_pred[index_] > min_cnn and cnn_pred[index_] <= max_cnn and sum(abs(y_test_[index_])) != 0):
            while True:
                index_ += 1
                max_adc = int((max(x_test_[index_])))
                
                if (max_adc < 20 and cnn_pred[index_] > min_cnn and cnn_pred[index_] <= max_cnn and sum(abs(y_test_[index_])) != 0):
                    break
        wave_idx = index_


        axes[i].plot(x_test_[index_], color='black',alpha=0.2, label = 'original input (adc_max: ' + str(max_adc) + ')')
        axes[i].plot(y_test_[index_],color='blue', label='target', alpha=1)
        axes[i].plot(pred[index_],color='m', label='pred', alpha=1)
        
        axes[i].legend(fontsize=12)
        axes[i].set_title('CNN output: ' + str(round(cnn_pred[index_], 4)) + ' --- [idx: ' + str(index_) + ']', size=15)
        axes[i].set_ylabel('ADC', size=12)


    plt.savefig('./plots/tmp/plts_cnn_page' + str(pg_num) +  '.pdf',
                dpi=300,
                bbox_inches='tight', pad_inches=0.75)
    plt.close()

    return wave_idx

# %%
# creates and merges pdf, removes all single page pdfs from tmp folder
def make_complete_pdf(num_pages, min_cnn, max_cnn):
    wave_idx_ = 0
    page_num = 0

    while page_num < num_pages:
        wave_idx_ = make_single_pdf(wave_idx_, page_num, min_cnn, max_cnn) + 1
        page_num += 1

    merger = PdfMerger()
    path = './plots/tmp/'
    pdf_files = [path+f for f in listdir(path) if (isfile(join(path, f)))]
    print(pdf_files)
    for pdf_file in pdf_files:
        #Append PDF files
        merger.append(pdf_file)
    #merger.write('pdfs/plts_tmp/plts_' + wireplane + '_cnn_'+str(int(min_cnn*100)) + '-' + str(int(max_cnn*100)) + '_' + str(num_pages) +  'pages.pdf')
    merger.write('./plots/'+wireplane+'/plts_' + wireplane + '_cnn_'+str(int(min_cnn*100)) + '-' + str(int(max_cnn*100)) + '_' + str(num_pages) +  'pages.pdf')
    merger.close()

    for file in pdf_files:
        os.remove(file)

# %%
make_complete_pdf(10, 0.94, 1)
# Out:
# ['./plots/tmp/plts_cnn_page2.pdf', './plots/tmp/plts_cnn_page1.pdf', './plots/tmp/plts_cnn_page9.pdf', './plots/tmp/plts_cnn_page4.pdf', './plots/tmp/plts_cnn_page6.pdf', './plots/tmp/plts_cnn_page0.pdf', './plots/tmp/plts_cnn_page7.pdf', './plots/tmp/plts_cnn_page3.pdf', './plots/tmp/plts_cnn_page8.pdf', './plots/tmp/plts_cnn_page5.pdf']

# %%
min_ = 0.94
prev = min_
max_ = 1
while min_ > 0:
    min_ = min_ - 0.2 
    make_complete_pdf(10, min_, prev)
    prev = min_
# Out:
# ['./plots/tmp/plts_cnn_page2.pdf', './plots/tmp/plts_cnn_page1.pdf', './plots/tmp/plts_cnn_page9.pdf', './plots/tmp/plts_cnn_page4.pdf', './plots/tmp/plts_cnn_page6.pdf', './plots/tmp/plts_cnn_page0.pdf', './plots/tmp/plts_cnn_page7.pdf', './plots/tmp/plts_cnn_page3.pdf', './plots/tmp/plts_cnn_page8.pdf', './plots/tmp/plts_cnn_page5.pdf']
# ['./plots/tmp/plts_cnn_page2.pdf', './plots/tmp/plts_cnn_page1.pdf', './plots/tmp/plts_cnn_page9.pdf', './plots/tmp/plts_cnn_page4.pdf', './plots/tmp/plts_cnn_page6.pdf', './plots/tmp/plts_cnn_page0.pdf', './plots/tmp/plts_cnn_page7.pdf', './plots/tmp/plts_cnn_page3.pdf', './plots/tmp/plts_cnn_page8.pdf', './plots/tmp/plts_cnn_page5.pdf']
# ['./plots/tmp/plts_cnn_page2.pdf', './plots/tmp/plts_cnn_page1.pdf', './plots/tmp/plts_cnn_page9.pdf', './plots/tmp/plts_cnn_page4.pdf', './plots/tmp/plts_cnn_page6.pdf', './plots/tmp/plts_cnn_page0.pdf', './plots/tmp/plts_cnn_page7.pdf', './plots/tmp/plts_cnn_page3.pdf', './plots/tmp/plts_cnn_page8.pdf', './plots/tmp/plts_cnn_page5.pdf']
# ['./plots/tmp/plts_cnn_page2.pdf', './plots/tmp/plts_cnn_page1.pdf', './plots/tmp/plts_cnn_page9.pdf', './plots/tmp/plts_cnn_page4.pdf', './plots/tmp/plts_cnn_page6.pdf', './plots/tmp/plts_cnn_page0.pdf', './plots/tmp/plts_cnn_page7.pdf', './plots/tmp/plts_cnn_page3.pdf', './plots/tmp/plts_cnn_page8.pdf', './plots/tmp/plts_cnn_page5.pdf']
# ['./plots/tmp/plts_cnn_page2.pdf', './plots/tmp/plts_cnn_page1.pdf', './plots/tmp/plts_cnn_page9.pdf', './plots/tmp/plts_cnn_page4.pdf', './plots/tmp/plts_cnn_page6.pdf', './plots/tmp/plts_cnn_page0.pdf', './plots/tmp/plts_cnn_page7.pdf', './plots/tmp/plts_cnn_page3.pdf', './plots/tmp/plts_cnn_page8.pdf', './plots/tmp/plts_cnn_page5.pdf']
