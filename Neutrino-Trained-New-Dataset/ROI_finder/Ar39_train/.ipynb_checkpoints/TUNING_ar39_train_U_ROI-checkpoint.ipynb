# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import helper_functions as f
# Out:
# 2023-07-19 18:08:12.313381: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 18:08:13.142043: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load SIGNALS

# %%
wireplane = "U"
np.random.seed(77)
path = ('/home/vlian/Workspace/ar39_samples/processed/' +wireplane+'/')

# %%
dataset_adc_5_13 = np.load(path+'adc_5_13.npz', allow_pickle=True)

# %%
dataset_adc_14_16 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_14_16_U.npz', allow_pickle=True)

# %%
dataset_adc_gt_eq_17 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_gt_eq_17_U_ar39.npz', allow_pickle=True)

# %%
list(dataset_adc_14_16.keys())
# Out:
# ['adc_14', 'adc_15', 'adc_16']

# %%
list(dataset_adc_gt_eq_17.keys())
# Out:
# ['adc_17', 'adc_18', 'adc_19', 'adc_20', 'adc_21', 'adc_22', 'adc_gt_22']

# %%
adc_5_7 = dataset_adc_5_13['adc_5_7']
adc_8_10 = dataset_adc_5_13['adc_8_10']
adc_11_13 = dataset_adc_5_13['adc_11_13']

# %%
adc_14 = dataset_adc_14_16['adc_14']
adc_15 = dataset_adc_14_16['adc_15']
adc_16 = dataset_adc_14_16['adc_16']

# %%
adc_17 = dataset_adc_gt_eq_17['adc_17']
adc_18 = dataset_adc_gt_eq_17['adc_18']
adc_19 = dataset_adc_gt_eq_17['adc_19']
adc_20 = dataset_adc_gt_eq_17['adc_20']
adc_21 = dataset_adc_gt_eq_17['adc_21']
adc_22 = dataset_adc_gt_eq_17['adc_22']
adc_gt_22 = dataset_adc_gt_eq_17['adc_gt_22']

# %%
def cut_data(adc_group, type_):
    if type_:
        num_samples = 54000
    else:
        num_samples = 18000
    
    x = adc_group[0][0:num_samples]
    y = adc_group[1][0:num_samples]
    
    print(x.shape, y.shape)
    
    return x, y

# %%
adc_5_7_x, adc_5_7_y = cut_data(adc_5_7, True)
adc_8_10_x, adc_8_10_y = cut_data(adc_8_10, True)
adc_11_13_x, adc_11_13_y = cut_data(adc_11_13, True)

adc_14_x, adc_14_y = cut_data(adc_14, False)
adc_15_x, adc_15_y = cut_data(adc_15, False)
adc_16_x, adc_16_y = cut_data(adc_16, False)
adc_17_x, adc_17_y = cut_data(adc_17, False)
adc_18_x, adc_18_y = cut_data(adc_18, False)
adc_19_x, adc_19_y = cut_data(adc_19, False)
adc_20_x, adc_20_y = cut_data(adc_20, False)
adc_21_x, adc_21_y = cut_data(adc_21, False)
adc_22_x, adc_22_y = cut_data(adc_22, False)
adc_gt_22_x, adc_gt_22_y = cut_data(adc_gt_22, True)

del adc_5_7, adc_8_10, adc_11_13, adc_14, adc_15, adc_16, adc_17, adc_18, adc_19, adc_20, adc_21, adc_22, adc_gt_22
# Out:
# (54000, 200) (54000, 200)
# (54000, 200) (54000, 200)
# (54000, 200) (54000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (18000, 200) (18000, 200)
# (54000, 200) (54000, 200)

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.plot(adc_8_10_x[i])
    plt.plot(adc_8_10_y[i])
    plt.show()

# %%
x_train = np.empty((0,200))
x_train = np.concatenate((x_train, adc_5_7_x))
x_train = np.concatenate((x_train, adc_8_10_x))
x_train = np.concatenate((x_train, adc_11_13_x))
x_train = np.concatenate((x_train, adc_14_x))
x_train = np.concatenate((x_train, adc_15_x))
x_train = np.concatenate((x_train, adc_16_x))
x_train = np.concatenate((x_train, adc_17_x))
x_train = np.concatenate((x_train, adc_18_x))
x_train = np.concatenate((x_train, adc_19_x))
x_train = np.concatenate((x_train, adc_20_x))
x_train = np.concatenate((x_train, adc_21_x))
x_train = np.concatenate((x_train, adc_22_x))
x_train = np.concatenate((x_train, adc_gt_22_x))

y_train = np.empty((0,200))
y_train = np.concatenate((y_train, adc_5_7_y))
y_train = np.concatenate((y_train, adc_8_10_y))
y_train = np.concatenate((y_train, adc_11_13_y))
y_train = np.concatenate((y_train, adc_14_y))
y_train = np.concatenate((y_train, adc_15_y))
y_train = np.concatenate((y_train, adc_16_y))
y_train = np.concatenate((y_train, adc_17_y))
y_train = np.concatenate((y_train, adc_18_y))
y_train = np.concatenate((y_train, adc_19_y))
y_train = np.concatenate((y_train, adc_20_y))
y_train = np.concatenate((y_train, adc_21_y))
y_train = np.concatenate((y_train, adc_22_y))
y_train = np.concatenate((y_train, adc_gt_22_y))

# %%
print(x_train.shape, y_train.shape)
# Out:
# (378000, 200) (378000, 200)

# %%
for i in range(300000,300000+10):
    fig = plt.figure(figsize=(8,1))
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
for i in range(100):
    x_train, y_train = shuffle(x_train, y_train)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (378000, 200) (378000, 200)

# %%
roi_truth_signals = np.ones(y_train.shape[0])

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.title(str(max(y_train[i])) + ' -- ' + str(roi_truth_signals[i]) )
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
check_grouping = f.adc_grouping(x_train, y_train)
del check_grouping
# Out:
#  0: adc_5_7             1: adc_8_10             2: adc_11_13             3: adc_14_16             4: adc_17_19             5: adc_20_22             6: adc_gt_22
#
# adc_5_7
# count       54000
#
# adc_8_10
# count       54000
#
# adc_11_13
# count       54000
#
# adc_14_16
# count       54000
#
# adc_17_19
# count       54000
#
# adc_20_22
# count       54000
#
# adc_gt_22
# count       54000
#
#      Total:    378000

# %% [markdown]
# ## Load NOISE

# %%
noise_path = '/home/vlian/Workspace/more-noise/U/'
noise_filenames = sorted([f for f in listdir(noise_path) if (isfile(join(noise_path, f)) and wireplane in f)])
combined_noise = np.concatenate([np.load(noise_path+fname, mmap_mode='r') for fname in noise_filenames])

noise_waveforms = f.get_std_waveforms(combined_noise, 200)
roi_truth_noise = np.zeros(noise_waveforms.shape[0]) # for autoencoder
print(noise_waveforms.shape, roi_truth_noise.shape)
# Out:
# (1400000, 200) (1400000,)

# %%
for i in range(10):
    noise_waveforms = shuffle(noise_waveforms)

# %%
noise_waveforms = noise_waveforms[:y_train.shape[0]]
roi_truth_noise = roi_truth_noise[:y_train.shape[0]]

# %%
print(noise_waveforms.shape, roi_truth_noise.shape)
# Out:
# (378000, 200) (378000,)

# %% [markdown]
# ## Train/Test Split - Signals

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, roi_truth_signals, test_size=0.4, shuffle=True)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (226800, 200) (151200, 200) (226800,) (151200,)

# %% [markdown]
# #### Train/Val Split - Signals

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, shuffle=True)
print(x_train.shape, x_valid.shape, y_train.shape, y_valid.shape)
# Out:
# (181440, 200) (45360, 200) (181440,) (45360,)

# %% [markdown]
# ## Train/Test Split - Noise

# %%
x_noise_train, x_noise_test, y_noise_train, y_noise_test = train_test_split(noise_waveforms, roi_truth_noise, test_size=0.3, shuffle=True)
print(x_noise_train.shape, x_noise_test.shape, y_noise_train.shape, y_noise_test.shape)
# Out:
# (264600, 200) (113400, 200) (264600,) (113400,)

# %% [markdown]
# #### Train/Val Split - Noise

# %%
x_noise_train, x_noise_valid, y_noise_train, y_noise_valid = train_test_split(x_noise_train, y_noise_train, test_size=0.2, shuffle=True)
print(x_noise_train.shape, x_noise_valid.shape, y_noise_train.shape, y_noise_valid.shape)
# Out:
# (211680, 200) (52920, 200) (211680,) (52920,)

# %% [markdown]
# ## Combine Signal + Noise

# %%
x_train = np.concatenate((x_train, x_noise_train))
y_train = np.concatenate((y_train, y_noise_train))

x_valid = np.concatenate((x_valid, x_noise_valid))
y_valid = np.concatenate((y_valid, y_noise_valid))

x_test = np.concatenate((x_test, x_noise_test))
y_test = np.concatenate((y_test, y_noise_test))

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (393120, 200) (393120,)
# (98280, 200) (98280,)
# (264600, 200) (264600,)

# %%
for i in range(100):
    x_train, y_train = shuffle(x_train, y_train)
    x_valid, y_valid = shuffle(x_valid, y_valid)
    x_test, y_test = shuffle(x_test, y_test)

# %%
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (393120, 200) (393120,)
# (98280, 200) (98280,)
# (264600, 200) (264600,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
print(mean, std)
# Out:
# 0.004608109483109483 4.888007271376124

# %%
np.save("Tuned_models/mean"+wireplane+"_nu_ROI", mean)
np.save("Tuned_models/scale"+wireplane+"_nu_ROI", std)

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %% [markdown]
# # MODEL

# %%
#!pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Using cached keras_tuner-1.3.5-py3-none-any.whl (176 kB)
# Requirement already satisfied: packaging in /home/vlian/.conda/envs/tf/lib/python3.9/site-packages (from keras-tuner) (23.0)
# Collecting kt-legacy
#   Using cached kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /home/vlian/.conda/envs/tf/lib/python3.9/site-packages (from keras-tuner) (2.28.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vlian/.conda/envs/tf/lib/python3.9/site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vlian/.conda/envs/tf/lib/python3.9/site-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vlian/.conda/envs/tf/lib/python3.9/site-packages (from requests->keras-tuner) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/vlian/.conda/envs/tf/lib/python3.9/site-packages (from requests->keras-tuner) (1.26.15)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

import keras_tuner

# %%
time_periods = 200
def create_model(hp):
    model = Sequential()  
    #first convolutional block
    model.add(Conv1D(filters=hp.Int('conv1_filter', 
                                    min_val = 16, 
                                    max_value=128, step=16), 
                    kernel_size=hp.Choice('conv1_kernel',
                    values=[3,5]), strides=2, 
                    activation = "relu", input_shape=(time_periods,1)))
    #model.add(MaxPooling1D(pool_size=2))

    #second convolutional block
    model.add(Conv1D(filters=hp.Int('conv2_filter',
                                   min_val=32, max_val=128, step=16),
                     kernel_size=hp.Choice('conv2_kernal', values=[3,5])
                     strides=2, activation = "relu"))
    #model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.1))

    #forth convolutional block                                      
    model.add(Conv1D(filters=hp.Int('conv3_filter',
                               min_val=64, max_val=128, step=16),
                 kernel_size=hp.Choice('conv3_kernal', values=[7,9])
                 strides=2, activation = "relu"))
    #model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2)) 

    model.add(Flatten())



    model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
    adam = adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
    print(model.summary())
    return model

# %%
tuner = keras_tuner.RandomSearch(create_model, objective='val_loss',
                                 max_trials=10)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 99, 16)            64
#
#  conv1d_7 (Conv1D)           (None, 48, 32)            2592
#
#  dropout_4 (Dropout)         (None, 48, 32)            0
#
#  conv1d_8 (Conv1D)           (None, 40, 64)            18496
#
#  dropout_5 (Dropout)         (None, 40, 64)            0
#
#  flatten_2 (Flatten)         (None, 2560)              0
#
#  wavrec_out (Dense)          (None, 1)                 2561
#
# =================================================================
# Total params: 23,713
# Trainable params: 23,713
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Search for best model

# %%
tuner.search(x_train_scaled, y_train, epochs=100,
             validation_data=(x_valid_scaled, y_valid),
             verbose=1)
best_model=tuner.get_best_models()[0]
# Out:
# Search: Running Trial #1
#
# default configuration
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  conv1d_1 (Conv1D)           (None, 48, 32)            2592
#
#  dropout (Dropout)           (None, 48, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 40, 64)            18496
#
#  dropout_1 (Dropout)         (None, 40, 64)            0
#
#  flatten (Flatten)           (None, 2560)              0
#
#  wavrec_out (Dense)          (None, 1)                 2561
#
# =================================================================
# Total params: 23,713
# Trainable params: 23,713
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2872 - accuracy: 0.8847 - val_loss: 0.2906 - val_accuracy: 0.8815
# Epoch 2/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2778 - accuracy: 0.8901 - val_loss: 0.2713 - val_accuracy: 0.8923
# Epoch 3/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2766 - accuracy: 0.8907 - val_loss: 0.2702 - val_accuracy: 0.8929
# Epoch 4/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2756 - accuracy: 0.8906 - val_loss: 0.2783 - val_accuracy: 0.8879
# Epoch 5/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2751 - accuracy: 0.8913 - val_loss: 0.2757 - val_accuracy: 0.8890
# Epoch 6/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2751 - accuracy: 0.8914 - val_loss: 0.2762 - val_accuracy: 0.8916
# Epoch 7/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2747 - accuracy: 0.8911 - val_loss: 0.2760 - val_accuracy: 0.8921
# Epoch 8/100
# 12285/12285 [==============================] - 35s 3ms/step - loss: 0.2747 - accuracy: 0.8911 - val_loss: 0.2711 - val_accuracy: 0.8934
# Epoch 9/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2744 - accuracy: 0.8913 - val_loss: 0.2700 - val_accuracy: 0.8927
# Epoch 10/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2745 - accuracy: 0.8910 - val_loss: 0.2732 - val_accuracy: 0.8932
# Epoch 11/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2740 - accuracy: 0.8913 - val_loss: 0.2708 - val_accuracy: 0.8927
# Epoch 12/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2736 - accuracy: 0.8915 - val_loss: 0.2736 - val_accuracy: 0.8932
# Epoch 13/100
# 12285/12285 [==============================] - 32s 3ms/step - loss: 0.2737 - accuracy: 0.8914 - val_loss: 0.2724 - val_accuracy: 0.8928
# Epoch 14/100
# 12285/12285 [==============================] - 31s 3ms/step - loss: 0.2740 - accuracy: 0.8914 - val_loss: 0.2748 - val_accuracy: 0.8927
# Epoch 15/100
# 12285/12285 [==============================] - 31s 3ms/step - loss: 0.2736 - accuracy: 0.8914 - val_loss: 0.2704 - val_accuracy: 0.8921
# Epoch 16/100
# 12285/12285 [==============================] - 31s 3ms/step - loss: 0.2737 - accuracy: 0.8913 - val_loss: 0.2837 - val_accuracy: 0.8852
# Epoch 17/100
# 12285/12285 [==============================] - 31s 3ms/step - loss: 0.2741 - accuracy: 0.8914 - val_loss: 0.2714 - val_accuracy: 0.8925
# Epoch 18/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2738 - accuracy: 0.8918 - val_loss: 0.2776 - val_accuracy: 0.8913
# Epoch 19/100
# 12285/12285 [==============================] - 32s 3ms/step - loss: 0.2739 - accuracy: 0.8912 - val_loss: 0.2698 - val_accuracy: 0.8931
# Epoch 20/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2736 - accuracy: 0.8916 - val_loss: 0.2703 - val_accuracy: 0.8934
# Epoch 21/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2739 - accuracy: 0.8913 - val_loss: 0.2722 - val_accuracy: 0.8925
# Epoch 22/100
# 12285/12285 [==============================] - 35s 3ms/step - loss: 0.2734 - accuracy: 0.8918 - val_loss: 0.2751 - val_accuracy: 0.8900
# Epoch 23/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2740 - accuracy: 0.8916 - val_loss: 0.2747 - val_accuracy: 0.8903
# Epoch 24/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2733 - accuracy: 0.8915 - val_loss: 0.2723 - val_accuracy: 0.8915
# Epoch 25/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2730 - accuracy: 0.8917 - val_loss: 0.2728 - val_accuracy: 0.8928
# Epoch 26/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2730 - accuracy: 0.8916 - val_loss: 0.2750 - val_accuracy: 0.8918
# Epoch 27/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2741 - accuracy: 0.8916 - val_loss: 0.2748 - val_accuracy: 0.8900
# Epoch 28/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2730 - accuracy: 0.8917 - val_loss: 0.2786 - val_accuracy: 0.8881
# Epoch 29/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2729 - accuracy: 0.8916 - val_loss: 0.2799 - val_accuracy: 0.8878
# Epoch 30/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2729 - accuracy: 0.8918 - val_loss: 0.2717 - val_accuracy: 0.8937
# Epoch 31/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2734 - accuracy: 0.8916 - val_loss: 0.2803 - val_accuracy: 0.8873
# Epoch 32/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2738 - accuracy: 0.8916 - val_loss: 0.2709 - val_accuracy: 0.8929
# Epoch 33/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2727 - accuracy: 0.8923 - val_loss: 0.2718 - val_accuracy: 0.8926
# Epoch 34/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2731 - accuracy: 0.8917 - val_loss: 0.2710 - val_accuracy: 0.8931
# Epoch 35/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2733 - accuracy: 0.8914 - val_loss: 0.2817 - val_accuracy: 0.8866
# Epoch 36/100
# 12285/12285 [==============================] - 35s 3ms/step - loss: 0.2736 - accuracy: 0.8915 - val_loss: 0.2788 - val_accuracy: 0.8879
# Epoch 37/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2735 - accuracy: 0.8919 - val_loss: 0.2755 - val_accuracy: 0.8901
# Epoch 38/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2734 - accuracy: 0.8916 - val_loss: 0.2722 - val_accuracy: 0.8923
# Epoch 39/100
# 12285/12285 [==============================] - 33s 3ms/step - loss: 0.2727 - accuracy: 0.8919 - val_loss: 0.2720 - val_accuracy: 0.8917
# Epoch 40/100
# 12285/12285 [==============================] - 34s 3ms/step - loss: 0.2724 - accuracy: 0.8917 - val_loss: 0.2721 - val_accuracy: 0.8928
# Epoch 41/100
# 12285/12285 [==============================] - 38s 3ms/step - loss: 0.2730 - accuracy: 0.8920 - val_loss: 0.2817 - val_accuracy: 0.8869
# Epoch 42/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2732 - accuracy: 0.8913 - val_loss: 0.2745 - val_accuracy: 0.8899
# Epoch 43/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2738 - accuracy: 0.8914 - val_loss: 0.2733 - val_accuracy: 0.8912
# Epoch 44/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2726 - accuracy: 0.8916 - val_loss: 0.2751 - val_accuracy: 0.8910
# Epoch 45/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2731 - accuracy: 0.8917 - val_loss: 0.2798 - val_accuracy: 0.8881
# Epoch 46/100
# 12285/12285 [==============================] - 39s 3ms/step - loss: 0.2738 - accuracy: 0.8915 - val_loss: 0.2720 - val_accuracy: 0.8925
# Epoch 47/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2734 - accuracy: 0.8916 - val_loss: 0.2770 - val_accuracy: 0.8888
# Epoch 48/100
# 12285/12285 [==============================] - 41s 3ms/step - loss: 0.2728 - accuracy: 0.8918 - val_loss: 0.2799 - val_accuracy: 0.8879
# Epoch 49/100
# 12285/12285 [==============================] - 41s 3ms/step - loss: 0.2732 - accuracy: 0.8916 - val_loss: 0.2725 - val_accuracy: 0.8919
# Epoch 50/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2730 - accuracy: 0.8918 - val_loss: 0.2732 - val_accuracy: 0.8922
# Epoch 51/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2735 - accuracy: 0.8913 - val_loss: 0.2735 - val_accuracy: 0.8912
# Epoch 52/100
# 12285/12285 [==============================] - 41s 3ms/step - loss: 0.2732 - accuracy: 0.8916 - val_loss: 0.2825 - val_accuracy: 0.8867
# Epoch 53/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2733 - accuracy: 0.8917 - val_loss: 0.2771 - val_accuracy: 0.8892
# Epoch 54/100
# 12285/12285 [==============================] - 40s 3ms/step - loss: 0.2733 - accuracy: 0.8918 - val_loss: 0.2747 - val_accuracy: 0.8906
# Epoch 55/100
# 12273/12285 [============================>.] - ETA: 0s - loss: 0.2724 - accuracy: 0.8920

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#HERE

import gc
gc.collect()

# %%
model.save("Tuned_models/model" + wireplane + "plane_nu_ROI.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)

# %%
a = [out for out in all_infer if out >= 0.94]

# %%
len(a)/len(all_infer)

# %%
all_infer

# %%
sigs_truth = []
sigs_pred = []

noise_truth = []
noise_pred = []

for i, truth in enumerate(all_y_test):
    if truth == 1:
        sigs_truth.append(truth)
        sigs_pred.append(all_infer[i])
    else:
        noise_truth.append(truth)
        noise_pred.append(all_infer[i])

# %%
print(len(sigs_truth), len(sigs_pred))
print(len(noise_truth), len(noise_pred))

# %%
a = [out for out in sigs_pred if out >= 0.94]

# %%
len(a)/len(sigs_truth)

# %%
a = [out for out in noise_pred if out < 0.94]

# %%
len(a)/len(noise_truth)
