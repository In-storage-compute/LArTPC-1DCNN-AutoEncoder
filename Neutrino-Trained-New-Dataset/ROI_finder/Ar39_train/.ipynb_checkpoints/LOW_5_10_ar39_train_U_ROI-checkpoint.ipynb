# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import helper_functions as f
# Out:
# 2023-07-25 20:08:05.192082: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-25 20:08:06.161484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load SIGNALS

# %%
wireplane = "U"
np.random.seed(77)

# %%
dataset_adc_5_13 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_5_13_U.npz', allow_pickle=True)

# %%
dataset_adc_14_16 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_14_16_U.npz', allow_pickle=True)

# %%
dataset_adc_gt_eq_17 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_gt_eq_17_U_ar39.npz', allow_pickle=True)

# %%
list(dataset_adc_5_13.keys())
# Out:
# ['adc_5',
#  'adc_6',
#  'adc_7',
#  'adc_8',
#  'adc_9',
#  'adc_10',
#  'adc_11',
#  'adc_12',
#  'adc_13']

# %%
list(dataset_adc_14_16.keys())
# Out:
# ['adc_14', 'adc_15', 'adc_16']

# %%
list(dataset_adc_gt_eq_17.keys())
# Out:
# ['adc_17', 'adc_18', 'adc_19', 'adc_20', 'adc_21', 'adc_22', 'adc_gt_22']

# %%
adc_5 = dataset_adc_5_13['adc_5']
adc_6 = dataset_adc_5_13['adc_6']
adc_7 = dataset_adc_5_13['adc_7']
adc_8 = dataset_adc_5_13['adc_8']
adc_9 = dataset_adc_5_13['adc_9']
adc_10 = dataset_adc_5_13['adc_10']

# %%
def cut_data(adc_group, type_):
    if type_:
        num_samples = 100000
    else:
        num_samples = 60000
    
    x = adc_group[0][0:num_samples]
    y = adc_group[1][0:num_samples]
    
    print(x.shape, y.shape)
    
    return x, y

# %%
adc_5_x, adc_5_y = cut_data(adc_5, True)
adc_6_x, adc_6_y = cut_data(adc_6, True)
adc_7_x, adc_7_y = cut_data(adc_7, True)
adc_8_x, adc_8_y = cut_data(adc_8, True)
adc_9_x, adc_9_y = cut_data(adc_9, True)
adc_10_x, adc_10_y = cut_data(adc_10, True)

del adc_5, adc_6, adc_7, adc_8, adc_9, adc_10
# Out:
# (100000, 200) (100000, 200)
# (100000, 200) (100000, 200)
# (100000, 200) (100000, 200)
# (100000, 200) (100000, 200)
# (100000, 200) (100000, 200)
# (100000, 200) (100000, 200)

# %%
x_train = np.empty((0,200))
x_train = np.concatenate((x_train, adc_5_x))
x_train = np.concatenate((x_train, adc_6_x))
x_train = np.concatenate((x_train, adc_7_x))
x_train = np.concatenate((x_train, adc_8_x))
x_train = np.concatenate((x_train, adc_9_x))
x_train = np.concatenate((x_train, adc_10_x))

y_train = np.empty((0,200))
y_train = np.concatenate((y_train, adc_5_y))
y_train = np.concatenate((y_train, adc_6_y))
y_train = np.concatenate((y_train, adc_7_y))
y_train = np.concatenate((y_train, adc_8_y))
y_train = np.concatenate((y_train, adc_9_y))
y_train = np.concatenate((y_train, adc_10_y))

# %%
print(x_train.shape, y_train.shape)
# Out:
# (600000, 200) (600000, 200)

# %%
for i in range(300000,300000+10):
    fig = plt.figure(figsize=(8,1))
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
for i in range(100):
    x_train, y_train = shuffle(x_train, y_train)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (600000, 200) (600000, 200)

# %%
roi_truth_signals = np.ones(y_train.shape[0])

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.title(str(max(y_train[i])) + ' -- ' + str(roi_truth_signals[i]) )
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
check_grouping = f.adc_grouping(x_train, y_train)
del check_grouping
# Out:
#  0: adc_5_7             1: adc_8_10             2: adc_11_13             3: adc_14_16             4: adc_17_19             5: adc_20_22             6: adc_gt_22
#
# adc_5_7
# count       300000
#
# adc_8_10
# count       300000
#
# adc_11_13
# count       0
#
# adc_14_16
# count       0
#
# adc_17_19
# count       0
#
# adc_20_22
# count       0
#
# adc_gt_22
# count       0
#
#      Total:    600000

# %% [markdown]
# ## Load NOISE

# %%
noise_path = '/home/vlian/Workspace/more-noise/U/'
noise_filenames = sorted([f for f in listdir(noise_path) if (isfile(join(noise_path, f)) and wireplane in f)])
combined_noise = np.concatenate([np.load(noise_path+fname, mmap_mode='r') for fname in noise_filenames])

noise_waveforms = f.get_std_waveforms(combined_noise, 200)
noiseless_waveform = noise_waveforms*0 # for autoencoder
roi_truth_noise = np.zeros(noise_waveforms.shape[0]) # for roi finder
print(noise_waveforms.shape, roi_truth_noise.shape)
# Out:
# (1400000, 200) (1400000,)

# %%
for i in range(10):
    noise_waveforms = shuffle(noise_waveforms)

# %%
noise_waveforms = noise_waveforms[:y_train.shape[0]]
noiseless_waveform = noiseless_waveform[:y_train.shape[0]]
roi_truth_noise = roi_truth_noise[:y_train.shape[0]]

# %%
print(noise_waveforms.shape, noiseless_waveform.shape, roi_truth_noise.shape)
# Out:
# (600000, 200) (600000, 200) (600000,)

# %% [markdown]
# ## Train/Test Split - Signals

# %%
x_train, x_test, y_train_ROI, y_test_ROI, y_train_AE, y_test_AE = train_test_split(x_train, roi_truth_signals, y_train, test_size=0.5, shuffle=True)
print(x_train.shape, x_test.shape, y_train_ROI.shape, y_train_AE.shape, y_test_ROI.shape, y_test_AE.shape)
# Out:
# (300000, 200) (300000, 200) (300000,) (300000, 200) (300000,) (300000, 200)

# %% [markdown]
# #### Train/Val Split - Signals

# %%
x_train, x_valid, y_train_ROI, y_valid_ROI, y_train_AE, y_valid_AE = train_test_split(x_train, y_train_ROI, y_train_AE, test_size=0.2, shuffle=True)
print(x_train.shape, x_valid.shape, y_train_ROI.shape, y_train_AE.shape, y_valid_ROI.shape, y_valid_AE.shape)
# Out:
# (240000, 200) (60000, 200) (240000,) (240000, 200) (60000,) (60000, 200)

# %% [markdown]
# ## Train/Test Split - Noise

# %%
x_noise_train, x_noise_test, y_noise_train_ROI, y_noise_test_ROI, y_noise_train_AE, y_noise_test_AE = train_test_split(noise_waveforms, 
                                                                                                     roi_truth_noise, noiseless_waveform, test_size=0.5, shuffle=True)
print(x_noise_train.shape, x_noise_test.shape, y_noise_train_ROI.shape, y_noise_train_AE.shape, y_noise_test_ROI.shape, y_noise_test_AE.shape)
# Out:
# (300000, 200) (300000, 200) (300000,) (300000, 200) (300000,) (300000, 200)

# %% [markdown]
# #### Train/Val Split - Noise

# %%
x_noise_train, x_noise_valid, y_noise_train_ROI, y_noise_valid_ROI, y_noise_train_AE, y_noise_valid_AE = train_test_split(x_noise_train, 
                                                                                                        y_noise_train_ROI, y_noise_train_AE,
                                                                                                        test_size=0.2, shuffle=True)
print(x_noise_train.shape, x_noise_valid.shape, y_noise_train_ROI.shape, y_noise_train_AE.shape, y_noise_valid_ROI.shape, y_noise_valid_AE.shape)
# Out:
# (240000, 200) (60000, 200) (240000,) (240000, 200) (60000,) (60000, 200)

# %% [markdown]
# ## Combine Signal + Noise

# %%
x_train = np.concatenate((x_train, x_noise_train))
y_train_ROI = np.concatenate((y_train_ROI, y_noise_train_ROI))
y_train_AE = np.concatenate((y_train_AE, y_noise_train_AE))

x_valid = np.concatenate((x_valid, x_noise_valid))
y_valid_ROI = np.concatenate((y_valid_ROI, y_noise_valid_ROI))
y_valid_AE = np.concatenate((y_valid_AE, y_noise_valid_AE))

x_test = np.concatenate((x_test, x_noise_test))
y_test_ROI = np.concatenate((y_test_ROI, y_noise_test_ROI))
y_test_AE = np.concatenate((y_test_AE, y_noise_test_AE))

print(x_train.shape, y_train_ROI.shape, y_train_AE.shape)
print(x_valid.shape, y_valid_ROI.shape, y_valid_AE.shape)
print(x_test.shape, y_test_AE.shape, y_test_ROI.shape)
# Out:
# (480000, 200) (480000,) (480000, 200)
# (120000, 200) (120000,) (120000, 200)
# (600000, 200) (600000, 200) (600000,)

# %%
for i in range(100):
    x_train, y_train_ROI, y_train_AE = shuffle(x_train, y_train_ROI, y_train_AE)
    x_valid, y_valid_ROI, y_valid_AE = shuffle(x_valid, y_valid_ROI, y_valid_AE)
    x_test, y_test_ROI, y_test_AE = shuffle(x_test, y_test_ROI, y_test_AE)

# %%
print(x_train.shape, y_train_ROI.shape, y_train_AE.shape)
print(x_valid.shape, y_valid_ROI.shape, y_valid_AE.shape)
print(x_test.shape, y_test_AE.shape, y_test_ROI.shape)
# Out:
# (480000, 200) (480000,) (480000, 200)
# (120000, 200) (120000,) (120000, 200)
# (600000, 200) (600000, 200) (600000,)

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.title(y_train_ROI[i])
    plt.plot(x_valid[i])
    plt.plot(y_train_AE[i])
    plt.show()

# %%
mean = x_train.mean()
std = x_train.std()

# %%
print(mean, std)
# Out:
# 0.007211645833333333 4.529425063827744

# %%
np.save("models_scales/mean_5_10"+wireplane+"_nu", mean)
np.save("models_scales/scale_5_10"+wireplane+"_nu", std)

# %%
x_train_scaled = (x_train-mean)/std
y_train_AE_scaled = (y_train_AE-mean)/std

x_valid_scaled = (x_valid-mean)/std
y_valid_AE_scaled = (y_valid_AE-mean)/std

x_test_scaled = (x_test-mean)/std
y_test_AE_scaled = (y_test_AE-mean)/std

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (480000, 200, 1) (120000, 200, 1) (600000, 200, 1)

# %% [markdown]
# # MODEL - ROI

# %%
#!pip install keras-tuner --upgrade

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
    model = Sequential()  
    #first convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
    model.add(MaxPooling1D(pool_size=2))

    #second convolutional block
    model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.1))

    #forth convolutional block                                      
    model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2)) 

    model.add(Flatten())



    model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
    return model

# %%
model_ROI = create_model()

#lr=0.001
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model_ROI.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model_ROI.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________
# 2023-07-25 20:11:18.516500: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:18.560287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:18.560640: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:18.568741: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:18.569060: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:18.569335: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:19.214539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:19.214897: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:19.215162: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 20:11:19.215419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18083 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 2g.20gb, pci bus id: 0000:05:00.0, compute capability: 8.0

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#%%time
history = model_ROI.fit(x_train_scaled,                                                              
                    y_train_ROI,
                    batch_size = 512,
                    epochs=100,      
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid_ROI),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 2023-07-25 20:11:21.996884: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-25 20:11:23.311760: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 938/938 [==============================] - 8s 5ms/step - loss: 0.5524 - accuracy: 0.7118 - val_loss: 0.5201 - val_accuracy: 0.7380
# Epoch 2/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5254 - accuracy: 0.7348 - val_loss: 0.5190 - val_accuracy: 0.7380
# Epoch 3/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5230 - accuracy: 0.7358 - val_loss: 0.5173 - val_accuracy: 0.7391
# Epoch 4/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5212 - accuracy: 0.7369 - val_loss: 0.5158 - val_accuracy: 0.7408
# Epoch 5/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5201 - accuracy: 0.7378 - val_loss: 0.5167 - val_accuracy: 0.7391
# Epoch 6/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5193 - accuracy: 0.7378 - val_loss: 0.5154 - val_accuracy: 0.7404
# Epoch 7/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5189 - accuracy: 0.7383 - val_loss: 0.5151 - val_accuracy: 0.7408
# Epoch 8/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5179 - accuracy: 0.7390 - val_loss: 0.5152 - val_accuracy: 0.7402
# Epoch 9/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5174 - accuracy: 0.7393 - val_loss: 0.5156 - val_accuracy: 0.7405
# Epoch 10/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5173 - accuracy: 0.7394 - val_loss: 0.5152 - val_accuracy: 0.7408
# Epoch 11/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5166 - accuracy: 0.7396 - val_loss: 0.5161 - val_accuracy: 0.7407
# Epoch 12/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5159 - accuracy: 0.7400 - val_loss: 0.5183 - val_accuracy: 0.7387
# Epoch 13/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5161 - accuracy: 0.7399 - val_loss: 0.5149 - val_accuracy: 0.7415
# Epoch 14/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5155 - accuracy: 0.7402 - val_loss: 0.5152 - val_accuracy: 0.7409
# Epoch 15/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5152 - accuracy: 0.7411 - val_loss: 0.5158 - val_accuracy: 0.7403
# Epoch 16/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5147 - accuracy: 0.7415 - val_loss: 0.5164 - val_accuracy: 0.7407
# Epoch 17/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5143 - accuracy: 0.7414 - val_loss: 0.5157 - val_accuracy: 0.7402
# Epoch 18/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5141 - accuracy: 0.7413 - val_loss: 0.5156 - val_accuracy: 0.7409
# Epoch 19/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5141 - accuracy: 0.7414 - val_loss: 0.5170 - val_accuracy: 0.7400
# Epoch 20/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5139 - accuracy: 0.7412 - val_loss: 0.5162 - val_accuracy: 0.7402
# Epoch 21/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5133 - accuracy: 0.7420 - val_loss: 0.5176 - val_accuracy: 0.7395
# Epoch 22/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5134 - accuracy: 0.7421 - val_loss: 0.5158 - val_accuracy: 0.7407
# Epoch 23/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5131 - accuracy: 0.7418 - val_loss: 0.5165 - val_accuracy: 0.7400

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#HERE

import gc
gc.collect()
# Out:
# 21394

# %%
model_ROI.save("ROI_ar39_models/model_5_10" + wireplane + "plane_nu_ROI.h5")

# %%
model_ROI.evaluate(x_test_scaled, y_test_ROI, batch_size=4096)
# Out:
# 147/147 [==============================] - 1s 4ms/step - loss: 0.5161 - accuracy: 0.7397
# [0.5160507559776306, 0.7397199869155884]

# %%
x_train_ = x_train_scaled
y_train_ = y_train_ROI

x_valid_ = x_valid_scaled
y_valid_ = y_valid_ROI

# %% [markdown]
# # test

# %%
#%%time
all_infer = model_ROI.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test_ROI
# Out:
# 147/147 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model_ROI.predict(x_test_scaled[y_test_ROI==1], batch_size=4096)
all_infer_noise = model_ROI.predict(x_test_scaled[y_test_ROI==0], batch_size=4096)
# Out:
# 74/74 [==============================] - 0s 4ms/step
# 74/74 [==============================] - 0s 3ms/step
# CPU times: user 1.14 s, sys: 639 ms, total: 1.78 s
# Wall time: 1.51 s

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([0.0000e+00, 5.0000e+00, 8.0300e+03, 5.0003e+04, 5.4733e+04,
#         4.3656e+04, 3.3986e+04, 2.6025e+04, 1.9349e+04, 1.4711e+04,
#         1.1069e+04, 8.8450e+03, 7.0570e+03, 5.7140e+03, 4.6590e+03,
#         3.7490e+03, 2.9500e+03, 2.4700e+03, 1.9090e+03, 1.0800e+03]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([0.0000e+00, 1.0000e+00, 1.2340e+03, 1.0291e+04, 1.5746e+04,
#         1.7138e+04, 1.6822e+04, 1.6108e+04, 1.5189e+04, 1.4137e+04,
#         1.3201e+04, 1.2729e+04, 1.2180e+04, 1.1946e+04, 1.2300e+04,
#         1.3003e+04, 1.4528e+04, 1.6887e+04, 2.3157e+04, 6.3403e+04]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
a = [out for out in all_infer if out >= 0.94]

# %%
len(a)/len(all_infer)
# Out:
# 0.11719166666666667

# %%
all_infer
# Out:
# array([[0.17050436],
#        [0.75515544],
#        [0.37134126],
#        ...,
#        [0.20852004],
#        [0.32477087],
#        [0.17401958]], dtype=float32)

# %%
sigs_truth = []
sigs_pred = []

noise_truth = []
noise_pred = []

for i, truth in enumerate(all_y_test):
    if truth == 1:
        sigs_truth.append(truth)
        sigs_pred.append(all_infer[i])
    else:
        noise_truth.append(truth)
        noise_pred.append(all_infer[i])

# %%
print(len(sigs_truth), len(sigs_pred))
print(len(noise_truth), len(noise_pred))
# Out:
# 300000 300000
# 300000 300000

# %%
a = [out for out in sigs_pred if out >= 0.94]

# %%
len(a)/len(sigs_truth)
# Out:
# 0.22969333333333333

# %%
a = [out for out in noise_pred if out < 0.94]

# %%
len(a)/len(noise_truth)
# Out:
# 0.99531

# %% [markdown]
# # MODEL - AE

# %%
from tensorflow.keras.layers import Conv1DTranspose

# %%
time_periods = 200
autoencoder = Sequential()
# encoder
autoencoder.add(Conv1D(filters=16, kernel_size=3, padding="same", strides=2, activation = "relu", input_shape=(time_periods,1)))
autoencoder.add(Conv1D(filters=32, kernel_size=5, padding="same", strides=4, activation = "relu"))
autoencoder.add(Conv1D(filters=64, kernel_size=9, padding="same", strides=5, activation = "relu"))

# decoder
autoencoder.add(Conv1DTranspose(filters=64, kernel_size=9, padding="same", strides=5, activation = "relu"))
autoencoder.add(Conv1DTranspose(filters=32, kernel_size=5, padding="same", strides=4, activation = "relu"))
autoencoder.add(Conv1DTranspose(filters=16, kernel_size=3, padding="same", strides=2, activation = "relu"))

autoencoder.add(Conv1DTranspose(filters=1, kernel_size=3, padding="same"))

autoencoder.compile(loss='mse', optimizer='adam')

# %%
autoencoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 100, 16)           64
#
#  conv1d_4 (Conv1D)           (None, 25, 32)            2592
#
#  conv1d_5 (Conv1D)           (None, 5, 64)             18496
#
#  conv1d_transpose (Conv1DTra  (None, 25, 64)           36928
#  nspose)
#
#  conv1d_transpose_1 (Conv1DT  (None, 100, 32)          10272
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 200, 16)          1552
#  ranspose)
#
#  conv1d_transpose_3 (Conv1DT  (None, 200, 1)           49
#  ranspose)
#
# =================================================================
# Total params: 69,953
# Trainable params: 69,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
history_AE = autoencoder.fit(x_train_scaled,                                                              
            y_train_AE_scaled,                                                            
            batch_size=512,                                              
            epochs=1000,                                                      
            callbacks= [earlystop], #[NewCallback(alpha)], # callbacks=callbacks_list,
            validation_data=(x_valid_scaled, y_valid_AE_scaled),                                                                      
            verbose=1)
# Out:
# Epoch 1/1000
# 2023-07-25 20:13:01.701354: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f0550733dc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-25 20:13:01.701409: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA A100 80GB PCIe MIG 2g.20gb, Compute Capability 8.0
# 2023-07-25 20:13:01.706699: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-25 20:13:02.148950: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 [==============================] - 12s 7ms/step - loss: 0.0350 - val_loss: 0.0327
# Epoch 2/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0326 - val_loss: 0.0327
# Epoch 3/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0324 - val_loss: 0.0325
# Epoch 4/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0323 - val_loss: 0.0326
# Epoch 5/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0323 - val_loss: 0.0324
# Epoch 6/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0322 - val_loss: 0.0323
# Epoch 7/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0322 - val_loss: 0.0323
# Epoch 8/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0321 - val_loss: 0.0324
# Epoch 9/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0321 - val_loss: 0.0324
# Epoch 10/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0320 - val_loss: 0.0324
# Epoch 11/1000
# 938/938 [==============================] - 6s 7ms/step - loss: 0.0320 - val_loss: 0.0324
# Epoch 12/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0320 - val_loss: 0.0323
# Epoch 13/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0319 - val_loss: 0.0324
# Epoch 14/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0319 - val_loss: 0.0324
# Epoch 15/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0319 - val_loss: 0.0324
# Epoch 16/1000
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0318 - val_loss: 0.0325

# %%
predictions = autoencoder.predict(x_test_scaled, batch_size=4096)
predictions = predictions.reshape(predictions.shape[0], predictions.shape[1])
# Out:
# 147/147 [==============================] - 3s 16ms/step

# %%
for i in range(100):
    wave = x_test_scaled[i:i+1]
    if model_ROI.predict(wave) >= 0.94:
        print(wave.shape)
        ae_pred = autoencoder.predict(wave)
        print(ae_pred.shape)
        pred = ae_pred*std + mean
        
        #wave_re_scaled = wave*std + mean
    
        plt.plot(pred[0])
        plt.plot(y_test_AE[i])
        plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 61ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 95ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
autoencoder.save("AE_ar39_models/model_5_10" + wireplane + "plane_nu_AE.h5")
