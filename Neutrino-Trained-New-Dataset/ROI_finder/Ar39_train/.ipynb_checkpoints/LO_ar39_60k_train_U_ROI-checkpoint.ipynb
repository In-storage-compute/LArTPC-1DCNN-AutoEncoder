# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import helper_functions as f
# Out:
# 2023-07-25 21:15:24.847636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-25 21:15:25.706359: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load SIGNALS

# %%
wireplane = "U"
np.random.seed(77)

# %%
dataset_adc_5_13 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_5_13_U.npz', allow_pickle=True)

# %%
dataset_adc_14_16 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_14_16_U.npz', allow_pickle=True)

# %%
dataset_adc_gt_eq_17 = np.load('/home/vlian/Workspace/ar39_new_samples/adc_gt_eq_17_U_ar39.npz', allow_pickle=True)

# %%
list(dataset_adc_5_13.keys())
# Out:
# ['adc_5',
#  'adc_6',
#  'adc_7',
#  'adc_8',
#  'adc_9',
#  'adc_10',
#  'adc_11',
#  'adc_12',
#  'adc_13']

# %%
list(dataset_adc_14_16.keys())
# Out:
# ['adc_14', 'adc_15', 'adc_16']

# %%
list(dataset_adc_gt_eq_17.keys())
# Out:
# ['adc_17', 'adc_18', 'adc_19', 'adc_20', 'adc_21', 'adc_22', 'adc_gt_22']

# %%
adc_5 = dataset_adc_5_13['adc_5']
adc_6 = dataset_adc_5_13['adc_6']
adc_7 = dataset_adc_5_13['adc_7']
adc_8 = dataset_adc_5_13['adc_8']
adc_9 = dataset_adc_5_13['adc_9']
adc_10 = dataset_adc_5_13['adc_10']
adc_11 = dataset_adc_5_13['adc_11']
adc_12 = dataset_adc_5_13['adc_12']
adc_13 = dataset_adc_5_13['adc_13']
adc_14 = dataset_adc_14_16['adc_14']
adc_15 = dataset_adc_14_16['adc_15']
adc_16 = dataset_adc_14_16['adc_16']
adc_17 = dataset_adc_gt_eq_17['adc_17']
adc_18 = dataset_adc_gt_eq_17['adc_18']
adc_19 = dataset_adc_gt_eq_17['adc_19']
adc_20 = dataset_adc_gt_eq_17['adc_20']
adc_21 = dataset_adc_gt_eq_17['adc_21']
adc_22 = dataset_adc_gt_eq_17['adc_22']
adc_gt_22 = dataset_adc_gt_eq_17['adc_gt_22']

# %%
adc_gt_21 = np.concatenate((adc_22, adc_gt_22), axis=1)

# %%
for i in range(10):
    adc_gt_21[0], adc_gt_21[1] = shuffle(adc_gt_21[0], adc_gt_21[1])

# %%
def cut_data(adc_group, type_):
    if type_:
        num_samples = 60000
    else:
        num_samples = 60000
    
    x = adc_group[0][0:num_samples]
    y = adc_group[1][0:num_samples]
    
    print(x.shape, y.shape)
    
    return x, y

# %%
adc_5_x, adc_5_y = cut_data(adc_5, False)
adc_6_x, adc_6_y = cut_data(adc_6, False)
adc_7_x, adc_7_y = cut_data(adc_7, False)
adc_8_x, adc_8_y = cut_data(adc_8, False)
adc_9_x, adc_9_y = cut_data(adc_9, False)
adc_10_x, adc_10_y = cut_data(adc_10, False)
adc_11_x, adc_11_y = cut_data(adc_11, False)
adc_12_x, adc_12_y = cut_data(adc_12, False)
adc_13_x, adc_13_y = cut_data(adc_13, False)

adc_14_x, adc_14_y = cut_data(adc_14, False)
adc_15_x, adc_15_y = cut_data(adc_15, False)
adc_16_x, adc_16_y = cut_data(adc_16, False)
adc_17_x, adc_17_y = cut_data(adc_17, False)
adc_18_x, adc_18_y = cut_data(adc_18, False)
adc_19_x, adc_19_y = cut_data(adc_19, False)
adc_20_x, adc_20_y = cut_data(adc_20, False)
adc_21_x, adc_21_y = cut_data(adc_21, False)
adc_gt_21_x, adc_gt_21_y = cut_data(adc_gt_21, False)

del adc_5, adc_6, adc_7, adc_8, adc_9, adc_10, adc_11, adc_12, adc_13
del adc_14, adc_15, adc_16, adc_17, adc_18, adc_19, adc_20, adc_21, adc_22, adc_gt_22
# Out:
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)
# (60000, 200) (60000, 200)

# %%
x_train = np.empty((0,200))
x_train = np.concatenate((x_train, adc_5_x))
x_train = np.concatenate((x_train, adc_6_x))
x_train = np.concatenate((x_train, adc_7_x))
x_train = np.concatenate((x_train, adc_8_x))
x_train = np.concatenate((x_train, adc_9_x))
x_train = np.concatenate((x_train, adc_10_x))
x_train = np.concatenate((x_train, adc_11_x))
x_train = np.concatenate((x_train, adc_12_x))
x_train = np.concatenate((x_train, adc_13_x))
x_train = np.concatenate((x_train, adc_14_x))
x_train = np.concatenate((x_train, adc_15_x))
x_train = np.concatenate((x_train, adc_16_x))
x_train = np.concatenate((x_train, adc_17_x))
x_train = np.concatenate((x_train, adc_18_x))
x_train = np.concatenate((x_train, adc_19_x))
x_train = np.concatenate((x_train, adc_20_x))
x_train = np.concatenate((x_train, adc_21_x))
x_train = np.concatenate((x_train, adc_gt_21_x))

y_train = np.empty((0,200))
y_train = np.concatenate((y_train, adc_5_y))
y_train = np.concatenate((y_train, adc_6_y))
y_train = np.concatenate((y_train, adc_7_y))
y_train = np.concatenate((y_train, adc_8_y))
y_train = np.concatenate((y_train, adc_9_y))
y_train = np.concatenate((y_train, adc_10_y))
y_train = np.concatenate((y_train, adc_11_y))
y_train = np.concatenate((y_train, adc_12_y))
y_train = np.concatenate((y_train, adc_13_y))
y_train = np.concatenate((y_train, adc_14_y))
y_train = np.concatenate((y_train, adc_15_y))
y_train = np.concatenate((y_train, adc_16_y))
y_train = np.concatenate((y_train, adc_17_y))
y_train = np.concatenate((y_train, adc_18_y))
y_train = np.concatenate((y_train, adc_19_y))
y_train = np.concatenate((y_train, adc_20_y))
y_train = np.concatenate((y_train, adc_21_y))
y_train = np.concatenate((y_train, adc_gt_21_y))

# %%
print(x_train.shape, y_train.shape)
# Out:
# (1080000, 200) (1080000, 200)

# %%
for i in range(300000,300000+10):
    fig = plt.figure(figsize=(8,1))
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
for i in range(100):
    x_train, y_train = shuffle(x_train, y_train)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (1080000, 200) (1080000, 200)

# %%
roi_truth_signals = np.ones(y_train.shape[0])

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.title(str(max(y_train[i])) + ' -- ' + str(roi_truth_signals[i]) )
    plt.plot(x_train[i])
    plt.plot(y_train[i])
    plt.show()

# %%
check_grouping = f.adc_grouping(x_train, y_train)
del check_grouping
# Out:
#  0: adc_5_7             1: adc_8_10             2: adc_11_13             3: adc_14_16             4: adc_17_19             5: adc_20_22             6: adc_gt_22
#
# adc_5_7
# count       180000
#
# adc_8_10
# count       180000
#
# adc_11_13
# count       180000
#
# adc_14_16
# count       180000
#
# adc_17_19
# count       180000
#
# adc_20_22
# count       142385
#
# adc_gt_22
# count       37615
#
#      Total:    1080000

# %% [markdown]
# ## Load NOISE

# %%
noise_path = '/home/vlian/Workspace/more-noise/U/'
noise_filenames = sorted([f for f in listdir(noise_path) if (isfile(join(noise_path, f)) and wireplane in f)])
combined_noise = np.concatenate([np.load(noise_path+fname, mmap_mode='r') for fname in noise_filenames])

noise_waveforms = f.get_std_waveforms(combined_noise, 200)
noiseless_waveform = noise_waveforms*0 # for autoencoder
roi_truth_noise = np.zeros(noise_waveforms.shape[0]) # for roi finder
print(noise_waveforms.shape, roi_truth_noise.shape)
# Out:
# (1400000, 200) (1400000,)

# %%
for i in range(10):
    noise_waveforms = shuffle(noise_waveforms)

# %%
noise_waveforms = noise_waveforms[:y_train.shape[0]]
noiseless_waveform = noiseless_waveform[:y_train.shape[0]]
roi_truth_noise = roi_truth_noise[:y_train.shape[0]]

# %%
print(noise_waveforms.shape, noiseless_waveform.shape, roi_truth_noise.shape)
# Out:
# (1080000, 200) (1080000, 200) (1080000,)

# %% [markdown]
# ## Train/Test Split - Signals

# %%
x_train, x_test, y_train_ROI, y_test_ROI, y_train_AE, y_test_AE = train_test_split(x_train, roi_truth_signals, y_train, test_size=0.5, shuffle=True)
print(x_train.shape, x_test.shape, y_train_ROI.shape, y_train_AE.shape, y_test_ROI.shape, y_test_AE.shape)
# Out:
# (540000, 200) (540000, 200) (540000,) (540000, 200) (540000,) (540000, 200)

# %% [markdown]
# #### Train/Val Split - Signals

# %%
x_train, x_valid, y_train_ROI, y_valid_ROI, y_train_AE, y_valid_AE = train_test_split(x_train, y_train_ROI, y_train_AE, test_size=0.2, shuffle=True)
print(x_train.shape, x_valid.shape, y_train_ROI.shape, y_train_AE.shape, y_valid_ROI.shape, y_valid_AE.shape)
# Out:
# (432000, 200) (108000, 200) (432000,) (432000, 200) (108000,) (108000, 200)

# %% [markdown]
# ## Train/Test Split - Noise

# %%
x_noise_train, x_noise_test, y_noise_train_ROI, y_noise_test_ROI, y_noise_train_AE, y_noise_test_AE = train_test_split(noise_waveforms, 
                                                                                                     roi_truth_noise, noiseless_waveform, test_size=0.5, shuffle=True)
print(x_noise_train.shape, x_noise_test.shape, y_noise_train_ROI.shape, y_noise_train_AE.shape, y_noise_test_ROI.shape, y_noise_test_AE.shape)
# Out:
# (540000, 200) (540000, 200) (540000,) (540000, 200) (540000,) (540000, 200)

# %% [markdown]
# #### Train/Val Split - Noise

# %%
x_noise_train, x_noise_valid, y_noise_train_ROI, y_noise_valid_ROI, y_noise_train_AE, y_noise_valid_AE = train_test_split(x_noise_train, 
                                                                                                        y_noise_train_ROI, y_noise_train_AE,
                                                                                                        test_size=0.2, shuffle=True)
print(x_noise_train.shape, x_noise_valid.shape, y_noise_train_ROI.shape, y_noise_train_AE.shape, y_noise_valid_ROI.shape, y_noise_valid_AE.shape)
# Out:
# (432000, 200) (108000, 200) (432000,) (432000, 200) (108000,) (108000, 200)

# %% [markdown]
# ## Combine Signal + Noise

# %%
x_train = np.concatenate((x_train, x_noise_train))
y_train_ROI = np.concatenate((y_train_ROI, y_noise_train_ROI))
y_train_AE = np.concatenate((y_train_AE, y_noise_train_AE))

x_valid = np.concatenate((x_valid, x_noise_valid))
y_valid_ROI = np.concatenate((y_valid_ROI, y_noise_valid_ROI))
y_valid_AE = np.concatenate((y_valid_AE, y_noise_valid_AE))

x_test = np.concatenate((x_test, x_noise_test))
y_test_ROI = np.concatenate((y_test_ROI, y_noise_test_ROI))
y_test_AE = np.concatenate((y_test_AE, y_noise_test_AE))

print(x_train.shape, y_train_ROI.shape, y_train_AE.shape)
print(x_valid.shape, y_valid_ROI.shape, y_valid_AE.shape)
print(x_test.shape, y_test_AE.shape, y_test_ROI.shape)
# Out:
# (864000, 200) (864000,) (864000, 200)
# (216000, 200) (216000,) (216000, 200)
# (1080000, 200) (1080000, 200) (1080000,)

# %%
for i in range(100):
    x_train, y_train_ROI, y_train_AE = shuffle(x_train, y_train_ROI, y_train_AE)
    x_valid, y_valid_ROI, y_valid_AE = shuffle(x_valid, y_valid_ROI, y_valid_AE)
    x_test, y_test_ROI, y_test_AE = shuffle(x_test, y_test_ROI, y_test_AE)

# %%
print(x_train.shape, y_train_ROI.shape, y_train_AE.shape)
print(x_valid.shape, y_valid_ROI.shape, y_valid_AE.shape)
print(x_test.shape, y_test_AE.shape, y_test_ROI.shape)
# Out:
# (864000, 200) (864000,) (864000, 200)
# (216000, 200) (216000,) (216000, 200)
# (1080000, 200) (1080000, 200) (1080000,)

# %%
for i in range(10):
    fig = plt.figure(figsize=(8,1))
    plt.title(y_train_ROI[i])
    plt.plot(x_valid[i])
    plt.plot(y_train_AE[i])
    plt.show()

# %%
mean = x_train.mean()
std = x_train.std()

# %%
print(mean, std)
# Out:
# 0.003920474537037037 4.8398532366283264

# %%
np.save("models_scales/mean_60k"+wireplane+"_nu", mean)
np.save("models_scales/scale_60k"+wireplane+"_nu", std)

# %%
x_train_scaled = (x_train-mean)/std
y_train_AE_scaled = (y_train_AE-mean)/std

x_valid_scaled = (x_valid-mean)/std
y_valid_AE_scaled = (y_valid_AE-mean)/std

x_test_scaled = (x_test-mean)/std
y_test_AE_scaled = (y_test_AE-mean)/std

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (864000, 200, 1) (216000, 200, 1) (1080000, 200, 1)

# %% [markdown]
# # MODEL - ROI

# %%
#!pip install keras-tuner --upgrade

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
    model = Sequential()  
    #first convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
    model.add(MaxPooling1D(pool_size=2))

    #second convolutional block
    model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.1))

    #forth convolutional block                                      
    model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2)) 

    model.add(Flatten())



    model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
    return model

# %%
model_ROI = create_model()

#lr=0.001
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model_ROI.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model_ROI.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________
# 2023-07-25 21:21:40.351903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:40.405550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:40.406066: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:40.415010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:40.415363: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:40.415662: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:41.051871: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:41.052230: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:41.052501: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-25 21:21:41.052773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18083 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 2g.20gb, pci bus id: 0000:05:00.0, compute capability: 8.0

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#%%time
history = model_ROI.fit(x_train_scaled,                                                              
                    y_train_ROI,
                    batch_size = 512,
                    epochs=100,      
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid_ROI),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 2023-07-25 21:21:44.229651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-25 21:21:46.003870: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1688/1688 [==============================] - 12s 5ms/step - loss: 0.3326 - accuracy: 0.8574 - val_loss: 0.3091 - val_accuracy: 0.8698
# Epoch 2/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3093 - accuracy: 0.8703 - val_loss: 0.3051 - val_accuracy: 0.8714
# Epoch 3/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3062 - accuracy: 0.8715 - val_loss: 0.3028 - val_accuracy: 0.8731
# Epoch 4/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3048 - accuracy: 0.8720 - val_loss: 0.3018 - val_accuracy: 0.8732
# Epoch 5/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3039 - accuracy: 0.8725 - val_loss: 0.3039 - val_accuracy: 0.8723
# Epoch 6/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3033 - accuracy: 0.8728 - val_loss: 0.3029 - val_accuracy: 0.8726
# Epoch 7/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3026 - accuracy: 0.8731 - val_loss: 0.3025 - val_accuracy: 0.8728
# Epoch 8/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3024 - accuracy: 0.8729 - val_loss: 0.3011 - val_accuracy: 0.8736
# Epoch 9/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3019 - accuracy: 0.8731 - val_loss: 0.3020 - val_accuracy: 0.8732
# Epoch 10/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3016 - accuracy: 0.8732 - val_loss: 0.3016 - val_accuracy: 0.8734
# Epoch 11/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3014 - accuracy: 0.8733 - val_loss: 0.3016 - val_accuracy: 0.8731
# Epoch 12/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3011 - accuracy: 0.8734 - val_loss: 0.3009 - val_accuracy: 0.8734
# Epoch 13/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3009 - accuracy: 0.8735 - val_loss: 0.3009 - val_accuracy: 0.8736
# Epoch 14/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3009 - accuracy: 0.8736 - val_loss: 0.3012 - val_accuracy: 0.8737
# Epoch 15/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3006 - accuracy: 0.8739 - val_loss: 0.3011 - val_accuracy: 0.8737
# Epoch 16/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3003 - accuracy: 0.8740 - val_loss: 0.3013 - val_accuracy: 0.8736
# Epoch 17/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3004 - accuracy: 0.8736 - val_loss: 0.3010 - val_accuracy: 0.8736
# Epoch 18/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3000 - accuracy: 0.8740 - val_loss: 0.3010 - val_accuracy: 0.8737
# Epoch 19/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3000 - accuracy: 0.8737 - val_loss: 0.3010 - val_accuracy: 0.8735
# Epoch 20/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2999 - accuracy: 0.8738 - val_loss: 0.3023 - val_accuracy: 0.8727
# Epoch 21/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2997 - accuracy: 0.8740 - val_loss: 0.3026 - val_accuracy: 0.8729
# Epoch 22/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2994 - accuracy: 0.8742 - val_loss: 0.3014 - val_accuracy: 0.8733
# Epoch 23/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2995 - accuracy: 0.8741 - val_loss: 0.3035 - val_accuracy: 0.8720

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#HERE

import gc
gc.collect()
# Out:
# 25623

# %%
model_ROI.save("ROI_ar39_models/model_60k" + wireplane + "plane_nu_ROI.h5")

# %%
model_ROI.evaluate(x_test_scaled, y_test_ROI, batch_size=4096)
# Out:
# 264/264 [==============================] - 1s 4ms/step - loss: 0.3008 - accuracy: 0.8735
# [0.30079343914985657, 0.8735379576683044]

# %%
x_train_ = x_train_scaled
y_train_ = y_train_ROI

x_valid_ = x_valid_scaled
y_valid_ = y_valid_ROI

# %% [markdown]
# # test

# %%
#%%time
all_infer = model_ROI.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test_ROI
# Out:
# 264/264 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model_ROI.predict(x_test_scaled[y_test_ROI==1], batch_size=4096)
all_infer_noise = model_ROI.predict(x_test_scaled[y_test_ROI==0], batch_size=4096)
# Out:
# 132/132 [==============================] - 0s 3ms/step
# 132/132 [==============================] - 0s 3ms/step
# CPU times: user 1.82 s, sys: 1.58 s, total: 3.39 s
# Wall time: 2.8 s

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([   375., 151478., 150176.,  81264.,  46948.,  29684.,  19910.,
#          14102.,  10164.,   7792.,   5891.,   4715.,   3802.,   2945.,
#           2542.,   2148.,   1836.,   1574.,   1392.,   1262.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([1.80000e+01, 1.15330e+04, 2.00260e+04, 1.65580e+04, 1.37210e+04,
#         1.15930e+04, 1.00250e+04, 9.10400e+03, 8.25400e+03, 7.64000e+03,
#         7.27200e+03, 7.18000e+03, 6.95700e+03, 7.24300e+03, 7.45200e+03,
#         8.27400e+03, 9.60200e+03, 1.21290e+04, 1.90310e+04, 3.46388e+05]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
a = [out for out in all_infer if out >= 0.94]

# %%
len(a)/len(all_infer)
# Out:
# 0.32661944444444446

# %%
all_infer
# Out:
# array([[0.07378891],
#        [0.9999976 ],
#        [0.9982773 ],
#        ...,
#        [0.57662374],
#        [0.19886057],
#        [1.        ]], dtype=float32)

# %%
sigs_truth = []
sigs_pred = []

noise_truth = []
noise_pred = []

for i, truth in enumerate(all_y_test):
    if truth == 1:
        sigs_truth.append(truth)
        sigs_pred.append(all_infer[i])
    else:
        noise_truth.append(truth)
        noise_pred.append(all_infer[i])

# %%
print(len(sigs_truth), len(sigs_pred))
print(len(noise_truth), len(noise_pred))
# Out:
# 540000 540000
# 540000 540000

# %%
a = [out for out in sigs_pred if out >= 0.94]

# %%
len(a)/len(sigs_truth)
# Out:
# 0.6504055555555556

# %%
a = [out for out in noise_pred if out < 0.94]

# %%
len(a)/len(noise_truth)
# Out:
# 0.9971666666666666

# %% [markdown]
# # MODEL - AE

# %%
from tensorflow.keras.layers import Conv1DTranspose

# %%
time_periods = 200
autoencoder = Sequential()
# encoder
autoencoder.add(Conv1D(filters=16, kernel_size=3, padding="same", strides=2, activation = "relu", input_shape=(time_periods,1)))
autoencoder.add(Conv1D(filters=32, kernel_size=5, padding="same", strides=4, activation = "relu"))
autoencoder.add(Conv1D(filters=64, kernel_size=9, padding="same", strides=5, activation = "relu"))

# decoder
autoencoder.add(Conv1DTranspose(filters=64, kernel_size=9, padding="same", strides=5, activation = "relu"))
autoencoder.add(Conv1DTranspose(filters=32, kernel_size=5, padding="same", strides=4, activation = "relu"))
autoencoder.add(Conv1DTranspose(filters=16, kernel_size=3, padding="same", strides=2, activation = "relu"))

autoencoder.add(Conv1DTranspose(filters=1, kernel_size=3, padding="same"))

autoencoder.compile(loss='mse', optimizer='adam')

# %%
autoencoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 100, 16)           64
#
#  conv1d_4 (Conv1D)           (None, 25, 32)            2592
#
#  conv1d_5 (Conv1D)           (None, 5, 64)             18496
#
#  conv1d_transpose (Conv1DTra  (None, 25, 64)           36928
#  nspose)
#
#  conv1d_transpose_1 (Conv1DT  (None, 100, 32)          10272
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 200, 16)          1552
#  ranspose)
#
#  conv1d_transpose_3 (Conv1DT  (None, 200, 1)           49
#  ranspose)
#
# =================================================================
# Total params: 69,953
# Trainable params: 69,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
history_AE = autoencoder.fit(x_train_scaled,                                                              
            y_train_AE_scaled,                                                            
            batch_size=512,                                              
            epochs=1000,                                                      
            callbacks= [earlystop], #[NewCallback(alpha)], # callbacks=callbacks_list,
            validation_data=(x_valid_scaled, y_valid_AE_scaled),                                                                      
            verbose=1)
# Out:
# Epoch 1/1000
# 2023-07-25 21:24:42.473344: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f825461ef80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-25 21:24:42.473411: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA A100 80GB PCIe MIG 2g.20gb, Compute Capability 8.0
# 2023-07-25 21:24:42.479045: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-25 21:24:43.056130: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1688/1688 [==============================] - 19s 7ms/step - loss: 0.0305 - val_loss: 0.0251
# Epoch 2/1000
# 1688/1688 [==============================] - 11s 6ms/step - loss: 0.0250 - val_loss: 0.0249
# Epoch 3/1000
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.0248 - val_loss: 0.0247
# Epoch 4/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0247 - val_loss: 0.0246
# Epoch 5/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0246 - val_loss: 0.0248
# Epoch 6/1000
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.0245 - val_loss: 0.0249
# Epoch 7/1000
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.0244 - val_loss: 0.0247
# Epoch 8/1000
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.0244 - val_loss: 0.0246
# Epoch 9/1000
# 1688/1688 [==============================] - 11s 6ms/step - loss: 0.0243 - val_loss: 0.0245
# Epoch 10/1000
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0243 - val_loss: 0.0245
# Epoch 11/1000
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.0243 - val_loss: 0.0245
# Epoch 12/1000
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.0242 - val_loss: 0.0245
# Epoch 13/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0242 - val_loss: 0.0246
# Epoch 14/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0242 - val_loss: 0.0245
# Epoch 15/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0241 - val_loss: 0.0245
# Epoch 16/1000
# 1688/1688 [==============================] - 11s 6ms/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 17/1000
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 18/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 19/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0240 - val_loss: 0.0246
# Epoch 20/1000
# 1688/1688 [==============================] - 12s 7ms/step - loss: 0.0240 - val_loss: 0.0245
# Epoch 21/1000
# 1688/1688 [==============================] - 11s 6ms/step - loss: 0.0240 - val_loss: 0.0248
# Epoch 22/1000
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.0239 - val_loss: 0.0245

# %%
predictions = autoencoder.predict(x_test_scaled, batch_size=4096)
predictions = predictions.reshape(predictions.shape[0], predictions.shape[1])
# Out:
# 264/264 [==============================] - 4s 14ms/step

# %%
for i in range(100):
    wave = x_test_scaled[i:i+1]
    if model_ROI.predict(wave) >= 0.94:
        print(wave.shape)
        ae_pred = autoencoder.predict(wave)
        print(ae_pred.shape)
        pred = ae_pred*std + mean
        
        #wave_re_scaled = wave*std + mean
    
        plt.plot(pred[0])
        plt.plot(y_test_AE[i])
        plt.show()
# Out:
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 27ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 161ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 24ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 22ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 38ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 28ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 253ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 28ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 200ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 22ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 21ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 31ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 18ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# (1, 200, 1)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
autoencoder.save("AE_ar39_models/model_60k" + wireplane + "plane_nu_AE.h5")
