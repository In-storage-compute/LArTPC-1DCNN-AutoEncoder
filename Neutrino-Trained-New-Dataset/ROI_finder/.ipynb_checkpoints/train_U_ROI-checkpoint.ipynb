# %%
import sys
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 2023-04-29 19:09:40.375578: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
np.random.seed(33)

# %%
wireplane = "U"
path = 'processed_data/'
filenames = [path+f for f in listdir(path) if (isfile(join(path, f)) and wireplane in f)]
filenames
# Out:
# ['processed_data/x_train_U.npy',
#  'processed_data/y_train_ROI_U.npy',
#  'processed_data/y_test_AE_U.npy',
#  'processed_data/y_test_ROI_U.npy',
#  'processed_data/x_test_U.npy',
#  'processed_data/y_train_AE_U.npy']

# %%
x_train = np.load(path+'x_train_' + wireplane + '.npy')
x_test = np.load(path+'x_test_' + wireplane + '.npy')
y_train = np.load(path+'y_train_ROI_' + wireplane + '.npy')
y_test = np.load(path+'y_test_ROI_'+wireplane+'.npy')

# %%
print(x_test.shape, y_train.shape, y_test.shape, y_train.shape)
# Out:
# (100000, 200) (100000,) (100000,) (100000,)

# %%
#split train and valid sets
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=0.2, shuffle=True
)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (80000, 200) (80000,)
# (100000, 200) (100000,)
# (20000, 200) (20000,)

# %%
mean = x_train.mean()
std = x_train.std()

# %%
x_train_scaled = (x_train-mean)/std
x_valid_scaled = (x_valid-mean)/std
x_test_scaled = (x_test-mean)/std

# %%
np.save("ROI_models/mean_"+wireplane+"_nu_ROI", mean)
np.save("ROI_models/scale_"+wireplane+"_nu_ROI", std)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, \
    Dropout, Dense,Flatten, AveragePooling1D, BatchNormalization

# %%
time_periods = 200
def create_model():
    model = Sequential()  
    #first convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, strides=2, activation = "relu", input_shape=(time_periods,1)))
    model.add(MaxPooling1D(pool_size=2))

    #second convolutional block
    model.add(Conv1D(filters=32, kernel_size=5, strides=2, activation = "relu"))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.1))

    #forth convolutional block                                      
    model.add(Conv1D(filters=64, kernel_size=9, activation = "relu"))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2)) 

    model.add(Flatten())



    model.add(Dense(1, activation="sigmoid", name="wavrec_out"))
    return model

# %%
model = create_model()

#lr=0.001
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 16)            64
#
#  max_pooling1d (MaxPooling1D  (None, 49, 16)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 23, 32)            2592
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 32)           0
#  1D)
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 3, 64)             18496
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  wavrec_out (Dense)          (None, 1)                 65
#
# =================================================================
# Total params: 21,217
# Trainable params: 21,217
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-29 19:09:42.302280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.306933: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.307276: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.307957: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-29 19:09:42.314765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.315113: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.315415: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.788157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.788536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.788831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-29 19:09:42.789111: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7927 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 1g.10gb, pci bus id: 0000:04:00.0, compute capability: 8.0

# %%
x_train_scaled = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)
x_valid_scaled = x_valid_scaled.reshape(x_valid_scaled.shape[0], x_valid_scaled.shape[1], 1)
x_test_scaled = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
print(x_train_scaled.shape, x_valid_scaled.shape, x_test_scaled.shape)
# Out:
# (80000, 200, 1) (20000, 200, 1) (100000, 200, 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#%%time
history = model.fit(x_train_scaled,                                                              
                    y_train,                                                            
                    batch_size=2048,                                              
                    epochs=100,      
                    
                   # epochs=30, 
                    #epochs = 6,
                    callbacks=[earlystop],
                     # callbacks=callbacks_list,                         
                    validation_data=(x_valid_scaled, y_valid),                                               
                    verbose=1)
# Out:
# Epoch 1/100
# 2023-04-29 19:09:44.582828: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2023-04-29 19:09:45.980963: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Running ptxas --version returned 32512
# 2023-04-29 19:09:46.271110: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: ptxas exited with non-zero error code 32512, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-04-29 19:09:46.416881: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 40/40 [==============================] - 5s 23ms/step - loss: 0.4922 - accuracy: 0.7446 - val_loss: 0.3322 - val_accuracy: 0.8770
# Epoch 2/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3054 - accuracy: 0.8786 - val_loss: 0.2692 - val_accuracy: 0.8964
# Epoch 3/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2766 - accuracy: 0.8900 - val_loss: 0.2582 - val_accuracy: 0.8996
# Epoch 4/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2678 - accuracy: 0.8938 - val_loss: 0.2554 - val_accuracy: 0.9006
# Epoch 5/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2629 - accuracy: 0.8963 - val_loss: 0.2499 - val_accuracy: 0.9021
# Epoch 6/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2603 - accuracy: 0.8974 - val_loss: 0.2486 - val_accuracy: 0.9032
# Epoch 7/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2588 - accuracy: 0.8985 - val_loss: 0.2486 - val_accuracy: 0.9038
# Epoch 8/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2558 - accuracy: 0.9004 - val_loss: 0.2446 - val_accuracy: 0.9051
# Epoch 9/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2533 - accuracy: 0.9008 - val_loss: 0.2437 - val_accuracy: 0.9057
# Epoch 10/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2523 - accuracy: 0.9025 - val_loss: 0.2435 - val_accuracy: 0.9058
# Epoch 11/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2524 - accuracy: 0.9015 - val_loss: 0.2462 - val_accuracy: 0.9044
# Epoch 12/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2516 - accuracy: 0.9019 - val_loss: 0.2411 - val_accuracy: 0.9071
# Epoch 13/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2500 - accuracy: 0.9030 - val_loss: 0.2403 - val_accuracy: 0.9074
# Epoch 14/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2488 - accuracy: 0.9033 - val_loss: 0.2403 - val_accuracy: 0.9073
# Epoch 15/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2479 - accuracy: 0.9042 - val_loss: 0.2399 - val_accuracy: 0.9079
# Epoch 16/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2481 - accuracy: 0.9039 - val_loss: 0.2397 - val_accuracy: 0.9081
# Epoch 17/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2477 - accuracy: 0.9038 - val_loss: 0.2400 - val_accuracy: 0.9076
# Epoch 18/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2464 - accuracy: 0.9050 - val_loss: 0.2392 - val_accuracy: 0.9078
# Epoch 19/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2470 - accuracy: 0.9047 - val_loss: 0.2390 - val_accuracy: 0.9076
# Epoch 20/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2460 - accuracy: 0.9049 - val_loss: 0.2400 - val_accuracy: 0.9075
# Epoch 21/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2463 - accuracy: 0.9043 - val_loss: 0.2393 - val_accuracy: 0.9074
# Epoch 22/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2449 - accuracy: 0.9054 - val_loss: 0.2389 - val_accuracy: 0.9075
# Epoch 23/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2454 - accuracy: 0.9048 - val_loss: 0.2407 - val_accuracy: 0.9079
# Epoch 24/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2455 - accuracy: 0.9053 - val_loss: 0.2387 - val_accuracy: 0.9075
# Epoch 25/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2449 - accuracy: 0.9055 - val_loss: 0.2423 - val_accuracy: 0.9076
# Epoch 26/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2447 - accuracy: 0.9053 - val_loss: 0.2390 - val_accuracy: 0.9071
# Epoch 27/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2436 - accuracy: 0.9057 - val_loss: 0.2389 - val_accuracy: 0.9068
# Epoch 28/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.2433 - accuracy: 0.9062 - val_loss: 0.2386 - val_accuracy: 0.9086
# Epoch 29/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2433 - accuracy: 0.9064 - val_loss: 0.2392 - val_accuracy: 0.9084
# Epoch 30/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2428 - accuracy: 0.9065 - val_loss: 0.2392 - val_accuracy: 0.9071
# Epoch 31/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2419 - accuracy: 0.9062 - val_loss: 0.2382 - val_accuracy: 0.9085
# Epoch 32/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2423 - accuracy: 0.9061 - val_loss: 0.2383 - val_accuracy: 0.9087
# Epoch 33/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2420 - accuracy: 0.9068 - val_loss: 0.2385 - val_accuracy: 0.9074
# Epoch 34/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2422 - accuracy: 0.9068 - val_loss: 0.2398 - val_accuracy: 0.9069
# Epoch 35/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2419 - accuracy: 0.9065 - val_loss: 0.2379 - val_accuracy: 0.9086
# Epoch 36/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2405 - accuracy: 0.9067 - val_loss: 0.2396 - val_accuracy: 0.9082
# Epoch 37/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2413 - accuracy: 0.9074 - val_loss: 0.2383 - val_accuracy: 0.9081
# Epoch 38/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2400 - accuracy: 0.9076 - val_loss: 0.2381 - val_accuracy: 0.9086
# Epoch 39/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.2398 - accuracy: 0.9074 - val_loss: 0.2382 - val_accuracy: 0.9074
# Epoch 40/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.2396 - accuracy: 0.9081 - val_loss: 0.2402 - val_accuracy: 0.9056

# %%
plt.figure(figsize=(12, 8))                                                     
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data", antialiased=True)
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data", antialiased=True)
plt.plot(history.history['loss'], "r--", label="Loss of training data", antialiased=True)
plt.plot(history.history['val_loss'], "r", label="Loss of validation data", antialiased=True)
plt.title('Model Accuracy and Loss')                                            
plt.ylabel('Accuracy and Loss')                                                 
plt.xlabel('Training Epoch')                                                    
#plt.ylim(0)                                                                     
plt.legend()                                                                    
plt.show()

# %%
#del x_train

import gc
gc.collect()
# Out:
# 4399

# %%
model.save("ROI_models/model_" + wireplane + "plane_nu_ROI.h5")

# %%
model.evaluate(x_test_scaled, y_test, batch_size=4096)
# Out:
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2426 - accuracy: 0.9069
# [0.24263912439346313, 0.9068899750709534]

# %%
x_train_ = x_train_scaled
y_train_ = y_train

x_valid_ = x_valid_scaled
y_valid_ = y_valid

# %% [markdown]
# # Train

# %%
# %%time
# %matplotlib inline
import seaborn as sns
infer = model.predict(x_train_, batch_size=1024)
# Out:
# 79/79 [==============================] - 0s 2ms/step
# CPU times: user 572 ms, sys: 176 ms, total: 748 ms
# Wall time: 637 ms

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_train_, infer>0.5)
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
cm2 = confusion_matrix(y_train_, infer>0.9)
sns.heatmap(cm2, annot=True)
# Out:
# <Axes: >

# %%
start_for_plot = 0
fig = plt.figure(figsize=(10,6))
plt.plot(y_train,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_, infer)
auc_keras = auc(fpr_keras, tpr_keras)

# %%
print(auc_keras)
# Out:
# 0.9498659423746649

# %%
np.save("ROI_results/false_positive_" + wireplane + "_train", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_train", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_train", thresholds_keras)

# %% [markdown]
# # Valid

# %%
# %%time
infer = model.predict(x_valid_, batch_size=4096)
# Out:
# 5/5 [==============================] - 0s 41ms/step
# CPU times: user 237 ms, sys: 31 ms, total: 268 ms
# Wall time: 241 ms

# %%
cmv = confusion_matrix(y_valid_, infer>0.5)
sns.heatmap(cmv, annot=True)
plt.show()

# %%
cmv2 = confusion_matrix(y_valid_, infer>0.9)
sns.heatmap(cmv2, annot=True)
# Out:
# <Axes: >

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10,6))
plt.plot(y_valid_,color='orange',alpha=0.5, label='True')
plt.plot(infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid_, infer)
auc_keras = auc(fpr_keras, tpr_keras)
print(auc_keras)
# Out:
# 0.9473848878953957

# %%
np.save("ROI_results/false_positive_" + wireplane + "_valid", fpr_keras)
np.save("ROI_results/true_positive_" + wireplane + "_valid", tpr_keras)
np.save("ROI_results/thresholds_" + wireplane + "_valid", thresholds_keras)

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc_keras,3)))
plt.title("ROC Curve - Validation Dataset")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %% [markdown]
# # test

# %%
#%%time
all_infer = model.predict(x_test_scaled, batch_size=4096)
all_y_test = y_test
# Out:
# 25/25 [==============================] - 0s 3ms/step

# %%
all1 = confusion_matrix(all_y_test, all_infer>0.5)
sns.heatmap(all1, annot=True)
plt.title("Confusion Matrix - Test Dataset Plane " + wireplane)
plt.xlabel("Predicted Class (>0.5)")
plt.ylabel("True Class")
plt.show()

# %%
start_for_plot = 4000
fig = plt.figure(figsize=(10, 8))
plt.plot(all_y_test,color='orange',alpha=0.5, label='True')
plt.plot(all_infer,color='blue',alpha=0.7, label='predicted')
plt.xlim(start_for_plot, start_for_plot + 200)
plt.title("infer")
plt.legend()
plt.show()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(all_y_test, all_infer)
plt.plot(fpr_keras, tpr_keras, label='auc: ' + str(round(auc(fpr_keras, tpr_keras), 3)))
plt.title("ROC Curve - Test Dataset Plane " + wireplane )
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='center')
plt.show()

# %%
# %%time
#cc_infer_signal = model.predict(cc_x_test_scaled[cc_y_test==1], batch_size=4096)
#cc_infer_noise = model.predict(cc_x_test_scaled[cc_y_test==0], batch_size=4096)
#es_infer_signal = model.predict(es_x_test_scaled[es_y_test==1], batch_size=4096)
#es_infer_noise = model.predict(es_x_test_scaled[es_y_test==0], batch_size=4096)
all_infer_signal = model.predict(x_test_scaled[y_test==1], batch_size=4096)
all_infer_noise = model.predict(x_test_scaled[y_test==0], batch_size=4096)
# Out:
# 13/13 [==============================] - 0s 13ms/step
# 13/13 [==============================] - 0s 3ms/step
# CPU times: user 410 ms, sys: 182 ms, total: 592 ms
# Wall time: 496 ms

# %%
plt.hist(all_infer_noise, range = (0,1), bins=20)
# Out:
# (array([    0., 22721., 14138.,  5030.,  2447.,  1545.,  1007.,   740.,
#           533.,   402.,   275.,   254.,   186.,   167.,   144.,   118.,
#            89.,    91.,    63.,    50.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(all_infer_signal, range = (0,1), bins=20)
# Out:
# (array([    0.,  1926.,  2039.,  1107.,   701.,   545.,   471.,   391.,
#           377.,   317.,   302.,   282.,   276.,   307.,   295.,   339.,
#           395.,   456.,   706., 38768.]),
#  array([0.        , 0.05      , 0.1       , 0.15000001, 0.2       ,
#         0.25      , 0.30000001, 0.34999999, 0.40000001, 0.44999999,
#         0.5       , 0.55000001, 0.60000002, 0.64999998, 0.69999999,
#         0.75      , 0.80000001, 0.85000002, 0.89999998, 0.94999999,
#         1.        ]),
#  <BarContainer object of 20 artists>)
